# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from google.cloud import speech_v1p1beta1 as speech
client = speech.SpeechClient()

speech_file = 'audio_file/commercial_mono.wav'     # files less than 1 minute

with open(speech_file, 'rb') as audio_file:
    content = audio_file.read()

audio = speech.types.RecognitionAudio(content=content)

config = speech.types.RecognitionConfig(
    encoding=speech.enums.RecognitionConfig.AudioEncoding.LINEAR16,
    sample_rate_hertz=8000,
    language_code='en-US',
    enable_speaker_diarization=True,
    diarization_speaker_count=2)

print('Waiting for operation to complete...')
response = client.recognize(config, audio)
print("complete !!!")
# Out:
# Waiting for operation to complete...
# complete !!!

# %%
# The transcript within each result is separate and sequential per result.
# However, the words list within an alternative includes all the words
# from all the results thus far. Thus, to get all the words with speaker
# tags, you only have to take the words list from the last result:
result = response.results[-1]

words_infos = result.alternatives[0].words

# Printing out the output:
for word_info in words_infos:
    print("word: '{}', speaker_tag: {}".format(word_info.word,
                                               word_info.speaker_tag))
# Out:
# word: 'I'm', speaker_tag: 1
# word: 'here', speaker_tag: 1
# word: 'hi', speaker_tag: 1
# word: 'I'd', speaker_tag: 1
# word: 'like', speaker_tag: 1
# word: 'to', speaker_tag: 1
# word: 'buy', speaker_tag: 1
# word: 'a', speaker_tag: 1
# word: 'Chrome', speaker_tag: 1
# word: 'Cast', speaker_tag: 1
# word: 'and', speaker_tag: 1
# word: 'I', speaker_tag: 1
# word: 'was', speaker_tag: 1
# word: 'wondering', speaker_tag: 1
# word: 'whether', speaker_tag: 1
# word: 'you', speaker_tag: 1
# word: 'could', speaker_tag: 1
# word: 'help', speaker_tag: 1
# word: 'me', speaker_tag: 1
# word: 'with', speaker_tag: 1
# word: 'that', speaker_tag: 1
# word: 'Hulu', speaker_tag: 1
# word: 'which', speaker_tag: 1
# word: 'color', speaker_tag: 1
# word: 'would', speaker_tag: 1
# word: 'you', speaker_tag: 1
# word: 'like', speaker_tag: 1
# word: 'we', speaker_tag: 1
# word: 'have', speaker_tag: 1
# word: 'blue', speaker_tag: 1
# word: 'black', speaker_tag: 1
# word: 'and', speaker_tag: 1
# word: 'breath', speaker_tag: 1
# word: 'let's', speaker_tag: 1
# word: 'get', speaker_tag: 1
# word: 'the', speaker_tag: 1
# word: 'black', speaker_tag: 1
# word: 'one', speaker_tag: 1
# word: 'okay', speaker_tag: 1
# word: 'Chris', speaker_tag: 1
# word: 'would', speaker_tag: 1
# word: 'you', speaker_tag: 1
# word: 'like', speaker_tag: 1
# word: 'the', speaker_tag: 1
# word: 'New', speaker_tag: 1
# word: 'Concord', speaker_tag: 1
# word: 'Ultra', speaker_tag: 1
# word: 'model', speaker_tag: 1
# word: 'or', speaker_tag: 1
# word: 'the', speaker_tag: 1
# word: 'regular', speaker_tag: 1
# word: 'Comcast', speaker_tag: 1
# word: 'regular', speaker_tag: 1
# word: 'Chrome', speaker_tag: 1
# word: 'Cast', speaker_tag: 1
# word: 'design', speaker_tag: 1
# word: 'okay', speaker_tag: 1
# word: 'sure', speaker_tag: 1
# word: 'would', speaker_tag: 1
# word: 'you', speaker_tag: 1
# word: 'like', speaker_tag: 1
# word: 'to', speaker_tag: 1
# word: 'ship', speaker_tag: 1
# word: 'it', speaker_tag: 1
# word: 'regular', speaker_tag: 1
# word: 'or', speaker_tag: 1
# word: 'Express', speaker_tag: 1
# word: 'Express', speaker_tag: 1
# word: 'please', speaker_tag: 1
# word: 'terrific', speaker_tag: 1
# word: 'it's', speaker_tag: 1
# word: 'on', speaker_tag: 1
# word: 'the', speaker_tag: 1
# word: 'way', speaker_tag: 1
# word: 'thank', speaker_tag: 1
# word: 'you', speaker_tag: 1
# word: 'very', speaker_tag: 1
# word: 'much', speaker_tag: 1
# word: 'thank', speaker_tag: 1
# word: 'you', speaker_tag: 1
# word: 'bye', speaker_tag: 1

# %%
response.results[9]
# Out:
# alternatives {
#   transcript: " bye"
#   confidence: 0.7384932637214661
#   words {
#     start_time {
#       seconds: 2
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 2
#       nanos: 700000000
#     }
#     word: "I\'m"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 2
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 2
#       nanos: 900000000
#     }
#     word: "here"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 4
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 4
#       nanos: 900000000
#     }
#     word: "hi"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 4
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 5
#       nanos: 600000000
#     }
#     word: "I\'d"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 5
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 5
#       nanos: 700000000
#     }
#     word: "like"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 5
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 5
#       nanos: 800000000
#     }
#     word: "to"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 5
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 6
#     }
#     word: "buy"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 6
#     }
#     end_time {
#       seconds: 6
#     }
#     word: "a"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 6
#     }
#     end_time {
#       seconds: 6
#       nanos: 300000000
#     }
#     word: "Chrome"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 6
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 6
#       nanos: 600000000
#     }
#     word: "Cast"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 6
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 7
#     }
#     word: "and"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 7
#     }
#     end_time {
#       seconds: 7
#       nanos: 200000000
#     }
#     word: "I"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 7
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 7
#       nanos: 200000000
#     }
#     word: "was"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 7
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 7
#       nanos: 500000000
#     }
#     word: "wondering"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 7
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 7
#       nanos: 800000000
#     }
#     word: "whether"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 7
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 7
#       nanos: 900000000
#     }
#     word: "you"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 7
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 8
#     }
#     word: "could"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 8
#     }
#     end_time {
#       seconds: 8
#       nanos: 200000000
#     }
#     word: "help"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 8
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 8
#       nanos: 400000000
#     }
#     word: "me"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 8
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 8
#       nanos: 600000000
#     }
#     word: "with"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 8
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 8
#       nanos: 600000000
#     }
#     word: "that"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 10
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 100000000
#     }
#     word: "Hulu"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 400000000
#     }
#     word: "which"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 700000000
#     }
#     word: "color"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 800000000
#     }
#     word: "would"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 900000000
#     }
#     word: "you"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 12
#     }
#     word: "like"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 12
#     }
#     end_time {
#       seconds: 12
#       nanos: 400000000
#     }
#     word: "we"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 12
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 12
#       nanos: 600000000
#     }
#     word: "have"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 12
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 13
#     }
#     word: "blue"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 13
#     }
#     end_time {
#       seconds: 13
#       nanos: 400000000
#     }
#     word: "black"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 13
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 13
#       nanos: 500000000
#     }
#     word: "and"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 13
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 13
#       nanos: 900000000
#     }
#     word: "breath"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 15
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 15
#       nanos: 900000000
#     }
#     word: "let\'s"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 15
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 16
#     }
#     word: "get"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 16
#     }
#     end_time {
#       seconds: 16
#       nanos: 200000000
#     }
#     word: "the"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 16
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 16
#       nanos: 300000000
#     }
#     word: "black"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 16
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 16
#       nanos: 600000000
#     }
#     word: "one"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 18
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 18
#       nanos: 900000000
#     }
#     word: "okay"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 18
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 19
#     }
#     word: "Chris"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 19
#     }
#     end_time {
#       seconds: 19
#       nanos: 600000000
#     }
#     word: "would"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 19
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 19
#       nanos: 600000000
#     }
#     word: "you"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 19
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 20
#       nanos: 100000000
#     }
#     word: "like"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 20
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 20
#       nanos: 300000000
#     }
#     word: "the"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 20
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 20
#       nanos: 500000000
#     }
#     word: "New"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 20
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 20
#       nanos: 900000000
#     }
#     word: "Concord"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 20
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 21
#       nanos: 500000000
#     }
#     word: "Ultra"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 21
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 21
#       nanos: 900000000
#     }
#     word: "model"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 21
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 22
#       nanos: 300000000
#     }
#     word: "or"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 22
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 22
#       nanos: 300000000
#     }
#     word: "the"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 22
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 22
#       nanos: 900000000
#     }
#     word: "regular"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 22
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 23
#       nanos: 300000000
#     }
#     word: "Comcast"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 24
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 26
#       nanos: 100000000
#     }
#     word: "regular"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 26
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 26
#       nanos: 300000000
#     }
#     word: "Chrome"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 26
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 26
#       nanos: 500000000
#     }
#     word: "Cast"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 26
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 26
#       nanos: 900000000
#     }
#     word: "design"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 28
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 29
#       nanos: 100000000
#     }
#     word: "okay"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 29
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 29
#       nanos: 400000000
#     }
#     word: "sure"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 29
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 30
#     }
#     word: "would"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 30
#     }
#     end_time {
#       seconds: 30
#       nanos: 100000000
#     }
#     word: "you"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 30
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 30
#       nanos: 300000000
#     }
#     word: "like"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 30
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 30
#       nanos: 400000000
#     }
#     word: "to"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 30
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 30
#       nanos: 900000000
#     }
#     word: "ship"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 30
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 31
#     }
#     word: "it"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 31
#     }
#     end_time {
#       seconds: 31
#       nanos: 200000000
#     }
#     word: "regular"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 31
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 31
#       nanos: 800000000
#     }
#     word: "or"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 31
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 32
#       nanos: 300000000
#     }
#     word: "Express"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 33
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 34
#       nanos: 400000000
#     }
#     word: "Express"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 34
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 34
#       nanos: 600000000
#     }
#     word: "please"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 36
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 36
#       nanos: 900000000
#     }
#     word: "terrific"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 36
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 37
#       nanos: 500000000
#     }
#     word: "it\'s"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 37
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 38
#     }
#     word: "on"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 38
#     }
#     end_time {
#       seconds: 38
#       nanos: 100000000
#     }
#     word: "the"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 38
#       nanos: 200000000
#     }
#     word: "way"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 38
#       nanos: 700000000
#     }
#     word: "thank"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 38
#       nanos: 800000000
#     }
#     word: "you"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 38
#       nanos: 900000000
#     }
#     word: "very"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 39
#       nanos: 100000000
#     }
#     word: "much"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 39
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 40
#       nanos: 700000000
#     }
#     word: "thank"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 40
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 40
#       nanos: 900000000
#     }
#     word: "you"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 42
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 42
#       nanos: 600000000
#     }
#     word: "bye"
#     speaker_tag: 1
#   }
# }
# language_code: "en-us"

# %%
response.results[-1]
# Out:
# alternatives {
#   transcript: " bye"
#   confidence: 0.7384932637214661
#   words {
#     start_time {
#       seconds: 2
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 2
#       nanos: 700000000
#     }
#     word: "I\'m"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 2
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 2
#       nanos: 900000000
#     }
#     word: "here"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 4
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 4
#       nanos: 900000000
#     }
#     word: "hi"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 4
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 5
#       nanos: 600000000
#     }
#     word: "I\'d"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 5
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 5
#       nanos: 700000000
#     }
#     word: "like"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 5
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 5
#       nanos: 800000000
#     }
#     word: "to"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 5
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 6
#     }
#     word: "buy"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 6
#     }
#     end_time {
#       seconds: 6
#     }
#     word: "a"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 6
#     }
#     end_time {
#       seconds: 6
#       nanos: 300000000
#     }
#     word: "Chrome"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 6
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 6
#       nanos: 600000000
#     }
#     word: "Cast"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 6
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 7
#     }
#     word: "and"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 7
#     }
#     end_time {
#       seconds: 7
#       nanos: 200000000
#     }
#     word: "I"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 7
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 7
#       nanos: 200000000
#     }
#     word: "was"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 7
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 7
#       nanos: 500000000
#     }
#     word: "wondering"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 7
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 7
#       nanos: 800000000
#     }
#     word: "whether"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 7
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 7
#       nanos: 900000000
#     }
#     word: "you"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 7
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 8
#     }
#     word: "could"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 8
#     }
#     end_time {
#       seconds: 8
#       nanos: 200000000
#     }
#     word: "help"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 8
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 8
#       nanos: 400000000
#     }
#     word: "me"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 8
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 8
#       nanos: 600000000
#     }
#     word: "with"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 8
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 8
#       nanos: 600000000
#     }
#     word: "that"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 10
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 100000000
#     }
#     word: "Hulu"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 400000000
#     }
#     word: "which"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 700000000
#     }
#     word: "color"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 800000000
#     }
#     word: "would"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 900000000
#     }
#     word: "you"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 12
#     }
#     word: "like"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 12
#     }
#     end_time {
#       seconds: 12
#       nanos: 400000000
#     }
#     word: "we"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 12
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 12
#       nanos: 600000000
#     }
#     word: "have"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 12
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 13
#     }
#     word: "blue"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 13
#     }
#     end_time {
#       seconds: 13
#       nanos: 400000000
#     }
#     word: "black"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 13
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 13
#       nanos: 500000000
#     }
#     word: "and"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 13
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 13
#       nanos: 900000000
#     }
#     word: "breath"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 15
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 15
#       nanos: 900000000
#     }
#     word: "let\'s"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 15
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 16
#     }
#     word: "get"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 16
#     }
#     end_time {
#       seconds: 16
#       nanos: 200000000
#     }
#     word: "the"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 16
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 16
#       nanos: 300000000
#     }
#     word: "black"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 16
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 16
#       nanos: 600000000
#     }
#     word: "one"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 18
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 18
#       nanos: 900000000
#     }
#     word: "okay"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 18
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 19
#     }
#     word: "Chris"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 19
#     }
#     end_time {
#       seconds: 19
#       nanos: 600000000
#     }
#     word: "would"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 19
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 19
#       nanos: 600000000
#     }
#     word: "you"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 19
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 20
#       nanos: 100000000
#     }
#     word: "like"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 20
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 20
#       nanos: 300000000
#     }
#     word: "the"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 20
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 20
#       nanos: 500000000
#     }
#     word: "New"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 20
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 20
#       nanos: 900000000
#     }
#     word: "Concord"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 20
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 21
#       nanos: 500000000
#     }
#     word: "Ultra"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 21
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 21
#       nanos: 900000000
#     }
#     word: "model"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 21
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 22
#       nanos: 300000000
#     }
#     word: "or"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 22
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 22
#       nanos: 300000000
#     }
#     word: "the"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 22
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 22
#       nanos: 900000000
#     }
#     word: "regular"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 22
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 23
#       nanos: 300000000
#     }
#     word: "Comcast"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 24
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 26
#       nanos: 100000000
#     }
#     word: "regular"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 26
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 26
#       nanos: 300000000
#     }
#     word: "Chrome"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 26
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 26
#       nanos: 500000000
#     }
#     word: "Cast"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 26
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 26
#       nanos: 900000000
#     }
#     word: "design"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 28
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 29
#       nanos: 100000000
#     }
#     word: "okay"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 29
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 29
#       nanos: 400000000
#     }
#     word: "sure"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 29
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 30
#     }
#     word: "would"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 30
#     }
#     end_time {
#       seconds: 30
#       nanos: 100000000
#     }
#     word: "you"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 30
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 30
#       nanos: 300000000
#     }
#     word: "like"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 30
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 30
#       nanos: 400000000
#     }
#     word: "to"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 30
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 30
#       nanos: 900000000
#     }
#     word: "ship"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 30
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 31
#     }
#     word: "it"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 31
#     }
#     end_time {
#       seconds: 31
#       nanos: 200000000
#     }
#     word: "regular"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 31
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 31
#       nanos: 800000000
#     }
#     word: "or"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 31
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 32
#       nanos: 300000000
#     }
#     word: "Express"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 33
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 34
#       nanos: 400000000
#     }
#     word: "Express"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 34
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 34
#       nanos: 600000000
#     }
#     word: "please"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 36
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 36
#       nanos: 900000000
#     }
#     word: "terrific"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 36
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 37
#       nanos: 500000000
#     }
#     word: "it\'s"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 37
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 38
#     }
#     word: "on"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 38
#     }
#     end_time {
#       seconds: 38
#       nanos: 100000000
#     }
#     word: "the"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 38
#       nanos: 200000000
#     }
#     word: "way"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 38
#       nanos: 700000000
#     }
#     word: "thank"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 38
#       nanos: 800000000
#     }
#     word: "you"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 38
#       nanos: 900000000
#     }
#     word: "very"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 39
#       nanos: 100000000
#     }
#     word: "much"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 39
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 40
#       nanos: 700000000
#     }
#     word: "thank"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 40
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 40
#       nanos: 900000000
#     }
#     word: "you"
#     speaker_tag: 1
#   }
#   words {
#     start_time {
#       seconds: 42
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 42
#       nanos: 600000000
#     }
#     word: "bye"
#     speaker_tag: 1
#   }
# }
# language_code: "en-us"
