# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Google-Cloud-Speech-to-Text-API-Streaming-example" data-toc-modified-id="Google-Cloud-Speech-to-Text-API-Streaming-example-1">Google Cloud Speech-to-Text API Streaming example</a></span></li></ul></div>

# %% [markdown]
# # Google Cloud Speech-to-Text API Streaming example

# %% [markdown]
# - 1분 이상의 긴 오디오 파일을 Streaming 방식으로 처리하는 샘플
# - https://cloud.google.com/speech-to-text/docs/streaming-recognize
# - google.cloud.speech.SpeechClient().**streaming_recognize(streaming_config, requests)**
# - **Audio file size limit : 10M bytes** => 10M 이상의 파일을 처리하기 위해 wave file을 10M 이하 크기로 잘라서 변환하도록 개선

# %%
import pyaudio
import wave
import os
import io
import csv

import numpy as np

from nltk.tokenize import sent_tokenize, word_tokenize

# for speaker_diarization (use speech_v1p1beta1)
from google.cloud import speech_v1p1beta1 as speech
from google.cloud.speech_v1p1beta1 import enums
from google.cloud.speech_v1p1beta1 import types

# %%
def transcribe_streaming(stream_file):
    """Streams transcription of the given audio file."""
    words_with_tag = []
    transcripts = []

    client = speech.SpeechClient()

    with io.open(stream_file, 'rb') as audio_file:
        content = audio_file.read()

    # In practice, stream should be a generator yielding chunks of audio data.
    stream = [content]

    requests = (types.StreamingRecognizeRequest(audio_content=chunk)
                for chunk in stream)

    config = types.RecognitionConfig(
        encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
        sample_rate_hertz=16000,
        language_code='ko-KR',
        enable_automatic_punctuation=True,
        enable_word_time_offsets=True,
        enable_speaker_diarization=True,    # 한국어 지원 안됨 (speaker_tag가 모두 동일인으로 분류됨)
        diarization_speaker_count=3)

    streaming_config = types.StreamingRecognitionConfig(config=config)
    
    # streaming_recognize returns a generator.
    responses = client.streaming_recognize(streaming_config, requests)
    
    for response in responses:
        for result in response.results:
            alternatives = result.alternatives
            for alternative in alternatives:
                print(u'Transcript: {}'.format(alternative.transcript))
                transcripts.append(alternative.transcript)    # punctuation 포함된 문장을 사용하기 위해 저장
                for words in alternative.words:
                    word = words.word
                    start_time = round(words.start_time.seconds + words.start_time.nanos * 1e-9, 3)
                    end_time = round(words.end_time.seconds + words.end_time.nanos * 1e-9, 3)
                    speaker_tag = words.speaker_tag
                    words_with_tag.append([word, start_time, end_time, speaker_tag])    # [word, start_time, end_time, speaker_tag]
        print()
    return words_with_tag, transcripts

# %%
def write_wave_frames(frames):
        wave_stream = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
        wave_stream.setnchannels(CHANNELS)
        wave_stream.setsampwidth(FORMAT)
        wave_stream.setframerate(RATE)
        wave_stream.writeframes(b''.join(frames))
        wave_stream.close()

# %%
# instantiate PyAudio
audio = pyaudio.PyAudio()

# %%
# open wave file
FILE_NAME = "경제청문회_4명인터뷰_YTN_16000"
wf = wave.open("audio_file/"+ FILE_NAME + ".wav", 'rb')

# %%
# initialize variables
CHUNK = 1024   # 1024 bytes of data read from the buffer
FRAME_SIZE = CHUNK * 4
WAVE_OUTPUT_FILENAME = "wave_output.wav"    # temperary wave file for streaming 
FORMAT=audio.get_sample_size(wf.getsampwidth())
CHANNELS=wf.getnchannels()
RATE=wf.getframerate()
words_with_tags = []
transcripts_arr = []
frames = []
f_count = 0

# %%
# read data (first frames)
data = wf.readframes(CHUNK)

# transcribe stream  : wave file을 10M 이하로 잘라서, google STT API에 stream 방식으로 요청
while len(data) > 0:
    frames.append(data)
    f_count += 1
    if f_count == FRAME_SIZE:
        # write frames to wave file for frames
        write_wave_frames(frames)
        
        # transcribe by streaming
        words_with_tag, transcripts = transcribe_streaming(WAVE_OUTPUT_FILENAME)    # frames를 직접 전달 시 google에서 grpc.RpcError 발생하면 cancel 됨 
        words_with_tags.append(words_with_tag)
        transcripts_arr.append(transcripts)
        
        # frame initialize
        frames = []
        f_count = 0
    
    # read data (continue)
    data = wf.readframes(CHUNK)

# transcribe for last frames
write_wave_frames(frames)

# last frames
words_with_tag, transcripts = transcribe_streaming(WAVE_OUTPUT_FILENAME)
words_with_tags.append(words_with_tag)
transcripts_arr.append(transcripts)
# Out:
# Transcript: 한국 땅이 내 건 경제 청문회 여야 각 정당의 반응이 엇갈립니다. 민주당과 바른미래당 정의당은 한국 땅이 업체를 부린다는 입장인 반면에 한국당과 민주평화당 민주당이 청문회를 받아야 한다고 압박합니다.
#
# Transcript:  여론은 반대가 55%로 찬성 31%를 크게 앞지른 것으로 조사됐습니다. 반대 여론이 높은 경제청 문제를 내 건 한국 땅이 문제가 앞으로 정당 지지도 그러면 어떤 영향을 미칠지 궁금합니다. 숫자이동지도 열어. 내서 YTN 더 뉴스가의 실시한 여론조사 결과 분석하겠습니다. 이택수 리얼미터 대표 박지영 윈지코리아컨설팅 부대표 타기 하셨습니다 하십니까? 안녕하세요. 안녕하세요. 경제 청문회 관련한 조사결과부터 다시 한번 정리를 하고 얘기를 이어가겠습니다. 함께 보시죠. 다 한국 땅이 요구한 경찰청 운세 응답자의 55.4%가 반대하는 것으로 나타났습니다. 찬성은 30.9% 였고요. 모른다거나 응답하지않음. 비율은 13.7% 뛰었습니다. 응답자를 지지정당 별로 나눠서 살펴보겠습니다. 민주당 짐승의 결제 또 가도 높았습니다. 응답자중 민주당 지지표의 85.9
#
# Transcript:  퍼센트는 반대했고 한국땅을 지지하는 응답자는 68.2%가 찬성하는 것으로 나타났습니다. 정치 성향 별로 나눠서 조사한 결과에서도 진보측의 반대 여론이 보수층의 찬성 여름보다 경고했습니다. 봉투 측에서의 반대 여론이 35.8%로 경제 청문회를 정치공세로 보내 시각도 포스팅에서도 적지 않아 중고책 전체 여론 부도와 비슷했습니다. 정치 성향 결론은 중도층이 전체 여론과 비슷해 따면 지역별로 나는 수도권과 충청권을 그랬습니다. 결과를 좀 봤습니다. 찬송 30.9% 돼. 반대 55.4% 대표님, 한국 땅에 이런 여러 오늘 예상 했을까요? 예상하지 못했을 것 같습니다. 일단 뭐 큰 틀에서의 결과는 55.4 돼. 30.9 예상가 크게 다르지 않은 듯 세부적으로 보면 이런 감정 보수층 일하는 중이라
#
# Transcript:  건지 아니면 한국당 지지율 제외하고는 대부분의 계층에서 지금 반대하는 의견이 높게 나타난다. 민요. 그것은 제 2항에서 내세운 명분은 이게 진정성 있는 야, 그동안에 국회정상화 라든지 규정에 따른 무노동 무임금 국민소환제 여론이 굉장히 안 좋아 썼거든요. 그렇기 때문에 결국에는이 수조차도 부케를 지금 정사 하는데 우리도 이제 그 반대일 요소로 작용할 키 규현 어떤 실띄우기 아니야? 이렇게 본 계층들이 많았던 거 같아요. 그래서 엉덩이 예상치 못한 세부적인 그런 결혼 응. 답들이 나온 거 같습니다. 항상 입장에서는 다른 것보다 보수층 내에서 35.8% 나 반대를 하고 있는이 부분이 좀 아팠을 것 같습니다. 2층에서 홍이 뜨겁지 않다. 평가할 수 있을 것 같은데 지금 국기에 공전 사태가 벌써 두 달이 너무 같지 않습니까?
#
# Transcript:  비판 여론이 경제 따갑습니다. 한국당 쪽에 초점이 좀 써 가지고 있거든요. 비판 여론이 그러다 보니까 이걸 처음부터 너를 좀 국회정상화 조건으로이 문제를 경제 청문회를 내 걸었으면 한국 땅이 진정성이란 며느리 평가 해 줄 수도 있겠지만 그렇지 않았거든요. 처음에는 패스트 트랙이 대한 어떤 철야? 사과 이런 거에 집중 되다가 갑자기 인제 협상이 잘 안 되니까 거기에 이제 더 얹혀서 이경제 청문회까지 들고 나왔거든. 그러다 보니까 이게 진정성이 있기보다는 시간 끌기 용 지연전술의 일환으로 정치공세에 일환으로이 문제를 들고 나온게 아닌가 그렇게 받아들이는 거야. 그러면 계속 그의 주장을 이어가면서 여러 지역에서 나빠지지 않겠습니까? 저는 만약에 오늘 이제 그 바른미래당 의원 총회 다 하고 민주당도 현충일 하는데 여야 사당이 협의를 해서 저녁에 쿠키 문을 연다. 한국 돈 반대한다 많으니 국면이 지속되면 지속될수록
#
# Transcript:  좀 더 고립되고 국민들의 평가는 더 냉담해 질거다. 저는 그 한국
#
# Transcript: 불리할 것이다. 이렇게 보여짐. 예. 이런 상황에서 여권이 양보할 가능성은 어느정도 있다고 여론 자체가 한국당 좀 불량한 형태로 나타나고 있기 때문에 이른바 개문발차라고 한국당 하는데 배제하고 다른 정성 들이는데 국회를 여는 것에 대해서 좀 자신감을 가질 수 있는 결과들이 나오고 있는 거 같습니다. 순천에서는 좀 불리한 그런 식으로 그동안 국회 공전이 장기와 대화하고 아직도 결론이 안 나왔습니다. 이런 상황 속에서 정당 지지도 어떻게 나타났는지 확인해 보겠습니다네. 6월 2주차 정당 지지도를 보면 더불어민주당이 0.5% 포인트 전주보다 장성에서 41퍼센트를 나타냈고 자유한국당 도수코 올랐습니다. 31% 2 정당간 지지율 격차는 10% 포인트 차이를 유지했습니다. 정의당과 바른미래당
#
# Transcript: 변화가 있었습니다. 그리고 민주평화당도 비슷한 수준을 주시고요. 대우당 층이 소폭 줄어든 것이 눈에 들어옵니다. 차 한국 땅이 오히려 올랐습니다. 왜 그런 거지요? 이거는 뭐 일주일 간격으로 보기보다는데 좀 거시적으로 볼 필요가 있는데 저는 이제 그 장외투쟁 측정과 지금 한 두 달 동안 여론의 쥐가 어떻게 변했는지 그 점을 좀 살펴 볼 필요가 있다고 그런데 이게 그 가장 그 점을 찍을 때가 34% 정도 찍었고요. 민주당이나 전태관 37% 수준까지 떨어졌을 16조 당시 4% 포인트 격자까지 주 삐지면 적이 있었거든요. 그래프의 나오네요. 그렇습니다. 38.7 돼. 34.3 4.4% 포인트까지 좁혀져 쓰는데 이게 지금 격차가 10일 10% 포인트 차로 다신 벌어졌고 든요. 결국은 장애 등급 길어지면서 한국 땅으로 향했던 관심이 좀 뚝 떨어졌다.
#
# Transcript: 계속 중도층에서 비디오 감도가 높아지면서 황교안 말씀하셨던 중원 전략 이른바 중도층을 잡겠다이 전략에 지금 잘 통하지 않는 그런 상황이 아닌가 싶습니다. 많이 단독 국회가 열릴 경우에 영어로는 어떻게 움직일까? 요거 말씀드렸듯이 한국 땅이 고립되면 집도 피는 이미 많이 결집되어 있거든요. 30% 안방으로 보승이 집토끼 막시 결집되어 있는데 중도층 외면하기 시작하면요. 한국 땅이 약 지지층은 동요 하게 되어 있습니다. 어, 이러다가 집권하기 어렵게 되겠는데라는 의구심이 형성될 수 있거든. 그렇기 때문에 지금은 황교안 대표께서 통큰 결단을 좀 해야 시점이 아닌가? 여론조사기관 이걸로 보며는 한국 땅이지 지도가 리얼미터 30% 30% 만 밖으로 그리고 다른데 보면은 20% 초반대로 나오게 하지. 크게 보면 1% 포인트 차이가 나는데네, 그게.
#
# Transcript: 승희 리얼미터 주사 방식으로 많이 드러나기 때문에 들어 있지만 지금 바쁘지. 편히 말씀대로 한국 땅이 흔들리고 중도층의 지지를 받지 못하면 20% 포인트 정도가 훅하고 움직이고 있다는 거죠? 이제 지난 주간 일주일 1일 날 이런데 보게 되면은 이제 주 초중반까지는 김원봉 서운 놀란 이라던지 또 민경욱 대변인 전력질주 막말 논란 있었습니다. 그때까지는 사실을 오히려 자신의 지층 좌측 토끼는 결집하는 장락탄 했었는데 중후반에 인제 기억하겠습니다. 많이 환영위원회 인제 그다음에 홍문종 의원 이인제 팔당 식사하면서 대한애국당 공동대표로 언제 간다는 소식이 전에 줬죠. 분열하고 산토끼를 떠나가는 한국이 지금 될 가능성이 있기 때문에 이번 주 아까는 좀 늦었습니다. 바른미래당 제주를 또 올라왔거든요. 한국 땅이 외환 답장을 못 하면 학교 바른미래당 올 가능성이 충분히 있기 때문에 한국 땅으로 쓰는 줘.
#
# Transcript: 어, 지금 상황이 오전 기회 요인보다는 위 기운이 좀 더 큰 상황이 아닌가 싶습니다. 지금 단독 단독이란 표현은 그렇습니다. 한국당을 배제한 여야 사당이 국회를 여는 그런 상황이 한국 땅에 정도 분리할 거라고 하셨잖아요. 혹시 구입을 어서 한국 땅이 반사이익이 받을 가능성은 전혀 없을까요? 이게 지금.
#
# Transcript: 누가 보더라도 기다릴만큼 기다려. 인형 보이거든요. 이게 만약에 장외투쟁 후에 맡길 이런 사당이 국회 단독 국회 빼고 이렇게 문을 연다면 용품이 있을 가능성도 있지만 버스 언제 두 다리 넘고 넘어가 때문에 국민들이 볼 때는 빨리 문을 열어라. 상임이 부터라도 빨리 시작해라. 이러는 어떤 요가 크기 때문에 저는 역풍 입을 가능성이 크지 않다. 이렇게 분만 열고 사실상 파행이 이어진다면 아마추 경희대 아빠에게 국민적 아빠에게 더욱 거세질 겁니다. 문을 열었는데 일을 안 한다. 용 답하겠습니다. 국민은 국민들이 지금은 시간이 한 편이 아니다. 이것을 빨리 그 깨닫는게 중요하다 알겠습니다. 얼굴에는 대통령 국정 수행에 대한 평가도 확인해 보세요.
#
# Transcript: 메뉴얼 두 번째 주 문재인 대통령 국정 수행 평가 긍정 평가가 전주보다 1.5% 포인트 장성에서 49.5% 절반수준에 육박했습니다. 그리고 부장 평가는 또 소폭 하락 했습니다. 45.3%로 금 구정 격차가 4.1% 포인트네요이 대표님, 이번 조사 오차범위가 플러스 마이너스 3% 4% 5% 그렇습니다. 최근 들어서는 오차범위를 경계선은 겁나 지르고 게다가 이번 주는 긍정평가 이제 많이 앞쪽이 착했는데 유럽 순방 효과가 있었습니다. 근데 그 다음에 이희호 여사 관제 사회자 지웠는데 북한에선 제주 뭐 좋은 거 좋아가 전달이 됐죠. 문재인 대통령이 6월중에 남북정사회담 가능성도 관련된 보도관제 오졌구요. 그러면서 문재인 대통령 높아졌는데 좀
#
# Transcript: 그 세분화해서 보면 5월 첫째 주부터 매우 잘 한다라는 의견이 잘한다는 잘하는 편보다 높아졌습니다지나 5월초부터 그렇게 됐는데요. 이게 이제 국회단지 폭력사태로 인원 파악 그다음에 한국당 의원들 막말 이어지면서 어떻게 보는지에 문재인 대통령 정통성에 11번은 촛불을 들었던 그 계층들이 다시 결집하는 모습 그동안은 굉장히 오랫동안 잘 하는 편이에요 봤습니다. 구정 평가는 매우 잘 못 한다는 의견이 높아서 그래. 근데 그 같은 48% 9%지만 매우 잘 한다는 것이 승이 아주 결집하고 있다. 이런 경향성이 발견이 되면서 오차범위를 없는 근접효과 나타난 것은 저는 이번에 그 격벽과 소폭이지만 올 뉴 중에 가장 큰 이유를 순방 유교 선거로 봅니다. 왜냐하면 민경욱 대변인 한국당대변인 질이라는 발원했습니다. 온라인 좀 됐습니다.
#
# Transcript: 1분 이제 신문에서 또 비판론 떠났습니다. 일하다 보니까 국민들이 그 대통령 순방에 대해서 좀 깊이 들여다보는 계기가 되었던 것은 과연 어떻게 하고 있지라고 관심을 귤 했는데 오슬로 사는 오늘 하면서 평화를 도광제 했고요. 거기에 머물지 않고 스타트업에 대한 생태계를 광주 한다든가 부산 헬싱키 직항노선 그다음에 이제 그 제약사의 투자를 유치하고 이런 경제정보를 같이 하셨거든요. 이런 것들이 국민들 눈에 신선하게 보였다. 하나 있고요. 그리고 u-20 월드컵 우리 그 어린 우리 축구 대표 축구 대표팀의 선전 이것도 또 영향을 미쳤고요. 국회 가진 마비 중이지만 나름대로 정부하고 그당이 일을 하고 있다. 당정협의를 통해서 뭔가 일을 하고 있다니 이미지를 좀 준 측면도 있습니다. 이제 구미와 밀양에 상생형 일자리 강조 했고요. 2장 통장 그대 그리고 군사병들을 월급 급여 이런 것들이 좀 인상하면서 뭔가 국회
#
# Transcript: 꽉 막혀 있지만 정부 여당이 좀 일을 하고 있구나. 일하는 어떤 성당 이미지 일하는 세력 이미지를 좀 준게 아닌가 그런 사람이 강기정 정무수석과 북경 정무비서관 바로 온 거 관련해서는 여론이 어떤 평가를 내렸다. 옷이 그게 그 영향을 미치지 않은 거 같아. 왜냐면 이게 국회 청원에 대한 답변 성격이 하나 있었잖아. 그냥 글씨 나오는 것은 아니거든. 교통이 올라가고 나 보니까 정호 수학 오정무 그
#
# Transcript: 아니, 답변할 수 밖에 없었고 답변했고 두 번째는 나경원 원내대표의 발언이 좀 무슨 됐다는 측면 있으면 첫 번째는 청와대에 끼지마라 빠져라. 뒤로 이런 얘기를 했다가 어느덧 본인한테 연락이 없다. 전화 한 통 없다. 이런 얘기를 했는데 청와대가 해명한 걸 보면 원내수석부대표 같아. 연락을 했다. 정양석 그리고 이현승 그 당대표 비서실장 한테도 수시로 이야기했다. 이런 얘기들이 나오고 나왔기 때문에 그 내부에 소통이 문제가 아니야. 한국당 내부의 일어났던 반박도 충분히 가능 했거든요. 예, 다 보니까 어떤 청와대에서 이런 민감한 바른 한 것이 그 다 결혼의 불리하게 작동 한 것 같진 않습니다. 보는 것이 강기정 추석에 대한 바로는 선관위에서 내 문제가 없다고 이제 해명을 행적이 됐고 두 번째 국민소환제 여론조사에서 이제 70% 이상이 소환 해야 된다는 찬성의견이 높았기 때문에이 두산은 당첨의 유리하게 작용했다고 밝혔다.
#
# Transcript: 강기정 정무수석은 정당해산청구 와. 관련해서 선거에서 4 4 * 5 유권자가 판단을 몫이라고 했고 국민소환제에 대한 국민 청원에 대한 답변을 복귀한 비서관이 국회에서 이탈리안 와야 된다. 이게 통과 돼야 된다는 그런 얘기를 줘. 이번 주에는 정치권 대통령의 국정 수행 평가 그다음에 어떤 부분이 가장 영향을 미칠까요? 첫 번째로 윤성열 경찰청장 후보자 이기용 하지 않았습니까이 부분이 여론의 가장 크게 영향을 미칠 것 같아. 어느 방향으로 긍정적으로 검찰개혁이 다둥이 조교가 높고 2분 이제 칼잡이로 유명 하지 않습니까? 권력형비리 문제에 대해서 단호하게 대처 있기 때문에 대통령의 어떤 검찰개혁의지 이런 것들이 국민들이 눈여겨 볼거다. 이렇게 생각이 들고요. 두 번째는 8개 정상화 관련해서 자연 관찰 할 거냐? 이게 세 번째는 그 제조업르네상스 이와 관련해서 규제혁파
#
# Transcript: 분들은 수요일 날 발표 할 것 같은데요. 정도에서 이게 영향을 미칠지. 또 언제 정적인 것은 인천지역에서 계속 지금 불금 수돗물이나 오고 있구만. 28일 지나고 있습니다. 장기화되고 있는데 얘는 여름이 안 좋습니다. 이래서 이것이 수도권 그게 미칠지. 이런 것도 대표적 간단하게 윤석열 검찰총장 20명이 지금 바쁘다. 대표님처럼네. 긍정적인 여름을 만들어냈지. 영향을 미칠 것 같은데요. 선생님. 권경수 학원이 갈등을 빚고 있지만 경찰 보다는 검찰에 대한 불신이 여론조사 해 보면 그 그 동안의 나타났던 좀 벌금 검찰 부서 회식 없기 때문에 거기에 대한게. 여기 요거는 높은편입니다. 그래서 그런 부분을 알고 있었기 때문에 일부 또 이명에 좋은 영향을 미친 것이 아닌가 싶습니다. 알겠습니다. 그럼 벌써 여기까지 쓰겠습니다. 고맙습니다.

# %%
# close PyAudio
audio.terminate()

# %%
corpus = ""
for transcripts in transcripts_arr:
    for transcript in transcripts:
        corpus += transcript + " "
# print(corpus)

# %%
sentence = sent_tokenize(corpus)    # 문장단위 분리
sentence
# Out:
# ['한국 땅이 내 건 경제 청문회 여야 각 정당의 반응이 엇갈립니다.',
#  '민주당과 바른미래당 정의당은 한국 땅이 업체를 부린다는 입장인 반면에 한국당과 민주평화당 민주당이 청문회를 받아야 한다고 압박합니다.',
#  '여론은 반대가 55%로 찬성 31%를 크게 앞지른 것으로 조사됐습니다.',
#  '반대 여론이 높은 경제청 문제를 내 건 한국 땅이 문제가 앞으로 정당 지지도 그러면 어떤 영향을 미칠지 궁금합니다.',
#  '숫자이동지도 열어.',
#  '내서 YTN 더 뉴스가의 실시한 여론조사 결과 분석하겠습니다.',
#  '이택수 리얼미터 대표 박지영 윈지코리아컨설팅 부대표 타기 하셨습니다 하십니까?',
#  '안녕하세요.',
#  '안녕하세요.',
#  '경제 청문회 관련한 조사결과부터 다시 한번 정리를 하고 얘기를 이어가겠습니다.',
#  '함께 보시죠.',
#  '다 한국 땅이 요구한 경찰청 운세 응답자의 55.4%가 반대하는 것으로 나타났습니다.',
#  '찬성은 30.9% 였고요.',
#  '모른다거나 응답하지않음.',
#  '비율은 13.7% 뛰었습니다.',
#  '응답자를 지지정당 별로 나눠서 살펴보겠습니다.',
#  '민주당 짐승의 결제 또 가도 높았습니다.',
#  '응답자중 민주당 지지표의 85.9  퍼센트는 반대했고 한국땅을 지지하는 응답자는 68.2%가 찬성하는 것으로 나타났습니다.',
#  '정치 성향 별로 나눠서 조사한 결과에서도 진보측의 반대 여론이 보수층의 찬성 여름보다 경고했습니다.',
#  '봉투 측에서의 반대 여론이 35.8%로 경제 청문회를 정치공세로 보내 시각도 포스팅에서도 적지 않아 중고책 전체 여론 부도와 비슷했습니다.',
#  '정치 성향 결론은 중도층이 전체 여론과 비슷해 따면 지역별로 나는 수도권과 충청권을 그랬습니다.',
#  '결과를 좀 봤습니다.',
#  '찬송 30.9% 돼.',
#  '반대 55.4% 대표님, 한국 땅에 이런 여러 오늘 예상 했을까요?',
#  '예상하지 못했을 것 같습니다.',
#  '일단 뭐 큰 틀에서의 결과는 55.4 돼.',
#  '30.9 예상가 크게 다르지 않은 듯 세부적으로 보면 이런 감정 보수층 일하는 중이라  건지 아니면 한국당 지지율 제외하고는 대부분의 계층에서 지금 반대하는 의견이 높게 나타난다.',
#  '민요.',
#  '그것은 제 2항에서 내세운 명분은 이게 진정성 있는 야, 그동안에 국회정상화 라든지 규정에 따른 무노동 무임금 국민소환제 여론이 굉장히 안 좋아 썼거든요.',
#  '그렇기 때문에 결국에는이 수조차도 부케를 지금 정사 하는데 우리도 이제 그 반대일 요소로 작용할 키 규현 어떤 실띄우기 아니야?',
#  '이렇게 본 계층들이 많았던 거 같아요.',
#  '그래서 엉덩이 예상치 못한 세부적인 그런 결혼 응.',
#  '답들이 나온 거 같습니다.',
#  '항상 입장에서는 다른 것보다 보수층 내에서 35.8% 나 반대를 하고 있는이 부분이 좀 아팠을 것 같습니다.',
#  '2층에서 홍이 뜨겁지 않다.',
#  '평가할 수 있을 것 같은데 지금 국기에 공전 사태가 벌써 두 달이 너무 같지 않습니까?',
#  '비판 여론이 경제 따갑습니다.',
#  '한국당 쪽에 초점이 좀 써 가지고 있거든요.',
#  '비판 여론이 그러다 보니까 이걸 처음부터 너를 좀 국회정상화 조건으로이 문제를 경제 청문회를 내 걸었으면 한국 땅이 진정성이란 며느리 평가 해 줄 수도 있겠지만 그렇지 않았거든요.',
#  '처음에는 패스트 트랙이 대한 어떤 철야?',
#  '사과 이런 거에 집중 되다가 갑자기 인제 협상이 잘 안 되니까 거기에 이제 더 얹혀서 이경제 청문회까지 들고 나왔거든.',
#  '그러다 보니까 이게 진정성이 있기보다는 시간 끌기 용 지연전술의 일환으로 정치공세에 일환으로이 문제를 들고 나온게 아닌가 그렇게 받아들이는 거야.',
#  '그러면 계속 그의 주장을 이어가면서 여러 지역에서 나빠지지 않겠습니까?',
#  '저는 만약에 오늘 이제 그 바른미래당 의원 총회 다 하고 민주당도 현충일 하는데 여야 사당이 협의를 해서 저녁에 쿠키 문을 연다.',
#  '한국 돈 반대한다 많으니 국면이 지속되면 지속될수록  좀 더 고립되고 국민들의 평가는 더 냉담해 질거다.',
#  '저는 그 한국 불리할 것이다.',
#  '이렇게 보여짐.',
#  '예.',
#  '이런 상황에서 여권이 양보할 가능성은 어느정도 있다고 여론 자체가 한국당 좀 불량한 형태로 나타나고 있기 때문에 이른바 개문발차라고 한국당 하는데 배제하고 다른 정성 들이는데 국회를 여는 것에 대해서 좀 자신감을 가질 수 있는 결과들이 나오고 있는 거 같습니다.',
#  '순천에서는 좀 불리한 그런 식으로 그동안 국회 공전이 장기와 대화하고 아직도 결론이 안 나왔습니다.',
#  '이런 상황 속에서 정당 지지도 어떻게 나타났는지 확인해 보겠습니다네.',
#  '6월 2주차 정당 지지도를 보면 더불어민주당이 0.5% 포인트 전주보다 장성에서 41퍼센트를 나타냈고 자유한국당 도수코 올랐습니다.',
#  '31% 2 정당간 지지율 격차는 10% 포인트 차이를 유지했습니다.',
#  '정의당과 바른미래당 변화가 있었습니다.',
#  '그리고 민주평화당도 비슷한 수준을 주시고요.',
#  '대우당 층이 소폭 줄어든 것이 눈에 들어옵니다.',
#  '차 한국 땅이 오히려 올랐습니다.',
#  '왜 그런 거지요?',
#  '이거는 뭐 일주일 간격으로 보기보다는데 좀 거시적으로 볼 필요가 있는데 저는 이제 그 장외투쟁 측정과 지금 한 두 달 동안 여론의 쥐가 어떻게 변했는지 그 점을 좀 살펴 볼 필요가 있다고 그런데 이게 그 가장 그 점을 찍을 때가 34% 정도 찍었고요.',
#  '민주당이나 전태관 37% 수준까지 떨어졌을 16조 당시 4% 포인트 격자까지 주 삐지면 적이 있었거든요.',
#  '그래프의 나오네요.',
#  '그렇습니다.',
#  '38.7 돼.',
#  '34.3 4.4% 포인트까지 좁혀져 쓰는데 이게 지금 격차가 10일 10% 포인트 차로 다신 벌어졌고 든요.',
#  '결국은 장애 등급 길어지면서 한국 땅으로 향했던 관심이 좀 뚝 떨어졌다.',
#  '계속 중도층에서 비디오 감도가 높아지면서 황교안 말씀하셨던 중원 전략 이른바 중도층을 잡겠다이 전략에 지금 잘 통하지 않는 그런 상황이 아닌가 싶습니다.',
#  '많이 단독 국회가 열릴 경우에 영어로는 어떻게 움직일까?',
#  '요거 말씀드렸듯이 한국 땅이 고립되면 집도 피는 이미 많이 결집되어 있거든요.',
#  '30% 안방으로 보승이 집토끼 막시 결집되어 있는데 중도층 외면하기 시작하면요.',
#  '한국 땅이 약 지지층은 동요 하게 되어 있습니다.',
#  '어, 이러다가 집권하기 어렵게 되겠는데라는 의구심이 형성될 수 있거든.',
#  '그렇기 때문에 지금은 황교안 대표께서 통큰 결단을 좀 해야 시점이 아닌가?',
#  '여론조사기관 이걸로 보며는 한국 땅이지 지도가 리얼미터 30% 30% 만 밖으로 그리고 다른데 보면은 20% 초반대로 나오게 하지.',
#  '크게 보면 1% 포인트 차이가 나는데네, 그게.',
#  '승희 리얼미터 주사 방식으로 많이 드러나기 때문에 들어 있지만 지금 바쁘지.',
#  '편히 말씀대로 한국 땅이 흔들리고 중도층의 지지를 받지 못하면 20% 포인트 정도가 훅하고 움직이고 있다는 거죠?',
#  '이제 지난 주간 일주일 1일 날 이런데 보게 되면은 이제 주 초중반까지는 김원봉 서운 놀란 이라던지 또 민경욱 대변인 전력질주 막말 논란 있었습니다.',
#  '그때까지는 사실을 오히려 자신의 지층 좌측 토끼는 결집하는 장락탄 했었는데 중후반에 인제 기억하겠습니다.',
#  '많이 환영위원회 인제 그다음에 홍문종 의원 이인제 팔당 식사하면서 대한애국당 공동대표로 언제 간다는 소식이 전에 줬죠.',
#  '분열하고 산토끼를 떠나가는 한국이 지금 될 가능성이 있기 때문에 이번 주 아까는 좀 늦었습니다.',
#  '바른미래당 제주를 또 올라왔거든요.',
#  '한국 땅이 외환 답장을 못 하면 학교 바른미래당 올 가능성이 충분히 있기 때문에 한국 땅으로 쓰는 줘.',
#  '어, 지금 상황이 오전 기회 요인보다는 위 기운이 좀 더 큰 상황이 아닌가 싶습니다.',
#  '지금 단독 단독이란 표현은 그렇습니다.',
#  '한국당을 배제한 여야 사당이 국회를 여는 그런 상황이 한국 땅에 정도 분리할 거라고 하셨잖아요.',
#  '혹시 구입을 어서 한국 땅이 반사이익이 받을 가능성은 전혀 없을까요?',
#  '이게 지금.',
#  '누가 보더라도 기다릴만큼 기다려.',
#  '인형 보이거든요.',
#  '이게 만약에 장외투쟁 후에 맡길 이런 사당이 국회 단독 국회 빼고 이렇게 문을 연다면 용품이 있을 가능성도 있지만 버스 언제 두 다리 넘고 넘어가 때문에 국민들이 볼 때는 빨리 문을 열어라.',
#  '상임이 부터라도 빨리 시작해라.',
#  '이러는 어떤 요가 크기 때문에 저는 역풍 입을 가능성이 크지 않다.',
#  '이렇게 분만 열고 사실상 파행이 이어진다면 아마추 경희대 아빠에게 국민적 아빠에게 더욱 거세질 겁니다.',
#  '문을 열었는데 일을 안 한다.',
#  '용 답하겠습니다.',
#  '국민은 국민들이 지금은 시간이 한 편이 아니다.',
#  '이것을 빨리 그 깨닫는게 중요하다 알겠습니다.',
#  '얼굴에는 대통령 국정 수행에 대한 평가도 확인해 보세요.',
#  '메뉴얼 두 번째 주 문재인 대통령 국정 수행 평가 긍정 평가가 전주보다 1.5% 포인트 장성에서 49.5% 절반수준에 육박했습니다.',
#  '그리고 부장 평가는 또 소폭 하락 했습니다.',
#  '45.3%로 금 구정 격차가 4.1% 포인트네요이 대표님, 이번 조사 오차범위가 플러스 마이너스 3% 4% 5% 그렇습니다.',
#  '최근 들어서는 오차범위를 경계선은 겁나 지르고 게다가 이번 주는 긍정평가 이제 많이 앞쪽이 착했는데 유럽 순방 효과가 있었습니다.',
#  '근데 그 다음에 이희호 여사 관제 사회자 지웠는데 북한에선 제주 뭐 좋은 거 좋아가 전달이 됐죠.',
#  '문재인 대통령이 6월중에 남북정사회담 가능성도 관련된 보도관제 오졌구요.',
#  '그러면서 문재인 대통령 높아졌는데 좀 그 세분화해서 보면 5월 첫째 주부터 매우 잘 한다라는 의견이 잘한다는 잘하는 편보다 높아졌습니다지나 5월초부터 그렇게 됐는데요.',
#  '이게 이제 국회단지 폭력사태로 인원 파악 그다음에 한국당 의원들 막말 이어지면서 어떻게 보는지에 문재인 대통령 정통성에 11번은 촛불을 들었던 그 계층들이 다시 결집하는 모습 그동안은 굉장히 오랫동안 잘 하는 편이에요 봤습니다.',
#  '구정 평가는 매우 잘 못 한다는 의견이 높아서 그래.',
#  '근데 그 같은 48% 9%지만 매우 잘 한다는 것이 승이 아주 결집하고 있다.',
#  '이런 경향성이 발견이 되면서 오차범위를 없는 근접효과 나타난 것은 저는 이번에 그 격벽과 소폭이지만 올 뉴 중에 가장 큰 이유를 순방 유교 선거로 봅니다.',
#  '왜냐하면 민경욱 대변인 한국당대변인 질이라는 발원했습니다.',
#  '온라인 좀 됐습니다.',
#  '1분 이제 신문에서 또 비판론 떠났습니다.',
#  '일하다 보니까 국민들이 그 대통령 순방에 대해서 좀 깊이 들여다보는 계기가 되었던 것은 과연 어떻게 하고 있지라고 관심을 귤 했는데 오슬로 사는 오늘 하면서 평화를 도광제 했고요.',
#  '거기에 머물지 않고 스타트업에 대한 생태계를 광주 한다든가 부산 헬싱키 직항노선 그다음에 이제 그 제약사의 투자를 유치하고 이런 경제정보를 같이 하셨거든요.',
#  '이런 것들이 국민들 눈에 신선하게 보였다.',
#  '하나 있고요.',
#  '그리고 u-20 월드컵 우리 그 어린 우리 축구 대표 축구 대표팀의 선전 이것도 또 영향을 미쳤고요.',
#  '국회 가진 마비 중이지만 나름대로 정부하고 그당이 일을 하고 있다.',
#  '당정협의를 통해서 뭔가 일을 하고 있다니 이미지를 좀 준 측면도 있습니다.',
#  '이제 구미와 밀양에 상생형 일자리 강조 했고요.',
#  '2장 통장 그대 그리고 군사병들을 월급 급여 이런 것들이 좀 인상하면서 뭔가 국회 꽉 막혀 있지만 정부 여당이 좀 일을 하고 있구나.',
#  '일하는 어떤 성당 이미지 일하는 세력 이미지를 좀 준게 아닌가 그런 사람이 강기정 정무수석과 북경 정무비서관 바로 온 거 관련해서는 여론이 어떤 평가를 내렸다.',
#  '옷이 그게 그 영향을 미치지 않은 거 같아.',
#  '왜냐면 이게 국회 청원에 대한 답변 성격이 하나 있었잖아.',
#  '그냥 글씨 나오는 것은 아니거든.',
#  '교통이 올라가고 나 보니까 정호 수학 오정무 그 아니, 답변할 수 밖에 없었고 답변했고 두 번째는 나경원 원내대표의 발언이 좀 무슨 됐다는 측면 있으면 첫 번째는 청와대에 끼지마라 빠져라.',
#  '뒤로 이런 얘기를 했다가 어느덧 본인한테 연락이 없다.',
#  '전화 한 통 없다.',
#  '이런 얘기를 했는데 청와대가 해명한 걸 보면 원내수석부대표 같아.',
#  '연락을 했다.',
#  '정양석 그리고 이현승 그 당대표 비서실장 한테도 수시로 이야기했다.',
#  '이런 얘기들이 나오고 나왔기 때문에 그 내부에 소통이 문제가 아니야.',
#  '한국당 내부의 일어났던 반박도 충분히 가능 했거든요.',
#  '예, 다 보니까 어떤 청와대에서 이런 민감한 바른 한 것이 그 다 결혼의 불리하게 작동 한 것 같진 않습니다.',
#  '보는 것이 강기정 추석에 대한 바로는 선관위에서 내 문제가 없다고 이제 해명을 행적이 됐고 두 번째 국민소환제 여론조사에서 이제 70% 이상이 소환 해야 된다는 찬성의견이 높았기 때문에이 두산은 당첨의 유리하게 작용했다고 밝혔다.',
#  '강기정 정무수석은 정당해산청구 와.',
#  '관련해서 선거에서 4 4 * 5 유권자가 판단을 몫이라고 했고 국민소환제에 대한 국민 청원에 대한 답변을 복귀한 비서관이 국회에서 이탈리안 와야 된다.',
#  '이게 통과 돼야 된다는 그런 얘기를 줘.',
#  '이번 주에는 정치권 대통령의 국정 수행 평가 그다음에 어떤 부분이 가장 영향을 미칠까요?',
#  '첫 번째로 윤성열 경찰청장 후보자 이기용 하지 않았습니까이 부분이 여론의 가장 크게 영향을 미칠 것 같아.',
#  '어느 방향으로 긍정적으로 검찰개혁이 다둥이 조교가 높고 2분 이제 칼잡이로 유명 하지 않습니까?',
#  '권력형비리 문제에 대해서 단호하게 대처 있기 때문에 대통령의 어떤 검찰개혁의지 이런 것들이 국민들이 눈여겨 볼거다.',
#  '이렇게 생각이 들고요.',
#  '두 번째는 8개 정상화 관련해서 자연 관찰 할 거냐?',
#  '이게 세 번째는 그 제조업르네상스 이와 관련해서 규제혁파 분들은 수요일 날 발표 할 것 같은데요.',
#  '정도에서 이게 영향을 미칠지.',
#  '또 언제 정적인 것은 인천지역에서 계속 지금 불금 수돗물이나 오고 있구만.',
#  '28일 지나고 있습니다.',
#  '장기화되고 있는데 얘는 여름이 안 좋습니다.',
#  '이래서 이것이 수도권 그게 미칠지.',
#  '이런 것도 대표적 간단하게 윤석열 검찰총장 20명이 지금 바쁘다.',
#  '대표님처럼네.',
#  '긍정적인 여름을 만들어냈지.',
#  '영향을 미칠 것 같은데요.',
#  '선생님.',
#  '권경수 학원이 갈등을 빚고 있지만 경찰 보다는 검찰에 대한 불신이 여론조사 해 보면 그 그 동안의 나타났던 좀 벌금 검찰 부서 회식 없기 때문에 거기에 대한게.',
#  '여기 요거는 높은편입니다.',
#  '그래서 그런 부분을 알고 있었기 때문에 일부 또 이명에 좋은 영향을 미친 것이 아닌가 싶습니다.',
#  '알겠습니다.',
#  '그럼 벌써 여기까지 쓰겠습니다.',
#  '고맙습니다.']

# %%
# 스크립트 만 Text 파일로 저장 (with newline)
text_file = "text/" + FILE_NAME + ".txt"
with open(text_file, 'w', encoding='utf-8') as f:
    for sent in sentence:
        f.write(sent + "\n")

# %%
# print(words_with_tags)
words_array = [wt for wts in words_with_tags for wt in wts]
words_array
# Out:
# [['한국', 0.3, 0.9, 1],
#  ['땅이', 0.9, 1.2, 1],
#  ['내', 1.2, 1.3, 1],
#  ['건', 1.3, 1.6, 1],
#  ['경제', 1.6, 2.2, 1],
#  ['청문회', 2.2, 2.7, 1],
#  ['여야', 2.7, 3.3, 1],
#  ['각', 3.3, 3.5, 1],
#  ['정당의', 3.5, 4.0, 1],
#  ['반응이', 4.0, 4.4, 1],
#  ['엇갈립니다', 4.4, 4.8, 1],
#  ['민주당과', 4.8, 5.7, 1],
#  ['바른미래당', 5.7, 6.3, 1],
#  ['정의당은', 6.3, 7.0, 1],
#  ['한국', 7.0, 7.6, 1],
#  ['땅이', 7.6, 7.9, 1],
#  ['업체를', 7.9, 8.4, 1],
#  ['부린다는', 8.4, 8.8, 1],
#  ['입장인', 8.8, 9.2, 1],
#  ['반면', 9.2, 9.3, 1],
#  ['에', 9.3, 9.6, 1],
#  ['한국당과', 9.6, 10.9, 1],
#  ['민주평화당', 10.9, 11.7, 1],
#  ['민주당이', 11.7, 12.8, 1],
#  ['청문회를', 12.8, 13.5, 1],
#  ['받아야', 13.5, 14.2, 1],
#  ['한다고', 14.2, 14.5, 1],
#  ['압박합니다', 14.5, 15.1, 1],
#  ['한국', 0.3, 0.9, 1],
#  ['땅이', 0.9, 1.2, 1],
#  ['내', 1.2, 1.3, 1],
#  ['건', 1.3, 1.6, 1],
#  ['경제', 1.6, 2.2, 1],
#  ['청문회', 2.2, 2.7, 1],
#  ['여야', 2.7, 3.3, 1],
#  ['각', 3.3, 3.5, 1],
#  ['정당의', 3.5, 4.0, 1],
#  ['반응이', 4.0, 4.4, 1],
#  ['엇갈립니다', 4.4, 4.8, 1],
#  ['민주당과', 4.8, 5.7, 1],
#  ['바른미래당', 5.7, 6.3, 1],
#  ['정의당은', 6.3, 7.0, 1],
#  ['한국', 7.0, 7.6, 1],
#  ['땅이', 7.6, 7.9, 1],
#  ['업체를', 7.9, 8.4, 1],
#  ['부린다는', 8.4, 8.8, 1],
#  ['입장인', 8.8, 9.2, 1],
#  ['반면', 9.2, 9.3, 1],
#  ['에', 9.3, 9.6, 1],
#  ['한국당과', 9.6, 10.9, 1],
#  ['민주평화당', 10.9, 11.7, 1],
#  ['민주당이', 11.7, 12.8, 1],
#  ['청문회를', 12.8, 13.5, 1],
#  ['받아야', 13.5, 14.2, 1],
#  ['한다고', 14.2, 14.5, 1],
#  ['압박합니다', 14.5, 15.1, 1],
#  ['여론은', 16.7, 18.1, 1],
#  ['반대가', 18.1, 18.7, 1],
#  ['55%', 18.7, 19.4, 1],
#  ['로', 19.4, 19.8, 1],
#  ['찬성', 19.8, 20.3, 1],
#  ['31%', 20.3, 20.9, 1],
#  ['를', 20.9, 21.4, 1],
#  ['크게', 21.4, 21.8, 1],
#  ['앞지른', 21.8, 22.3, 1],
#  ['것으로', 22.3, 22.6, 1],
#  ['조사됐습니다', 22.6, 23.1, 1],
#  ['반대', 23.1, 24.0, 1],
#  ['여론이', 24.0, 24.3, 1],
#  ['높은', 24.3, 24.7, 1],
#  ['경제청', 24.7, 25.1, 1],
#  ['문제를', 25.1, 25.5, 1],
#  ['내', 25.5, 25.6, 1],
#  ['건', 25.6, 25.8, 1],
#  ['한국', 25.8, 26.2, 1],
#  ['땅이', 26.2, 26.6, 1],
#  ['문제가', 26.6, 26.8, 1],
#  ['앞으로', 26.8, 27.2, 1],
#  ['정당', 27.2, 27.7, 1],
#  ['지지도', 27.7, 27.9, 1],
#  ['그러면', 27.9, 28.5, 1],
#  ['어떤', 28.5, 28.9, 1],
#  ['영향을', 28.9, 29.3, 1],
#  ['미칠지', 29.3, 29.8, 1],
#  ['궁금합니다', 29.8, 30.6, 1],
#  ['숫자이동', 30.6, 31.6, 1],
#  ['지도', 31.6, 31.9, 1],
#  ['열어', 31.9, 32.2, 1],
#  ['내서', 32.2, 32.4, 1],
#  ['ytn', 32.4, 32.9, 1],
#  ['더', 32.9, 33.0, 1],
#  ['뉴스가', 33.0, 33.5, 1],
#  ['의', 33.5, 33.5, 1],
#  ['실시한', 33.5, 34.4, 1],
#  ['여론조사', 34.4, 35.0, 1],
#  ['결과', 35.0, 35.4, 1],
#  ['분석하겠습니다', 35.4, 36.0, 1],
#  ['이택수', 36.0, 37.0, 1],
#  ['리얼미터', 37.0, 37.4, 1],
#  ['대표', 37.4, 37.8, 1],
#  ['박지영', 37.8, 38.1, 1],
#  ['윈지코리아컨설팅', 38.1, 38.7, 1],
#  ['부대표', 38.7, 39.6, 1],
#  ['타기', 39.6, 39.8, 1],
#  ['하셨습니다', 39.8, 40.2, 1],
#  ['하십니까', 40.2, 41.1, 1],
#  ['안녕하세요', 41.1, 41.8, 1],
#  ['안녕하세요', 41.8, 42.5, 1],
#  ['경제', 42.5, 44.5, 1],
#  ['청문회', 44.5, 45.0, 1],
#  ['관련한', 45.0, 45.8, 1],
#  ['조사결과', 45.8, 46.7, 1],
#  ['부터', 46.7, 47.0, 1],
#  ['다시', 47.0, 47.2, 1],
#  ['한번', 47.2, 47.4, 1],
#  ['정리를', 47.4, 47.8, 1],
#  ['하고', 47.8, 48.0, 1],
#  ['얘기를', 48.0, 48.5, 1],
#  ['이어가겠습니다', 48.5, 49.3, 1],
#  ['함께', 49.3, 50.0, 1],
#  ['보시죠', 50.0, 50.3, 1],
#  ['다', 50.3, 53.0, 1],
#  ['한국', 53.0, 53.3, 1],
#  ['땅이', 53.3, 53.6, 1],
#  ['요구한', 53.6, 54.0, 1],
#  ['경찰청', 54.0, 54.2, 1],
#  ['운세', 54.2, 54.6, 1],
#  ['응답자의', 54.6, 55.2, 1],
#  ['55.4%', 55.2, 56.2, 1],
#  ['가', 56.2, 56.7, 1],
#  ['반대하는', 56.7, 57.3, 1],
#  ['것으로', 57.3, 57.6, 1],
#  ['나타났습니다', 57.6, 58.2, 1],
#  ['찬성은', 58.2, 59.2, 1],
#  ['30.9%', 59.2, 60.6, 1],
#  ['였고요', 60.6, 61.2, 1],
#  ['모른다거나', 61.2, 62.2, 1],
#  ['응답하지않음', 62.2, 63.6, 1],
#  ['비율은', 63.6, 64.1, 1],
#  ['13.7%', 64.1, 65.5, 1],
#  ['뛰었습니다', 65.5, 66.1, 1],
#  ['응답자를', 66.1, 68.0, 1],
#  ['지지정당', 68.0, 68.8, 1],
#  ['별로', 68.8, 69.2, 1],
#  ['나눠서', 69.2, 69.6, 1],
#  ['살펴보겠습니다', 69.6, 70.5, 1],
#  ['민주당', 70.5, 71.6, 1],
#  ['짐승의', 71.6, 72.1, 1],
#  ['결제', 72.1, 72.4, 1],
#  ['또', 72.4, 72.6, 1],
#  ['가도', 72.6, 73.1, 1],
#  ['높았습니다', 73.1, 73.5, 1],
#  ['응답자중', 73.5, 74.4, 1],
#  ['민주당', 74.4, 75.2, 1],
#  ['지지표의', 75.2, 75.5, 1],
#  ['85.9', 75.5, 76.6, 1],
#  ['한국', 0.3, 0.9, 1],
#  ['땅이', 0.9, 1.2, 1],
#  ['내', 1.2, 1.3, 1],
#  ['건', 1.3, 1.6, 1],
#  ['경제', 1.6, 2.2, 1],
#  ['청문회', 2.2, 2.7, 1],
#  ['여야', 2.7, 3.3, 1],
#  ['각', 3.3, 3.5, 1],
#  ['정당의', 3.5, 4.0, 1],
#  ['반응이', 4.0, 4.4, 1],
#  ['엇갈립니다', 4.4, 4.8, 1],
#  ['민주당과', 4.8, 5.7, 1],
#  ['바른미래당', 5.7, 6.3, 1],
#  ['정의당은', 6.3, 7.0, 1],
#  ['한국', 7.0, 7.6, 1],
#  ['땅이', 7.6, 7.9, 1],
#  ['업체를', 7.9, 8.4, 1],
#  ['부린다는', 8.4, 8.8, 1],
#  ['입장인', 8.8, 9.2, 1],
#  ['반면', 9.2, 9.3, 1],
#  ['에', 9.3, 9.6, 1],
#  ['한국당과', 9.6, 10.9, 1],
#  ['민주평화당', 10.9, 11.7, 1],
#  ['민주당이', 11.7, 12.8, 1],
#  ['청문회를', 12.8, 13.5, 1],
#  ['받아야', 13.5, 14.2, 1],
#  ['한다고', 14.2, 14.5, 1],
#  ['압박합니다', 14.5, 15.1, 1],
#  ['여론은', 16.7, 18.1, 1],
#  ['반대가', 18.1, 18.7, 1],
#  ['55%', 18.7, 19.4, 1],
#  ['로', 19.4, 19.8, 1],
#  ['찬성', 19.8, 20.3, 1],
#  ['31%', 20.3, 20.9, 1],
#  ['를', 20.9, 21.4, 1],
#  ['크게', 21.4, 21.8, 1],
#  ['앞지른', 21.8, 22.3, 1],
#  ['것으로', 22.3, 22.6, 1],
#  ['조사됐습니다', 22.6, 23.1, 1],
#  ['반대', 23.1, 24.0, 1],
#  ['여론이', 24.0, 24.3, 1],
#  ['높은', 24.3, 24.7, 1],
#  ['경제청', 24.7, 25.1, 1],
#  ['문제를', 25.1, 25.5, 1],
#  ['내', 25.5, 25.6, 1],
#  ['건', 25.6, 25.8, 1],
#  ['한국', 25.8, 26.2, 1],
#  ['땅이', 26.2, 26.6, 1],
#  ['문제가', 26.6, 26.8, 1],
#  ['앞으로', 26.8, 27.2, 1],
#  ['정당', 27.2, 27.7, 1],
#  ['지지도', 27.7, 27.9, 1],
#  ['그러면', 27.9, 28.5, 1],
#  ['어떤', 28.5, 28.9, 1],
#  ['영향을', 28.9, 29.3, 1],
#  ['미칠지', 29.3, 29.8, 1],
#  ['궁금합니다', 29.8, 30.6, 1],
#  ['숫자이동', 30.6, 31.6, 1],
#  ['지도', 31.6, 31.9, 1],
#  ['열어', 31.9, 32.2, 1],
#  ['내서', 32.2, 32.4, 1],
#  ['ytn', 32.4, 32.9, 1],
#  ['더', 32.9, 33.0, 1],
#  ['뉴스가', 33.0, 33.5, 1],
#  ['의', 33.5, 33.5, 1],
#  ['실시한', 33.5, 34.4, 1],
#  ['여론조사', 34.4, 35.0, 1],
#  ['결과', 35.0, 35.4, 1],
#  ['분석하겠습니다', 35.4, 36.0, 1],
#  ['이택수', 36.0, 37.0, 1],
#  ['리얼미터', 37.0, 37.4, 1],
#  ['대표', 37.4, 37.8, 1],
#  ['박지영', 37.8, 38.1, 1],
#  ['윈지코리아컨설팅', 38.1, 38.7, 1],
#  ['부대표', 38.7, 39.6, 1],
#  ['타기', 39.6, 39.8, 1],
#  ['하셨습니다', 39.8, 40.2, 1],
#  ['하십니까', 40.2, 41.1, 1],
#  ['안녕하세요', 41.1, 41.8, 1],
#  ['안녕하세요', 41.8, 42.5, 1],
#  ['경제', 42.5, 44.5, 1],
#  ['청문회', 44.5, 45.0, 1],
#  ['관련한', 45.0, 45.8, 1],
#  ['조사결과', 45.8, 46.7, 1],
#  ['부터', 46.7, 47.0, 1],
#  ['다시', 47.0, 47.2, 1],
#  ['한번', 47.2, 47.4, 1],
#  ['정리를', 47.4, 47.8, 1],
#  ['하고', 47.8, 48.0, 1],
#  ['얘기를', 48.0, 48.5, 1],
#  ['이어가겠습니다', 48.5, 49.3, 1],
#  ['함께', 49.3, 50.0, 1],
#  ['보시죠', 50.0, 50.3, 1],
#  ['다', 50.3, 53.0, 1],
#  ['한국', 53.0, 53.3, 1],
#  ['땅이', 53.3, 53.6, 1],
#  ['요구한', 53.6, 54.0, 1],
#  ['경찰청', 54.0, 54.2, 1],
#  ['운세', 54.2, 54.6, 1],
#  ['응답자의', 54.6, 55.2, 1],
#  ['55.4%', 55.2, 56.2, 1],
#  ['가', 56.2, 56.7, 1],
#  ['반대하는', 56.7, 57.3, 1],
#  ['것으로', 57.3, 57.6, 1],
#  ['나타났습니다', 57.6, 58.2, 1],
#  ['찬성은', 58.2, 59.2, 1],
#  ['30.9%', 59.2, 60.6, 1],
#  ['였고요', 60.6, 61.2, 1],
#  ['모른다거나', 61.2, 62.2, 1],
#  ['응답하지않음', 62.2, 63.6, 1],
#  ['비율은', 63.6, 64.1, 1],
#  ['13.7%', 64.1, 65.5, 1],
#  ['뛰었습니다', 65.5, 66.1, 1],
#  ['응답자를', 66.1, 68.0, 1],
#  ['지지정당', 68.0, 68.8, 1],
#  ['별로', 68.8, 69.2, 1],
#  ['나눠서', 69.2, 69.6, 1],
#  ['살펴보겠습니다', 69.6, 70.5, 1],
#  ['민주당', 70.5, 71.6, 1],
#  ['짐승의', 71.6, 72.1, 1],
#  ['결제', 72.1, 72.4, 1],
#  ['또', 72.4, 72.6, 1],
#  ['가도', 72.6, 73.1, 1],
#  ['높았습니다', 73.1, 73.5, 1],
#  ['응답자중', 73.5, 74.4, 1],
#  ['민주당', 74.4, 75.2, 1],
#  ['지지표의', 75.2, 75.5, 1],
#  ['85.9', 75.5, 76.6, 1],
#  ['퍼센트는', 76.6, 77.3, 1],
#  ['반대했고', 77.3, 78.0, 1],
#  ['한국땅을', 78.0, 79.1, 1],
#  ['지지하는', 79.1, 79.5, 1],
#  ['응답자는', 79.5, 80.0, 1],
#  ['68.2%', 80.0, 81.4, 1],
#  ['가', 81.4, 82.0, 1],
#  ['찬성하는', 82.0, 82.9, 1],
#  ['것으로', 82.9, 83.1, 1],
#  ['나타났습니다', 83.1, 83.7, 1],
#  ['정치', 83.7, 85.7, 1],
#  ['성향', 85.7, 86.0, 1],
#  ['별로', 86.0, 86.5, 1],
#  ['나눠서', 86.5, 86.9, 1],
#  ['조사한', 86.9, 87.4, 1],
#  ['결과에서도', 87.4, 87.9, 1],
#  ['진보측', 87.9, 88.8, 1],
#  ['의', 88.8, 88.9, 1],
#  ['반대', 88.9, 89.3, 1],
#  ['여론이', 89.3, 89.7, 1],
#  ['보수층의', 89.7, 90.4, 1],
#  ['찬성', 90.4, 90.8, 1],
#  ['여름보다', 90.8, 91.3, 1],
#  ['경고했습니다', 91.3, 91.8, 1],
#  ['봉투', 91.8, 92.9, 1],
#  ['측에서의', 92.9, 93.7, 1],
#  ['반대', 93.7, 94.2, 1],
#  ['여론이', 94.2, 94.5, 1],
#  ['35.8%', 94.5, 95.9, 1],
#  ['로', 95.9, 96.3, 1],
#  ['경제', 96.3, 97.0, 1],
#  ['청문회를', 97.0, 97.5, 1],
#  ['정치공세로', 97.5, 98.4, 1],
#  ['보내', 98.4, 98.6, 1],
#  ['시각도', 98.6, 99.1, 1],
#  ['포스팅에서도', 99.1, 100.0, 1],
#  ['적지', 100.0, 100.4, 1],
#  ['않아', 100.4, 100.5, 1],
#  ['중고책', 100.5, 101.8, 1],
#  ['전체', 101.8, 102.4, 1],
#  ['여론', 102.4, 102.8, 1],
#  ['부도와', 102.8, 103.3, 1],
#  ['비슷했습니다', 103.3, 103.9, 1],
#  ['정치', 103.9, 105.8, 1],
#  ['성향', 105.8, 106.0, 1],
#  ['결론은', 106.0, 106.6, 1],
#  ['중도층이', 106.6, 107.1, 1],
#  ['전체', 107.1, 107.5, 1],
#  ['여론과', 107.5, 108.1, 1],
#  ['비슷해', 108.1, 108.4, 1],
#  ['따면', 108.4, 108.9, 1],
#  ['지역별로', 108.9, 109.5, 1],
#  ['나는', 109.5, 109.8, 1],
#  ['수도권과', 109.8, 110.7, 1],
#  ['충청권을', 110.7, 110.8, 1],
#  ['그랬습니다', 110.8, 112.3, 1],
#  ['결과를', 112.3, 114.2, 1],
#  ['좀', 114.2, 114.4, 1],
#  ['봤습니다', 114.4, 114.6, 1],
#  ['찬송', 114.6, 115.3, 1],
#  ['30.9%', 115.3, 116.8, 1],
#  ['돼', 116.8, 117.6, 1],
#  ['반대', 117.6, 118.2, 1],
#  ['55.4%', 118.2, 119.5, 1],
#  ['대표님', 119.5, 120.6, 1],
#  ['한국', 120.6, 120.9, 1],
#  ['땅에', 120.9, 121.1, 1],
#  ['이런', 121.1, 121.4, 1],
#  ['여러', 121.4, 121.6, 1],
#  ['오늘', 121.6, 121.9, 1],
#  ['예상', 121.9, 122.2, 1],
#  ['했을까요', 122.2, 122.7, 1],
#  ['예상하지', 122.7, 123.7, 1],
#  ['못했을', 123.7, 124.0, 1],
#  ['것', 124.0, 124.1, 1],
#  ['같습니다', 124.1, 124.5, 1],
#  ['일단', 124.5, 124.9, 1],
#  ['뭐', 124.9, 125.2, 1],
#  ['큰', 125.2, 125.9, 1],
#  ['틀에서의', 125.9, 126.5, 1],
#  ['결과는', 126.5, 127.5, 1],
#  ['55.4', 127.5, 128.1, 1],
#  ['돼', 128.1, 128.3, 1],
#  ['30.9', 128.3, 128.9, 1],
#  ['예상가', 128.9, 130.8, 1],
#  ['크게', 130.8, 131.1, 1],
#  ['다르지', 131.1, 131.7, 1],
#  ['않은', 131.7, 132.0, 1],
#  ['듯', 132.0, 132.3, 1],
#  ['세부적으로', 132.3, 133.0, 1],
#  ['보면', 133.0, 133.1, 1],
#  ['이런', 133.1, 134.3, 1],
#  ['감정', 134.3, 134.6, 1],
#  ['보수층', 134.6, 135.2, 1],
#  ['일하는', 135.2, 135.7, 1],
#  ['중이라', 135.7, 136.6, 1],
#  ['한국', 0.3, 0.9, 1],
#  ['땅이', 0.9, 1.2, 1],
#  ['내', 1.2, 1.3, 1],
#  ['건', 1.3, 1.6, 1],
#  ['경제', 1.6, 2.2, 1],
#  ['청문회', 2.2, 2.7, 1],
#  ['여야', 2.7, 3.3, 1],
#  ['각', 3.3, 3.5, 1],
#  ['정당의', 3.5, 4.0, 1],
#  ['반응이', 4.0, 4.4, 1],
#  ['엇갈립니다', 4.4, 4.8, 1],
#  ['민주당과', 4.8, 5.7, 1],
#  ['바른미래당', 5.7, 6.3, 1],
#  ['정의당은', 6.3, 7.0, 1],
#  ['한국', 7.0, 7.6, 1],
#  ['땅이', 7.6, 7.9, 1],
#  ['업체를', 7.9, 8.4, 1],
#  ['부린다는', 8.4, 8.8, 1],
#  ['입장인', 8.8, 9.2, 1],
#  ['반면', 9.2, 9.3, 1],
#  ['에', 9.3, 9.6, 1],
#  ['한국당과', 9.6, 10.9, 1],
#  ['민주평화당', 10.9, 11.7, 1],
#  ['민주당이', 11.7, 12.8, 1],
#  ['청문회를', 12.8, 13.5, 1],
#  ['받아야', 13.5, 14.2, 1],
#  ['한다고', 14.2, 14.5, 1],
#  ['압박합니다', 14.5, 15.1, 1],
#  ['여론은', 16.7, 18.1, 1],
#  ['반대가', 18.1, 18.7, 1],
#  ['55%', 18.7, 19.4, 1],
#  ['로', 19.4, 19.8, 1],
#  ['찬성', 19.8, 20.3, 1],
#  ['31%', 20.3, 20.9, 1],
#  ['를', 20.9, 21.4, 1],
#  ['크게', 21.4, 21.8, 1],
#  ['앞지른', 21.8, 22.3, 1],
#  ['것으로', 22.3, 22.6, 1],
#  ['조사됐습니다', 22.6, 23.1, 1],
#  ['반대', 23.1, 24.0, 1],
#  ['여론이', 24.0, 24.3, 1],
#  ['높은', 24.3, 24.7, 1],
#  ['경제청', 24.7, 25.1, 1],
#  ['문제를', 25.1, 25.5, 1],
#  ['내', 25.5, 25.6, 1],
#  ['건', 25.6, 25.8, 1],
#  ['한국', 25.8, 26.2, 1],
#  ['땅이', 26.2, 26.6, 1],
#  ['문제가', 26.6, 26.8, 1],
#  ['앞으로', 26.8, 27.2, 1],
#  ['정당', 27.2, 27.7, 1],
#  ['지지도', 27.7, 27.9, 1],
#  ['그러면', 27.9, 28.5, 1],
#  ['어떤', 28.5, 28.9, 1],
#  ['영향을', 28.9, 29.3, 1],
#  ['미칠지', 29.3, 29.8, 1],
#  ['궁금합니다', 29.8, 30.6, 1],
#  ['숫자이동', 30.6, 31.6, 1],
#  ['지도', 31.6, 31.9, 1],
#  ['열어', 31.9, 32.2, 1],
#  ['내서', 32.2, 32.4, 1],
#  ['ytn', 32.4, 32.9, 1],
#  ['더', 32.9, 33.0, 1],
#  ['뉴스가', 33.0, 33.5, 1],
#  ['의', 33.5, 33.5, 1],
#  ['실시한', 33.5, 34.4, 1],
#  ['여론조사', 34.4, 35.0, 1],
#  ['결과', 35.0, 35.4, 1],
#  ['분석하겠습니다', 35.4, 36.0, 1],
#  ['이택수', 36.0, 37.0, 1],
#  ['리얼미터', 37.0, 37.4, 1],
#  ['대표', 37.4, 37.8, 1],
#  ['박지영', 37.8, 38.1, 1],
#  ['윈지코리아컨설팅', 38.1, 38.7, 1],
#  ['부대표', 38.7, 39.6, 1],
#  ['타기', 39.6, 39.8, 1],
#  ['하셨습니다', 39.8, 40.2, 1],
#  ['하십니까', 40.2, 41.1, 1],
#  ['안녕하세요', 41.1, 41.8, 1],
#  ['안녕하세요', 41.8, 42.5, 1],
#  ['경제', 42.5, 44.5, 1],
#  ['청문회', 44.5, 45.0, 1],
#  ['관련한', 45.0, 45.8, 1],
#  ['조사결과', 45.8, 46.7, 1],
#  ['부터', 46.7, 47.0, 1],
#  ['다시', 47.0, 47.2, 1],
#  ['한번', 47.2, 47.4, 1],
#  ['정리를', 47.4, 47.8, 1],
#  ['하고', 47.8, 48.0, 1],
#  ['얘기를', 48.0, 48.5, 1],
#  ['이어가겠습니다', 48.5, 49.3, 1],
#  ['함께', 49.3, 50.0, 1],
#  ['보시죠', 50.0, 50.3, 1],
#  ['다', 50.3, 53.0, 1],
#  ['한국', 53.0, 53.3, 1],
#  ['땅이', 53.3, 53.6, 1],
#  ['요구한', 53.6, 54.0, 1],
#  ['경찰청', 54.0, 54.2, 1],
#  ['운세', 54.2, 54.6, 1],
#  ['응답자의', 54.6, 55.2, 1],
#  ['55.4%', 55.2, 56.2, 1],
#  ['가', 56.2, 56.7, 1],
#  ['반대하는', 56.7, 57.3, 1],
#  ['것으로', 57.3, 57.6, 1],
#  ['나타났습니다', 57.6, 58.2, 1],
#  ['찬성은', 58.2, 59.2, 1],
#  ['30.9%', 59.2, 60.6, 1],
#  ['였고요', 60.6, 61.2, 1],
#  ['모른다거나', 61.2, 62.2, 1],
#  ['응답하지않음', 62.2, 63.6, 1],
#  ['비율은', 63.6, 64.1, 1],
#  ['13.7%', 64.1, 65.5, 1],
#  ['뛰었습니다', 65.5, 66.1, 1],
#  ['응답자를', 66.1, 68.0, 1],
#  ['지지정당', 68.0, 68.8, 1],
#  ['별로', 68.8, 69.2, 1],
#  ['나눠서', 69.2, 69.6, 1],
#  ['살펴보겠습니다', 69.6, 70.5, 1],
#  ['민주당', 70.5, 71.6, 1],
#  ['짐승의', 71.6, 72.1, 1],
#  ['결제', 72.1, 72.4, 1],
#  ['또', 72.4, 72.6, 1],
#  ['가도', 72.6, 73.1, 1],
#  ['높았습니다', 73.1, 73.5, 1],
#  ['응답자중', 73.5, 74.4, 1],
#  ['민주당', 74.4, 75.2, 1],
#  ['지지표의', 75.2, 75.5, 1],
#  ['85.9', 75.5, 76.6, 1],
#  ['퍼센트는', 76.6, 77.3, 1],
#  ['반대했고', 77.3, 78.0, 1],
#  ['한국땅을', 78.0, 79.1, 1],
#  ['지지하는', 79.1, 79.5, 1],
#  ['응답자는', 79.5, 80.0, 1],
#  ['68.2%', 80.0, 81.4, 1],
#  ['가', 81.4, 82.0, 1],
#  ['찬성하는', 82.0, 82.9, 1],
#  ['것으로', 82.9, 83.1, 1],
#  ['나타났습니다', 83.1, 83.7, 1],
#  ['정치', 83.7, 85.7, 1],
#  ['성향', 85.7, 86.0, 1],
#  ['별로', 86.0, 86.5, 1],
#  ['나눠서', 86.5, 86.9, 1],
#  ['조사한', 86.9, 87.4, 1],
#  ['결과에서도', 87.4, 87.9, 1],
#  ['진보측', 87.9, 88.8, 1],
#  ['의', 88.8, 88.9, 1],
#  ['반대', 88.9, 89.3, 1],
#  ['여론이', 89.3, 89.7, 1],
#  ['보수층의', 89.7, 90.4, 1],
#  ['찬성', 90.4, 90.8, 1],
#  ['여름보다', 90.8, 91.3, 1],
#  ['경고했습니다', 91.3, 91.8, 1],
#  ['봉투', 91.8, 92.9, 1],
#  ['측에서의', 92.9, 93.7, 1],
#  ['반대', 93.7, 94.2, 1],
#  ['여론이', 94.2, 94.5, 1],
#  ['35.8%', 94.5, 95.9, 1],
#  ['로', 95.9, 96.3, 1],
#  ['경제', 96.3, 97.0, 1],
#  ['청문회를', 97.0, 97.5, 1],
#  ['정치공세로', 97.5, 98.4, 1],
#  ['보내', 98.4, 98.6, 1],
#  ['시각도', 98.6, 99.1, 1],
#  ['포스팅에서도', 99.1, 100.0, 1],
#  ['적지', 100.0, 100.4, 1],
#  ['않아', 100.4, 100.5, 1],
#  ['중고책', 100.5, 101.8, 1],
#  ['전체', 101.8, 102.4, 1],
#  ['여론', 102.4, 102.8, 1],
#  ['부도와', 102.8, 103.3, 1],
#  ['비슷했습니다', 103.3, 103.9, 1],
#  ['정치', 103.9, 105.8, 1],
#  ['성향', 105.8, 106.0, 1],
#  ['결론은', 106.0, 106.6, 1],
#  ['중도층이', 106.6, 107.1, 1],
#  ['전체', 107.1, 107.5, 1],
#  ['여론과', 107.5, 108.1, 1],
#  ['비슷해', 108.1, 108.4, 1],
#  ['따면', 108.4, 108.9, 1],
#  ['지역별로', 108.9, 109.5, 1],
#  ['나는', 109.5, 109.8, 1],
#  ['수도권과', 109.8, 110.7, 1],
#  ['충청권을', 110.7, 110.8, 1],
#  ['그랬습니다', 110.8, 112.3, 1],
#  ['결과를', 112.3, 114.2, 1],
#  ['좀', 114.2, 114.4, 1],
#  ['봤습니다', 114.4, 114.6, 1],
#  ['찬송', 114.6, 115.3, 1],
#  ['30.9%', 115.3, 116.8, 1],
#  ['돼', 116.8, 117.6, 1],
#  ['반대', 117.6, 118.2, 1],
#  ['55.4%', 118.2, 119.5, 1],
#  ['대표님', 119.5, 120.6, 1],
#  ['한국', 120.6, 120.9, 1],
#  ['땅에', 120.9, 121.1, 1],
#  ['이런', 121.1, 121.4, 1],
#  ['여러', 121.4, 121.6, 1],
#  ['오늘', 121.6, 121.9, 1],
#  ['예상', 121.9, 122.2, 1],
#  ['했을까요', 122.2, 122.7, 1],
#  ['예상하지', 122.7, 123.7, 1],
#  ['못했을', 123.7, 124.0, 1],
#  ['것', 124.0, 124.1, 1],
#  ['같습니다', 124.1, 124.5, 1],
#  ['일단', 124.5, 124.9, 1],
#  ['뭐', 124.9, 125.2, 1],
#  ['큰', 125.2, 125.9, 1],
#  ['틀에서의', 125.9, 126.5, 1],
#  ['결과는', 126.5, 127.5, 1],
#  ['55.4', 127.5, 128.1, 1],
#  ['돼', 128.1, 128.3, 1],
#  ['30.9', 128.3, 128.9, 1],
#  ['예상가', 128.9, 130.8, 1],
#  ['크게', 130.8, 131.1, 1],
#  ['다르지', 131.1, 131.7, 1],
#  ['않은', 131.7, 132.0, 1],
#  ['듯', 132.0, 132.3, 1],
#  ['세부적으로', 132.3, 133.0, 1],
#  ['보면', 133.0, 133.1, 1],
#  ['이런', 133.1, 134.3, 1],
#  ['감정', 134.3, 134.6, 1],
#  ['보수층', 134.6, 135.2, 1],
#  ['일하는', 135.2, 135.7, 1],
#  ['중이라', 135.7, 136.6, 1],
#  ['건지', 136.6, 136.9, 1],
#  ['아니면', 136.9, 137.3, 1],
#  ['한국당', 137.3, 138.1, 1],
#  ['지지율', 138.1, 138.2, 1],
#  ['제외하고는', 138.2, 138.9, 1],
#  ['대부분의', 138.9, 139.4, 1],
#  ['계층에서', 139.4, 140.0, 1],
#  ['지금', 140.0, 140.9, 1],
#  ['반대하는', 140.9, 141.4, 1],
#  ['의견이', 141.4, 141.7, 1],
#  ['높게', 141.7, 142.2, 1],
#  ['나타난다', 142.2, 142.6, 1],
#  ['민요', 142.6, 143.0, 1],
#  ['그것은', 143.0, 144.2, 1],
#  ['제', 144.2, 144.4, 1],
#  ['2항에서', 144.4, 145.2, 1],
#  ['내세운', 145.2, 145.7, 1],
#  ['명분은', 145.7, 146.3, 1],
#  ['이게', 146.3, 146.8, 1],
#  ['진정성', 146.8, 147.7, 1],
#  ['있는', 147.7, 147.8, 1],
#  ['야', 147.8, 148.1, 1],
#  ['그동안에', 148.1, 148.8, 1],
#  ['국회정상화', 148.8, 149.3, 1],
#  ['라든지', 149.3, 149.9, 1],
#  ['규정에', 149.9, 150.8, 1],
#  ['따른', 150.8, 151.3, 1],
#  ['무노동', 151.3, 152.6, 1],
#  ['무임금', 152.6, 152.7, 1],
#  ['국민소환제', 152.7, 153.8, 1],
#  ['여론이', 153.8, 154.8, 1],
#  ['굉장히', 154.8, 155.1, 1],
#  ['안', 155.1, 155.3, 1],
#  ['좋아', 155.3, 155.4, 1],
#  ['썼거든요', 155.4, 156.0, 1],
#  ['그렇기', 156.0, 156.7, 1],
#  ['때문에', 156.7, 157.1, 1],
#  ['결국에는', 157.1, 158.0, 1],
#  ['이', 158.0, 158.8, 1],
#  ['수조차도', 158.8, 159.8, 1],
#  ['부케를', 159.8, 161.0, 1],
#  ['지금', 161.0, 161.8, 1],
#  ['정사', 161.8, 162.7, 1],
#  ['하는데', 162.7, 163.1, 1],
#  ['우리도', 163.1, 163.9, 1],
#  ['이제', 163.9, 164.3, 1],
#  ['그', 164.3, 164.7, 1],
#  ['반대일', 164.7, 165.6, 1],
#  ['요소로', 165.6, 166.2, 1],
#  ['작용할', 166.2, 166.5, 1],
#  ['키', 166.5, 166.7, 1],
#  ['규현', 166.7, 167.0, 1],
#  ['어떤', 167.0, 167.7, 1],
#  ['실띄우기', 167.7, 168.5, 1],
#  ['아니야', 168.5, 168.9, 1],
#  ['이렇게', 168.9, 169.0, 1],
#  ['본', 169.0, 169.3, 1],
#  ['계층들이', 169.3, 170.6, 1],
#  ['많았던', 170.6, 171.0, 1],
#  ['거', 171.0, 171.1, 1],
#  ['같아요', 171.1, 171.5, 1],
#  ['그래서', 171.5, 171.7, 1],
#  ['엉덩이', 171.7, 173.2, 1],
#  ['예상치', 173.2, 174.3, 1],
#  ['못한', 174.3, 174.6, 1],
#  ['세부적인', 174.6, 175.3, 1],
#  ['그런', 175.3, 175.6, 1],
#  ['결혼', 175.6, 175.9, 1],
#  ['응', 175.9, 176.5, 1],
#  ['답들이', 176.5, 176.9, 1],
#  ['나온', 176.9, 177.0, 1],
#  ['거', 177.0, 177.1, 1],
#  ['같습니다', 177.1, 177.2, 1],
#  ['항상', 177.2, 178.3, 1],
#  ['입장에서는', 178.3, 179.1, 1],
#  ['다른', 179.1, 180.5, 1],
#  ['것보다', 180.5, 180.8, 1],
#  ['보수층', 180.8, 181.6, 1],
#  ['내에서', 181.6, 182.3, 1],
#  ['35.8%', 182.3, 183.2, 1],
#  ['나', 183.2, 183.7, 1],
#  ['반대를', 183.7, 184.6, 1],
#  ['하고', 184.6, 184.8, 1],
#  ['있는', 184.8, 185.1, 1],
#  ['이', 185.1, 185.2, 1],
#  ['부분이', 185.2, 185.6, 1],
#  ['좀', 185.6, 185.7, 1],
#  ['아팠을', 185.7, 186.1, 1],
#  ['것', 186.1, 186.2, 1],
#  ['같습니다', 186.2, 186.6, 1],
#  ['2층에서', 186.6, 187.6, 1],
#  ['홍이', 187.6, 188.0, 1],
#  ['뜨겁지', 188.0, 188.6, 1],
#  ['않다', 188.6, 189.0, 1],
#  ['평가할', 189.0, 190.4, 1],
#  ['수', 190.4, 190.5, 1],
#  ['있을', 190.5, 190.7, 1],
#  ['것', 190.7, 190.8, 1],
#  ['같은데', 190.8, 191.2, 1],
#  ['지금', 191.2, 191.9, 1],
#  ['국기에', 191.9, 192.4, 1],
#  ['공전', 192.4, 193.0, 1],
#  ['사태가', 193.0, 193.5, 1],
#  ['벌써', 193.5, 193.7, 1],
#  ['두', 193.7, 193.9, 1],
#  ['달이', 193.9, 194.1, 1],
#  ['너무', 194.1, 194.3, 1],
#  ['같지', 194.3, 194.6, 1],
#  ['않습니까', 194.6, 194.9, 1],
#  ['한국', 0.3, 0.9, 1],
#  ['땅이', 0.9, 1.2, 1],
#  ['내', 1.2, 1.3, 1],
#  ['건', 1.3, 1.6, 1],
#  ['경제', 1.6, 2.2, 1],
#  ['청문회', 2.2, 2.7, 1],
#  ['여야', 2.7, 3.3, 1],
#  ['각', 3.3, 3.5, 1],
#  ['정당의', 3.5, 4.0, 1],
#  ['반응이', 4.0, 4.4, 1],
#  ['엇갈립니다', 4.4, 4.8, 1],
#  ['민주당과', 4.8, 5.7, 1],
#  ['바른미래당', 5.7, 6.3, 1],
#  ['정의당은', 6.3, 7.0, 1],
#  ['한국', 7.0, 7.6, 1],
#  ['땅이', 7.6, 7.9, 1],
#  ['업체를', 7.9, 8.4, 1],
#  ['부린다는', 8.4, 8.8, 1],
#  ['입장인', 8.8, 9.2, 1],
#  ['반면', 9.2, 9.3, 1],
#  ['에', 9.3, 9.6, 1],
#  ['한국당과', 9.6, 10.9, 1],
#  ['민주평화당', 10.9, 11.7, 1],
#  ['민주당이', 11.7, 12.8, 1],
#  ['청문회를', 12.8, 13.5, 1],
#  ['받아야', 13.5, 14.2, 1],
#  ['한다고', 14.2, 14.5, 1],
#  ['압박합니다', 14.5, 15.1, 1],
#  ['여론은', 16.7, 18.1, 1],
#  ['반대가', 18.1, 18.7, 1],
#  ['55%', 18.7, 19.4, 1],
#  ['로', 19.4, 19.8, 1],
#  ['찬성', 19.8, 20.3, 1],
#  ['31%', 20.3, 20.9, 1],
#  ['를', 20.9, 21.4, 1],
#  ['크게', 21.4, 21.8, 1],
#  ['앞지른', 21.8, 22.3, 1],
#  ['것으로', 22.3, 22.6, 1],
#  ['조사됐습니다', 22.6, 23.1, 1],
#  ['반대', 23.1, 24.0, 1],
#  ['여론이', 24.0, 24.3, 1],
#  ['높은', 24.3, 24.7, 1],
#  ['경제청', 24.7, 25.1, 1],
#  ['문제를', 25.1, 25.5, 1],
#  ['내', 25.5, 25.6, 1],
#  ['건', 25.6, 25.8, 1],
#  ['한국', 25.8, 26.2, 1],
#  ['땅이', 26.2, 26.6, 1],
#  ['문제가', 26.6, 26.8, 1],
#  ['앞으로', 26.8, 27.2, 1],
#  ['정당', 27.2, 27.7, 1],
#  ['지지도', 27.7, 27.9, 1],
#  ['그러면', 27.9, 28.5, 1],
#  ['어떤', 28.5, 28.9, 1],
#  ['영향을', 28.9, 29.3, 1],
#  ['미칠지', 29.3, 29.8, 1],
#  ['궁금합니다', 29.8, 30.6, 1],
#  ['숫자이동', 30.6, 31.6, 1],
#  ['지도', 31.6, 31.9, 1],
#  ['열어', 31.9, 32.2, 1],
#  ['내서', 32.2, 32.4, 1],
#  ['ytn', 32.4, 32.9, 1],
#  ['더', 32.9, 33.0, 1],
#  ['뉴스가', 33.0, 33.5, 1],
#  ['의', 33.5, 33.5, 1],
#  ['실시한', 33.5, 34.4, 1],
#  ['여론조사', 34.4, 35.0, 1],
#  ['결과', 35.0, 35.4, 1],
#  ['분석하겠습니다', 35.4, 36.0, 1],
#  ['이택수', 36.0, 37.0, 1],
#  ['리얼미터', 37.0, 37.4, 1],
#  ['대표', 37.4, 37.8, 1],
#  ['박지영', 37.8, 38.1, 1],
#  ['윈지코리아컨설팅', 38.1, 38.7, 1],
#  ['부대표', 38.7, 39.6, 1],
#  ['타기', 39.6, 39.8, 1],
#  ['하셨습니다', 39.8, 40.2, 1],
#  ['하십니까', 40.2, 41.1, 1],
#  ['안녕하세요', 41.1, 41.8, 1],
#  ['안녕하세요', 41.8, 42.5, 1],
#  ['경제', 42.5, 44.5, 1],
#  ['청문회', 44.5, 45.0, 1],
#  ['관련한', 45.0, 45.8, 1],
#  ['조사결과', 45.8, 46.7, 1],
#  ['부터', 46.7, 47.0, 1],
#  ['다시', 47.0, 47.2, 1],
#  ['한번', 47.2, 47.4, 1],
#  ['정리를', 47.4, 47.8, 1],
#  ['하고', 47.8, 48.0, 1],
#  ['얘기를', 48.0, 48.5, 1],
#  ['이어가겠습니다', 48.5, 49.3, 1],
#  ['함께', 49.3, 50.0, 1],
#  ['보시죠', 50.0, 50.3, 1],
#  ['다', 50.3, 53.0, 1],
#  ['한국', 53.0, 53.3, 1],
#  ['땅이', 53.3, 53.6, 1],
#  ['요구한', 53.6, 54.0, 1],
#  ['경찰청', 54.0, 54.2, 1],
#  ['운세', 54.2, 54.6, 1],
#  ['응답자의', 54.6, 55.2, 1],
#  ['55.4%', 55.2, 56.2, 1],
#  ['가', 56.2, 56.7, 1],
#  ['반대하는', 56.7, 57.3, 1],
#  ['것으로', 57.3, 57.6, 1],
#  ['나타났습니다', 57.6, 58.2, 1],
#  ['찬성은', 58.2, 59.2, 1],
#  ['30.9%', 59.2, 60.6, 1],
#  ['였고요', 60.6, 61.2, 1],
#  ['모른다거나', 61.2, 62.2, 1],
#  ['응답하지않음', 62.2, 63.6, 1],
#  ['비율은', 63.6, 64.1, 1],
#  ['13.7%', 64.1, 65.5, 1],
#  ['뛰었습니다', 65.5, 66.1, 1],
#  ['응답자를', 66.1, 68.0, 1],
#  ['지지정당', 68.0, 68.8, 1],
#  ['별로', 68.8, 69.2, 1],
#  ['나눠서', 69.2, 69.6, 1],
#  ['살펴보겠습니다', 69.6, 70.5, 1],
#  ['민주당', 70.5, 71.6, 1],
#  ['짐승의', 71.6, 72.1, 1],
#  ['결제', 72.1, 72.4, 1],
#  ['또', 72.4, 72.6, 1],
#  ['가도', 72.6, 73.1, 1],
#  ['높았습니다', 73.1, 73.5, 1],
#  ['응답자중', 73.5, 74.4, 1],
#  ['민주당', 74.4, 75.2, 1],
#  ['지지표의', 75.2, 75.5, 1],
#  ['85.9', 75.5, 76.6, 1],
#  ['퍼센트는', 76.6, 77.3, 1],
#  ['반대했고', 77.3, 78.0, 1],
#  ['한국땅을', 78.0, 79.1, 1],
#  ['지지하는', 79.1, 79.5, 1],
#  ['응답자는', 79.5, 80.0, 1],
#  ['68.2%', 80.0, 81.4, 1],
#  ['가', 81.4, 82.0, 1],
#  ['찬성하는', 82.0, 82.9, 1],
#  ['것으로', 82.9, 83.1, 1],
#  ['나타났습니다', 83.1, 83.7, 1],
#  ['정치', 83.7, 85.7, 1],
#  ['성향', 85.7, 86.0, 1],
#  ['별로', 86.0, 86.5, 1],
#  ['나눠서', 86.5, 86.9, 1],
#  ['조사한', 86.9, 87.4, 1],
#  ['결과에서도', 87.4, 87.9, 1],
#  ['진보측', 87.9, 88.8, 1],
#  ['의', 88.8, 88.9, 1],
#  ['반대', 88.9, 89.3, 1],
#  ['여론이', 89.3, 89.7, 1],
#  ['보수층의', 89.7, 90.4, 1],
#  ['찬성', 90.4, 90.8, 1],
#  ['여름보다', 90.8, 91.3, 1],
#  ['경고했습니다', 91.3, 91.8, 1],
#  ['봉투', 91.8, 92.9, 1],
#  ['측에서의', 92.9, 93.7, 1],
#  ['반대', 93.7, 94.2, 1],
#  ['여론이', 94.2, 94.5, 1],
#  ['35.8%', 94.5, 95.9, 1],
#  ['로', 95.9, 96.3, 1],
#  ['경제', 96.3, 97.0, 1],
#  ['청문회를', 97.0, 97.5, 1],
#  ['정치공세로', 97.5, 98.4, 1],
#  ['보내', 98.4, 98.6, 1],
#  ['시각도', 98.6, 99.1, 1],
#  ['포스팅에서도', 99.1, 100.0, 1],
#  ['적지', 100.0, 100.4, 1],
#  ['않아', 100.4, 100.5, 1],
#  ['중고책', 100.5, 101.8, 1],
#  ['전체', 101.8, 102.4, 1],
#  ['여론', 102.4, 102.8, 1],
#  ['부도와', 102.8, 103.3, 1],
#  ['비슷했습니다', 103.3, 103.9, 1],
#  ['정치', 103.9, 105.8, 1],
#  ['성향', 105.8, 106.0, 1],
#  ['결론은', 106.0, 106.6, 1],
#  ['중도층이', 106.6, 107.1, 1],
#  ['전체', 107.1, 107.5, 1],
#  ['여론과', 107.5, 108.1, 1],
#  ['비슷해', 108.1, 108.4, 1],
#  ['따면', 108.4, 108.9, 1],
#  ['지역별로', 108.9, 109.5, 1],
#  ['나는', 109.5, 109.8, 1],
#  ['수도권과', 109.8, 110.7, 1],
#  ['충청권을', 110.7, 110.8, 1],
#  ['그랬습니다', 110.8, 112.3, 1],
#  ['결과를', 112.3, 114.2, 1],
#  ['좀', 114.2, 114.4, 1],
#  ['봤습니다', 114.4, 114.6, 1],
#  ['찬송', 114.6, 115.3, 1],
#  ['30.9%', 115.3, 116.8, 1],
#  ['돼', 116.8, 117.6, 1],
#  ['반대', 117.6, 118.2, 1],
#  ['55.4%', 118.2, 119.5, 1],
#  ['대표님', 119.5, 120.6, 1],
#  ['한국', 120.6, 120.9, 1],
#  ['땅에', 120.9, 121.1, 1],
#  ['이런', 121.1, 121.4, 1],
#  ['여러', 121.4, 121.6, 1],
#  ['오늘', 121.6, 121.9, 1],
#  ['예상', 121.9, 122.2, 1],
#  ['했을까요', 122.2, 122.7, 1],
#  ['예상하지', 122.7, 123.7, 1],
#  ['못했을', 123.7, 124.0, 1],
#  ['것', 124.0, 124.1, 1],
#  ['같습니다', 124.1, 124.5, 1],
#  ['일단', 124.5, 124.9, 1],
#  ['뭐', 124.9, 125.2, 1],
#  ['큰', 125.2, 125.9, 1],
#  ['틀에서의', 125.9, 126.5, 1],
#  ['결과는', 126.5, 127.5, 1],
#  ['55.4', 127.5, 128.1, 1],
#  ['돼', 128.1, 128.3, 1],
#  ['30.9', 128.3, 128.9, 1],
#  ['예상가', 128.9, 130.8, 1],
#  ['크게', 130.8, 131.1, 1],
#  ['다르지', 131.1, 131.7, 1],
#  ['않은', 131.7, 132.0, 1],
#  ['듯', 132.0, 132.3, 1],
#  ['세부적으로', 132.3, 133.0, 1],
#  ['보면', 133.0, 133.1, 1],
#  ['이런', 133.1, 134.3, 1],
#  ['감정', 134.3, 134.6, 1],
#  ['보수층', 134.6, 135.2, 1],
#  ['일하는', 135.2, 135.7, 1],
#  ['중이라', 135.7, 136.6, 1],
#  ['건지', 136.6, 136.9, 1],
#  ['아니면', 136.9, 137.3, 1],
#  ['한국당', 137.3, 138.1, 1],
#  ['지지율', 138.1, 138.2, 1],
#  ['제외하고는', 138.2, 138.9, 1],
#  ['대부분의', 138.9, 139.4, 1],
#  ['계층에서', 139.4, 140.0, 1],
#  ['지금', 140.0, 140.9, 1],
#  ['반대하는', 140.9, 141.4, 1],
#  ['의견이', 141.4, 141.7, 1],
#  ['높게', 141.7, 142.2, 1],
#  ['나타난다', 142.2, 142.6, 1],
#  ['민요', 142.6, 143.0, 1],
#  ['그것은', 143.0, 144.2, 1],
#  ['제', 144.2, 144.4, 1],
#  ['2항에서', 144.4, 145.2, 1],
#  ['내세운', 145.2, 145.7, 1],
#  ['명분은', 145.7, 146.3, 1],
#  ['이게', 146.3, 146.8, 1],
#  ['진정성', 146.8, 147.7, 1],
#  ['있는', 147.7, 147.8, 1],
#  ['야', 147.8, 148.1, 1],
#  ['그동안에', 148.1, 148.8, 1],
#  ['국회정상화', 148.8, 149.3, 1],
#  ['라든지', 149.3, 149.9, 1],
#  ['규정에', 149.9, 150.8, 1],
#  ['따른', 150.8, 151.3, 1],
#  ['무노동', 151.3, 152.6, 1],
#  ['무임금', 152.6, 152.7, 1],
#  ['국민소환제', 152.7, 153.8, 1],
#  ['여론이', 153.8, 154.8, 1],
#  ['굉장히', 154.8, 155.1, 1],
#  ['안', 155.1, 155.3, 1],
#  ['좋아', 155.3, 155.4, 1],
#  ['썼거든요', 155.4, 156.0, 1],
#  ['그렇기', 156.0, 156.7, 1],
#  ['때문에', 156.7, 157.1, 1],
#  ['결국에는', 157.1, 158.0, 1],
#  ['이', 158.0, 158.8, 1],
#  ['수조차도', 158.8, 159.8, 1],
#  ['부케를', 159.8, 161.0, 1],
#  ['지금', 161.0, 161.8, 1],
#  ['정사', 161.8, 162.7, 1],
#  ['하는데', 162.7, 163.1, 1],
#  ['우리도', 163.1, 163.9, 1],
#  ['이제', 163.9, 164.3, 1],
#  ['그', 164.3, 164.7, 1],
#  ['반대일', 164.7, 165.6, 1],
#  ['요소로', 165.6, 166.2, 1],
#  ['작용할', 166.2, 166.5, 1],
#  ['키', 166.5, 166.7, 1],
#  ['규현', 166.7, 167.0, 1],
#  ['어떤', 167.0, 167.7, 1],
#  ['실띄우기', 167.7, 168.5, 1],
#  ['아니야', 168.5, 168.9, 1],
#  ['이렇게', 168.9, 169.0, 1],
#  ['본', 169.0, 169.3, 1],
#  ['계층들이', 169.3, 170.6, 1],
#  ['많았던', 170.6, 171.0, 1],
#  ['거', 171.0, 171.1, 1],
#  ['같아요', 171.1, 171.5, 1],
#  ['그래서', 171.5, 171.7, 1],
#  ['엉덩이', 171.7, 173.2, 1],
#  ...]

# %%
# CSV 파일로 저장
csv_file = "text/" + FILE_NAME + ".csv"
with open(csv_file, 'w', encoding='utf-8', newline='') as f:
    wr = csv.writer(f)
    wr.writerow(["word", "start_time", "end_time", "speaker_tag"])
    for words in words_array:
        wr.writerow(words)
