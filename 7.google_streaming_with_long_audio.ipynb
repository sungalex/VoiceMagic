# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Google-Cloud-Speech-to-Text-API-Streaming-example" data-toc-modified-id="Google-Cloud-Speech-to-Text-API-Streaming-example-1">Google Cloud Speech-to-Text API Streaming example</a></span></li></ul></div>

# %% [markdown]
# # Google Cloud Speech-to-Text API Streaming example

# %% [markdown]
# - 1분 이상의 긴 오디오 파일을 Streaming 방식으로 처리하는 샘플
# - https://cloud.google.com/speech-to-text/docs/streaming-recognize
# - google.cloud.speech.SpeechClient().**streaming_recognize(streaming_config, requests)**
# - **Audio file size limit : 10M bytes** => 10M 이상의 파일을 처리하기 위해 wave file을 10M 이하 크기로 잘라서 변환하도록 개선

# %%
import pyaudio
import wave
import os
import io
import csv

import numpy as np

from nltk.tokenize import sent_tokenize, word_tokenize

# for speaker_diarization (use speech_v1p1beta1)
from google.cloud import speech_v1p1beta1 as speech
from google.cloud.speech_v1p1beta1 import enums
from google.cloud.speech_v1p1beta1 import types

# %%
def transcribe_streaming(stream_file):
    """Streams transcription of the given audio file."""
    words_with_tag = []
    transcripts = []

    client = speech.SpeechClient()

    with io.open(stream_file, 'rb') as audio_file:
        content = audio_file.read()

    # In practice, stream should be a generator yielding chunks of audio data.
    stream = [content]

    requests = (types.StreamingRecognizeRequest(audio_content=chunk)
                for chunk in stream)

    config = types.RecognitionConfig(
        encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
        sample_rate_hertz=16000,
        language_code='ko-KR',
        enable_automatic_punctuation=True,
        enable_word_time_offsets=True,
        enable_speaker_diarization=True,    # 한국어 지원 안됨 (speaker_tag가 모두 동일인으로 분류됨)
        diarization_speaker_count=3)

    streaming_config = types.StreamingRecognitionConfig(config=config)
    
    # streaming_recognize returns a generator.
    responses = client.streaming_recognize(streaming_config, requests)
    
    for response in responses:
        for result in response.results:
            alternatives = result.alternatives
            for alternative in alternatives:
                print(u'Transcript: {}'.format(alternative.transcript))
                transcripts.append(alternative.transcript)    # punctuation 포함된 문장을 사용하기 위해 저장
                for words in alternative.words:
                    word = words.word
                    start_time = round(words.start_time.seconds + words.start_time.nanos * 1e-9, 3)
                    end_time = round(words.end_time.seconds + words.end_time.nanos * 1e-9, 3)
                    speaker_tag = words.speaker_tag
                    words_with_tag.append([word, start_time, end_time, speaker_tag])    # [word, start_time, end_time, speaker_tag]
        print()
    return words_with_tag, transcripts

# %%
def write_wave_frames(frames):
        wave_stream = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
        wave_stream.setnchannels(CHANNELS)
        wave_stream.setsampwidth(FORMAT)
        wave_stream.setframerate(RATE)
        wave_stream.writeframes(b''.join(frames))
        wave_stream.close()

# %%
# instantiate PyAudio
audio = pyaudio.PyAudio()

# %%
# open wave file
FILE_NAME = "19m_20181220_deominju_16000"
wf = wave.open("audio_file/"+ FILE_NAME + ".wav", 'rb')

# %%
# initialize variables
CHUNK = 1024   # 1024 bytes of data read from the buffer
FRAME_SIZE = CHUNK * 4
WAVE_OUTPUT_FILENAME = "wave_output.wav"    # temperary wave file for streaming 
FORMAT=audio.get_sample_size(wf.getsampwidth())
CHANNELS=wf.getnchannels()
RATE=wf.getframerate()
words_with_tags = []
transcripts_arr = []
frames = []
f_count = 0

# %%
# read data (first frames)
data = wf.readframes(CHUNK)

# transcribe stream  : wave file을 10M 이하로 잘라서, google STT API에 stream 방식으로 요청
while len(data) > 0:
    frames.append(data)
    f_count += 1
    if f_count == FRAME_SIZE:
        # write frames to wave file for frames
        write_wave_frames(frames)
        
        # transcribe by streaming
        words_with_tag, transcripts = transcribe_streaming(WAVE_OUTPUT_FILENAME)    # frames를 직접 전달 시 google에서 grpc.RpcError 발생하면 cancel 됨 
        words_with_tags.append(words_with_tag)
        transcripts_arr.append(transcripts)
        
        # frame initialize
        frames = []
        f_count = 0
    
    # read data (continue)
    data = wf.readframes(CHUNK)

# transcribe for last frames
write_wave_frames(frames)

# last frames
words_with_tag, transcripts = transcribe_streaming(WAVE_OUTPUT_FILENAME)
words_with_tags.append(words_with_tag)
transcripts_arr.append(transcripts)
# Out:
# Transcript: 네, 반갑습니다. 제 125차 정책조정회의 일을 상영표 원내대표에 모두 바로 가겠습니다. 11 12 월 이렇게 분위기가 이제 일주일 앞으로 다가왔습니다. 여야가 민생법안 처리를 위해서 노니의 속도를 더 내야겠습니다. 꼭 처리해야 할 일이 또 과제는 6300번 산업안전보건법입니다. 하나유치원 선법은 오늘의 연애 법안소위에서 어머니들 예정입니다. 오늘 합의가 이루어지지 않을 경우 27분에 철인가 사실상 어렵습니다. 자유한국당 너 우리 아이들이 하는 마음이 조금이라도 있다면 6003번 노니의 접수 임해야 합니다. 지난번 정기국회 때처럼 법안처리를
#
# Transcript: 연 시키려는 무슨 국민이 용납하지 않을 것입니다. 우리당은 오늘 처리될 수 있도록 최선을 다해서 열린 자세로 소방서에 임하겠습니다. 그러나 끝내. 자유한국당이 반대한다면 패스트트랙을 통해 번 처리하는 방안을 추진 하겠습니다. 위험의 외주화를 막을 산업안전보건법 또 반드시 처리하겠습니다. 하청노동자들의 더 이상 내몰리지 않기 위해서 필요한 법안입니다. 다행히 어제 환노위 고용노동소위 해서 27일 본회의에서 산업안전보건법을 처리하기로 여야간 의견이 모아졌습니다. 앞으로 논의과정에서 차질없이 처리될 수 있도록 기대합니다. 대부분.
#
# Transcript: 협상을 총괄하는 비건 미국 특별대표가 어제 방황하면서 주목할만한 메시지를 발표했습니다. 인도적 차원의 대북지원을 확실히 보장하고 미국인의 북한 여행 금지 조치를 재검토하겠다고 밝혔다입니다. 남궁민 사이를 갈라놓았던 친한 70년에 적대감을 뛰어넘을 수 있도록 북한과 확장하겠다는 결혼 그동안은 엄격한 대북제재 방침을 고수했던 미국이 유화책을 제시한 것입니다. 미국 정부가 인도적 차원의 대북지원을 내게 북미대화를 다시 진전 시키겠다는 강한 의지를 밝힌 것으로 해석됩니다. 북한이 어떤 반응을 보이는지 나의 따라 한동안 곁에 교착상태를 보이던 북미 대화가 재개 될 가능성도 충분히 있어 보입니다. 오늘과 내일 추석 대표회의 한미워킹그룹 2차 회의를 통해 한미양국이 국민
#
# Transcript: 새로운 돌파구를 마련하게 바랍니다. 미국측이 인도적 차원의 제 해제를 식사하면서 남북 교류 해도 탄력이 붙을 것으로 예상됩니다. 26일 열리는 남북 철도 착공시기 남북교류를 확대하고 북미 대화 친절을 가져오는 계기가 되기를 바랍니다. 미국 중앙은행이 오늘 새벽 기준 금리를 또 인상했습니다. 월드 더 많은 벌써네 번째 기준 금리 인상입니다. 사람일까 우리나라의 기준 금리 격차 넣어서 벌어졌습니다. 미국 금리 인상은 우리 경제의 여러 측면에서 영향을 미치게 됩니다. 물론 당장은 우리 경제에 큰 영향은 없을 것이란 전망이 오세암니다. 그러나 외국인 자금 유출과 이로 인해 금융시장이 불안해질 가능성을 배제할 수 없음.
#
# Transcript: 정부는 미국 금리인상이 우리 경제에 미칠 영향을 주셔야 합니다. 외국인 자금 흐름과 증시 등 금융 시장 상황을 면밀히 점검하고 미리 대응책을 마련할 주기 바랍니다. 1500 도를 넘어선 가계부채도 철저하게 관리해야 합니다. 최근 부동산 가격이 안 줘.
#
# Transcript: 되면서 가계부채증가 속도는 둔화되는 추세입니다. 그러나 앞으로 대출 금리가 더 오르는 상황에 대비해 합니다. 금리가 오르면 서민채 합계 정은이 장성환 부담이 가중될 수밖에 없습니다. 정부는 금융권 대출 규제를 다시 한번 점검해 주고 취약계층에 부담이 걱정 하지 않도록 꼼꼼히 살펴 주시기 바랍니다. 택시업계가 지난 당대표 간담회에서 제한된 사회적 대타협기구 참여를 약속했습니다. 그리고 오늘 예정된 대규모집회도 평화적으로 진행하겠다고 약속했습니다. 이런 합의를 이끌어 내기까지 우리 당의 전현희 의원께서 많은 노력을 했습니다. 사실 쉽지 않은 그런 탑이었습니다만은
#
# Transcript: 이 문제를 우리가 머리를 맞대고 대화와 타협을 통해서 볼 수 있는 중요한 초대를 만들었다고 생각합니다. 앞으로 택시 카플 어깨 함께 참여하는 사회적 대화 지구에서 서로 상생하고 또 혁신성장을 위한 그런 사회적 대타협이 만들어질 수 있도록 우리 다음 최선을 다하겠습니다. 다음은 김태년 정책위의장이 잘 알겠습니다. 조금 전 당정 관련업계와 협의를 통해서 자영업의 혁신과 성장을 견인할 종합대책을 마련했습니다. 문재인 정부 출범 이후에 가장 적극적으로
#
# Transcript: 책을 말이 나무야 중에 하나가 바로 소상공인자영업자 대책입니다. 그동안 종합대책 마음 내 차례 발표를 했었는데요. 일자리 안정자금 사회보험료 등의 직접 지원 또 상가 임대차 및 공정거래에 분야 제도개선 이런 정책들을 한 팩 46개 146개의 과제가 현재 추진되고 있고 여기에 인제 오늘 종합대책이 발표가 되고 있는데 그거 최근에 카드 수수료 종합개편방안 유한팩 책들로 자영업자들의 경영난을 회수할 시급한 과제 돈은 어느 정도 가닥이 잡혔다고 생각을 합니다. 이제는 자영업에 혁신과 성장이 가능한 생태계를 구축하는데 정책역량을 집중할 계획입니다. 또한 이번에 소상공인 자영업자 업계와 노니에서
#
# Transcript: 대책을 마련 한 것처럼 앞으로도 현장과 긴밀하게 소통하면서 정책을 수립하고 집행할 것입니다. 자영업 성장 혁신 종합대책에 자세한 내용은 지금 중기부 등기부와 관계부처에서 지금 발표를 하고 있을 텐데요 주요. 내용만 말씀 드리면 첫째로 구 도심상권 경기 소상공인 복합지원센터 설치 등을 통해서 자영업의 성장에 영향을 제거하는 것입니다. 두 번째로 제로페이 서비스 강화 지역사랑상품권 및 온누리상품권 발행 확대 등을 통해서 자영업자에 매출을 실제로 늘리고 비용 부담을 원하는게 세 번째로 창업지원교육 제기를 아우르는 통합 지원 체계를 구축하는 것이네 번째로 가맹본부
#
# Transcript: 가맹점주가 4 2 0 프랜차이즈 육성 등을 통해서 골목상권을 지키고 상생협력 문화를 문화를 확산에 나가는 것이 다섯 번째로 자영업자에 대한 사회적 안전망을 확대에 나가는 것이 자영업에 혁신과
#
# Transcript: 통장은 함께 잘 사는 혁신적 포용국가론 아가 중요한 과제 중의 하나입니다. 저희 더불어민주당은 오늘 발표한 대책이 차질없이 집행되도록 만전을 기하겠습니다. 위한 범부처 간 또당 정관 협업체계를 잘 구축하고 무엇보다도 현장에서 실질적으로 성과가 날 때까지 끈질기게 그렇게 점검하고 실행하겠다는 말씀드리고이를 위해서 필요한 입법과제 다른 야당과 긴밀하게 협력해에서 조속히 입법 절차를 마무리하길겠습니다. 강릉 펜션 사고에 대해서 말씀드리겠습니다. 먼저 안타까운 사고로 희생된 학생들의 명복을 빌고 빌게 깊은 위로의 말씀을 드립니다. 현재 병원에 입원 중인 학생들이 빨리 와.
#
# Transcript: 그래서 사랑하는 가족들 곁으로 돌아가기를 기원합니다. 이번 사고의 잠정적인 원인은 보일러와. 배기구 예. 연결 부위 문제로 인한 일산화탄소 노출입니다. 학생들이 숙박했던 펜션의 가스 누출 경보기가 설치 설치 되어 있지 않아 키웠습니다. 펜션은 농어촌민박업으로 분류되어서 가스 누출 경보기 설치 의무가 없고 남방 안전은 점검 항목에서 빠질 기쁨입니다. 펜션 민박 시설의 안전 관리 실태를 점검하고 제도개선 방안 마련이 시급하다고 판단됩니다. 다 그리고 단지 민박 시설에 대한 안전 대책을 마련하는 것에 그치지 않고 이번 기회에 다중이용시설 교통시설 산업 현장 국민이 생활하고 일하는 모든
#
# Transcript: 시설과 공간에 대해서 안전관리실태 전반을 점검하고 개선 방안을 마련하는 것이 시급한 과제입니다. 최근 발생한 사고들을 거울 삼아서 안전에 사각지대에 놓인 각종 위험요소들을 면밀하게 살펴보고 종합적인 대책을 수립 하겠습니다. 정부와 긴밀한 협의를 통해서 국민의 안전과 관련된 정책들을 다시 한번 재정비하고 계정이 필요한 사항은 조속한 시일 내에 마무리 짓겠습니다. 그리고 올해 초에 발표한 바 있는 국민생명 3대 프로젝트 진행 상황 상황으로 다시 한번 몇 미리 점검하도록 하겠습니다. 무엇보다도 정부의 대책이 사후약방문 되지 않도록 선제적으로 터치해서 사고를 예방 해야겠습니다.
#
# Transcript: 당과 정부는 국민안전의 최우선의 가치로 들고 안전한 대한민국을 만들기 위해 최선을 다 하겠습니다. 송도 오늘 축구 대표 예의바른 지청장 검찰내 b62 있어서 4pc * 감찰반원 한마디에 야당이 출석하며 국기문란 진상조사단을 뿌린다는 뚱 행위를 하고 있습니다. 야당에게 축구 합니다. 기록으로 검찰이 복귀한 특별 감찰 받은 한마디에 아 정치공세를 하는 행위를 즉각 중단해야 할 것입니다이 사건의 내용을 청와대파견 나온 특별감찰관은 뭐니? 김태우 수사관이 비위사실이 있어서 소속 중으로 다시 돌려 보내 주고 거기에 핑계를 요청한
#
# Transcript: 산입니다이 김태우 감찰 봐. 너는 이미 나왔던 기사들을 재탕하면서 촛불 하고 올리고 2017년 7월에 올렸던 내용 때문에 자신이 정치적으로 내초 졌다는 얼토당토않은 주장을 하고 있습니다이 김태우 수사관은 광교 자고 자기 뒤를 밀어주는업자인지는 모르겠으나 관계 청와대 근무 시간에 골프를 쳤습니다. 업자가 경찰
#
# Transcript: 호환되는 날 경찰청을 직접 방문해서 수사 내용들을 확인했습니다. 그리고 이강철 대상들과 주고 받은 문자 등이 있었고 이런 내용들을 밝혀진 내용입니다. 또다시 김태우의 내가 의혹들이 나오고 있습니다. 유착의 시민은 건설업자에게 명절 때마다 대통령님을 선물을 했다는 겁니다. 김태우 특별감찰반원이 KT가 남긴 채 보러 사입을 추구했다는 의욕으로 수사를 받고 있기도 합니다. 일부 언론은 민간인 사찰을 청와대가 불쌍한 것 아니냐? 이런 이야기하는데 민간인 사찰이라고 하는 것은 어떤 것인지 여러분께 오늘이 표를 제공해 드리도록 하겠습니다. 다 봄인가 사찰들이 어떤 것이었는지 위의 내용에 정확히 나와 있습니다. 다시 한번 말씀 드리면 4대강 반대 세력을 방해하고 비어퐁
#
# Transcript: 차단하고 환경단체 핵심인물 24명을 감찰하고 세무조사를 압박하고 우리가 기억합니다. KB 한마음 김종익 대표는 수시로 사찰을 받아서 자살시도를 여러 번 했던 기억도 있습니다. 그리고 기무사가 세월호 유가족 실종자 가족 단원구 학생들을 불법 사찰 했던 내용들 이런 내용이 바로 과거 박근혜 정부에서 최순실 비선 실세 다 국기문란을 하면서 미뤄졌던 민간인 사찰입니다. 민간인 사찰이 어떤 것인지 다시 한번 정확히 여러분이 파악하고 그리고 또 기차에 올려 주실 것을 당부드립니다. 은서 언론은 자신들이 수 없기 때문에 우리 독식 할지 모른다라고 하는 착각은 그만둘 것을 촉구합니다. 이상입니다.
#
# Transcript: 지 돈으로 사서 대통령령이 선물을 업체에게 전달 할 때는 마치 자기 돈으로 사서 마치게 통영 깼어. 선물하신 것처럼 이렇게 위장하는 술수도 보였다라고 하는 것을 말씀드리겠습니다. 대로 정말 9분 정도에 연장에 따른겠습니다. 어제 오후 늦게 택시 차 단체장들 깼어. 매우 어려운 결정을 내렸습니다. 택시 택시 타면 커플의 갈등을 해결하기 위해서 사회적 대타협기구에 참여하고 또 대화와 타협으로 서희 문제를 해결 하겠다. 재활을 세우셨습니다. 그리고 오늘 예정
#
# Transcript: 10만 명 규모의 여의도 집회도 평화적으로 진행하기로 하였습니다. 택시업계에 오늘 집회 되지만 그 동안 많은 우려가 있어고 채우기 기사님의 분신이 있었고 택시업계는 생존권 투쟁으로 이번 집회를 교정시험만큼 극단적인 상황이 벌어질 우려가 있습니다. 정치권에서는 집회를 취소하거나 적어도 최소한 평화적 집회가 되어야 한다라는 고민이 깊어집니다. 극한 상황에서도 대화에 끈을 놓지 않을 택시 이쪽에 인내심에 깊은 감사를 드립니다. 그리고 이러한 결단을 내려 주신 택시업계에 카풀 TF 위원장으로서 진심으로 결단을 높이 평가 합니다. 오늘고 채우기 택시기사님의 영결식이 역시 예정되어 있습니다. 다시 한번
#
# Transcript: 고인의 명복을 빌고 유가족들에게 깊은 위로를 드립니다. 다시는 이런 희생자가 발생하지 않도록 더불어민주당도 택시 산업 발전을 위해서 최선을 다하겠습니다. 감사합니다. 가는 길이 통과 중.
#
# Transcript: 설정 좀는 안 된다고 생각합니다. 전 국민의 관심을 가지고 지켜봐 주고 계시는 산업안전보건법 개정 않는 그런 내용을 담고 있습니다. 우리가 제도를 통해서 모든 산업체를 모든 산업재해를 통한 사망사고를 없앨수는 없겠습니다만 제도를 통해서 해도 할 수는 있습니다. 그 최소화하기 위한 정보 나도 네이버 보이 노력에 대해서 경제계는 이제 제발 응답해 주시기를 바랍니다이 법이 통과되면 않기를 바라면서 입법 젖이 노력하는 그 열정만큼 실제로 현장에서 산업체를 줄이기 위해서 산업재해로 인한 사망사고를 줄이기 위해서 사용자들이 무엇을 해야 하는지에 대해서 한 번 더 고민해 주시는 그런 시간을 가져 주기를 바랍니다. 21일 공청회 그리고
#
# Transcript: 법안소위 내가 최대한 노력을 해서 24일까지는 전체의 1일까지 마치고 하노이를 통과시킨 다음에 27일 보내면 상정이 될 수 있도록 최대한 노력을 할 것입니다. 이렇게 이뻐. 부가 노력하는 것에 대해서 경영계는 다시 한번 말씀드립니다. 응답해 주시기를 바라겠습니다네. 이상으로 제 115차 정책조정회의 붕괴 일을 모두 마치도록 하겠습니다. 여러분들의

# %%
# close PyAudio
audio.terminate()

# %%
corpus = ""
for transcripts in transcripts_arr:
    for transcript in transcripts:
        corpus += transcript + " "
# print(corpus)

# %%
sentence = sent_tokenize(corpus)    # 문장단위 분리
sentence
# Out:
# ['네, 반갑습니다.',
#  '제 125차 정책조정회의 일을 상영표 원내대표에 모두 바로 가겠습니다.',
#  '11 12 월 이렇게 분위기가 이제 일주일 앞으로 다가왔습니다.',
#  '여야가 민생법안 처리를 위해서 노니의 속도를 더 내야겠습니다.',
#  '꼭 처리해야 할 일이 또 과제는 6300번 산업안전보건법입니다.',
#  '하나유치원 선법은 오늘의 연애 법안소위에서 어머니들 예정입니다.',
#  '오늘 합의가 이루어지지 않을 경우 27분에 철인가 사실상 어렵습니다.',
#  '자유한국당 너 우리 아이들이 하는 마음이 조금이라도 있다면 6003번 노니의 접수 임해야 합니다.',
#  '지난번 정기국회 때처럼 법안처리를 연 시키려는 무슨 국민이 용납하지 않을 것입니다.',
#  '우리당은 오늘 처리될 수 있도록 최선을 다해서 열린 자세로 소방서에 임하겠습니다.',
#  '그러나 끝내.',
#  '자유한국당이 반대한다면 패스트트랙을 통해 번 처리하는 방안을 추진 하겠습니다.',
#  '위험의 외주화를 막을 산업안전보건법 또 반드시 처리하겠습니다.',
#  '하청노동자들의 더 이상 내몰리지 않기 위해서 필요한 법안입니다.',
#  '다행히 어제 환노위 고용노동소위 해서 27일 본회의에서 산업안전보건법을 처리하기로 여야간 의견이 모아졌습니다.',
#  '앞으로 논의과정에서 차질없이 처리될 수 있도록 기대합니다.',
#  '대부분.',
#  '협상을 총괄하는 비건 미국 특별대표가 어제 방황하면서 주목할만한 메시지를 발표했습니다.',
#  '인도적 차원의 대북지원을 확실히 보장하고 미국인의 북한 여행 금지 조치를 재검토하겠다고 밝혔다입니다.',
#  '남궁민 사이를 갈라놓았던 친한 70년에 적대감을 뛰어넘을 수 있도록 북한과 확장하겠다는 결혼 그동안은 엄격한 대북제재 방침을 고수했던 미국이 유화책을 제시한 것입니다.',
#  '미국 정부가 인도적 차원의 대북지원을 내게 북미대화를 다시 진전 시키겠다는 강한 의지를 밝힌 것으로 해석됩니다.',
#  '북한이 어떤 반응을 보이는지 나의 따라 한동안 곁에 교착상태를 보이던 북미 대화가 재개 될 가능성도 충분히 있어 보입니다.',
#  '오늘과 내일 추석 대표회의 한미워킹그룹 2차 회의를 통해 한미양국이 국민 새로운 돌파구를 마련하게 바랍니다.',
#  '미국측이 인도적 차원의 제 해제를 식사하면서 남북 교류 해도 탄력이 붙을 것으로 예상됩니다.',
#  '26일 열리는 남북 철도 착공시기 남북교류를 확대하고 북미 대화 친절을 가져오는 계기가 되기를 바랍니다.',
#  '미국 중앙은행이 오늘 새벽 기준 금리를 또 인상했습니다.',
#  '월드 더 많은 벌써네 번째 기준 금리 인상입니다.',
#  '사람일까 우리나라의 기준 금리 격차 넣어서 벌어졌습니다.',
#  '미국 금리 인상은 우리 경제의 여러 측면에서 영향을 미치게 됩니다.',
#  '물론 당장은 우리 경제에 큰 영향은 없을 것이란 전망이 오세암니다.',
#  '그러나 외국인 자금 유출과 이로 인해 금융시장이 불안해질 가능성을 배제할 수 없음.',
#  '정부는 미국 금리인상이 우리 경제에 미칠 영향을 주셔야 합니다.',
#  '외국인 자금 흐름과 증시 등 금융 시장 상황을 면밀히 점검하고 미리 대응책을 마련할 주기 바랍니다.',
#  '1500 도를 넘어선 가계부채도 철저하게 관리해야 합니다.',
#  '최근 부동산 가격이 안 줘.',
#  '되면서 가계부채증가 속도는 둔화되는 추세입니다.',
#  '그러나 앞으로 대출 금리가 더 오르는 상황에 대비해 합니다.',
#  '금리가 오르면 서민채 합계 정은이 장성환 부담이 가중될 수밖에 없습니다.',
#  '정부는 금융권 대출 규제를 다시 한번 점검해 주고 취약계층에 부담이 걱정 하지 않도록 꼼꼼히 살펴 주시기 바랍니다.',
#  '택시업계가 지난 당대표 간담회에서 제한된 사회적 대타협기구 참여를 약속했습니다.',
#  '그리고 오늘 예정된 대규모집회도 평화적으로 진행하겠다고 약속했습니다.',
#  '이런 합의를 이끌어 내기까지 우리 당의 전현희 의원께서 많은 노력을 했습니다.',
#  '사실 쉽지 않은 그런 탑이었습니다만은 이 문제를 우리가 머리를 맞대고 대화와 타협을 통해서 볼 수 있는 중요한 초대를 만들었다고 생각합니다.',
#  '앞으로 택시 카플 어깨 함께 참여하는 사회적 대화 지구에서 서로 상생하고 또 혁신성장을 위한 그런 사회적 대타협이 만들어질 수 있도록 우리 다음 최선을 다하겠습니다.',
#  '다음은 김태년 정책위의장이 잘 알겠습니다.',
#  '조금 전 당정 관련업계와 협의를 통해서 자영업의 혁신과 성장을 견인할 종합대책을 마련했습니다.',
#  '문재인 정부 출범 이후에 가장 적극적으로 책을 말이 나무야 중에 하나가 바로 소상공인자영업자 대책입니다.',
#  '그동안 종합대책 마음 내 차례 발표를 했었는데요.',
#  '일자리 안정자금 사회보험료 등의 직접 지원 또 상가 임대차 및 공정거래에 분야 제도개선 이런 정책들을 한 팩 46개 146개의 과제가 현재 추진되고 있고 여기에 인제 오늘 종합대책이 발표가 되고 있는데 그거 최근에 카드 수수료 종합개편방안 유한팩 책들로 자영업자들의 경영난을 회수할 시급한 과제 돈은 어느 정도 가닥이 잡혔다고 생각을 합니다.',
#  '이제는 자영업에 혁신과 성장이 가능한 생태계를 구축하는데 정책역량을 집중할 계획입니다.',
#  '또한 이번에 소상공인 자영업자 업계와 노니에서 대책을 마련 한 것처럼 앞으로도 현장과 긴밀하게 소통하면서 정책을 수립하고 집행할 것입니다.',
#  '자영업 성장 혁신 종합대책에 자세한 내용은 지금 중기부 등기부와 관계부처에서 지금 발표를 하고 있을 텐데요 주요.',
#  '내용만 말씀 드리면 첫째로 구 도심상권 경기 소상공인 복합지원센터 설치 등을 통해서 자영업의 성장에 영향을 제거하는 것입니다.',
#  '두 번째로 제로페이 서비스 강화 지역사랑상품권 및 온누리상품권 발행 확대 등을 통해서 자영업자에 매출을 실제로 늘리고 비용 부담을 원하는게 세 번째로 창업지원교육 제기를 아우르는 통합 지원 체계를 구축하는 것이네 번째로 가맹본부 가맹점주가 4 2 0 프랜차이즈 육성 등을 통해서 골목상권을 지키고 상생협력 문화를 문화를 확산에 나가는 것이 다섯 번째로 자영업자에 대한 사회적 안전망을 확대에 나가는 것이 자영업에 혁신과 통장은 함께 잘 사는 혁신적 포용국가론 아가 중요한 과제 중의 하나입니다.',
#  '저희 더불어민주당은 오늘 발표한 대책이 차질없이 집행되도록 만전을 기하겠습니다.',
#  '위한 범부처 간 또당 정관 협업체계를 잘 구축하고 무엇보다도 현장에서 실질적으로 성과가 날 때까지 끈질기게 그렇게 점검하고 실행하겠다는 말씀드리고이를 위해서 필요한 입법과제 다른 야당과 긴밀하게 협력해에서 조속히 입법 절차를 마무리하길겠습니다.',
#  '강릉 펜션 사고에 대해서 말씀드리겠습니다.',
#  '먼저 안타까운 사고로 희생된 학생들의 명복을 빌고 빌게 깊은 위로의 말씀을 드립니다.',
#  '현재 병원에 입원 중인 학생들이 빨리 와.',
#  '그래서 사랑하는 가족들 곁으로 돌아가기를 기원합니다.',
#  '이번 사고의 잠정적인 원인은 보일러와.',
#  '배기구 예.',
#  '연결 부위 문제로 인한 일산화탄소 노출입니다.',
#  '학생들이 숙박했던 펜션의 가스 누출 경보기가 설치 설치 되어 있지 않아 키웠습니다.',
#  '펜션은 농어촌민박업으로 분류되어서 가스 누출 경보기 설치 의무가 없고 남방 안전은 점검 항목에서 빠질 기쁨입니다.',
#  '펜션 민박 시설의 안전 관리 실태를 점검하고 제도개선 방안 마련이 시급하다고 판단됩니다.',
#  '다 그리고 단지 민박 시설에 대한 안전 대책을 마련하는 것에 그치지 않고 이번 기회에 다중이용시설 교통시설 산업 현장 국민이 생활하고 일하는 모든 시설과 공간에 대해서 안전관리실태 전반을 점검하고 개선 방안을 마련하는 것이 시급한 과제입니다.',
#  '최근 발생한 사고들을 거울 삼아서 안전에 사각지대에 놓인 각종 위험요소들을 면밀하게 살펴보고 종합적인 대책을 수립 하겠습니다.',
#  '정부와 긴밀한 협의를 통해서 국민의 안전과 관련된 정책들을 다시 한번 재정비하고 계정이 필요한 사항은 조속한 시일 내에 마무리 짓겠습니다.',
#  '그리고 올해 초에 발표한 바 있는 국민생명 3대 프로젝트 진행 상황 상황으로 다시 한번 몇 미리 점검하도록 하겠습니다.',
#  '무엇보다도 정부의 대책이 사후약방문 되지 않도록 선제적으로 터치해서 사고를 예방 해야겠습니다.',
#  '당과 정부는 국민안전의 최우선의 가치로 들고 안전한 대한민국을 만들기 위해 최선을 다 하겠습니다.',
#  '송도 오늘 축구 대표 예의바른 지청장 검찰내 b62 있어서 4pc * 감찰반원 한마디에 야당이 출석하며 국기문란 진상조사단을 뿌린다는 뚱 행위를 하고 있습니다.',
#  '야당에게 축구 합니다.',
#  '기록으로 검찰이 복귀한 특별 감찰 받은 한마디에 아 정치공세를 하는 행위를 즉각 중단해야 할 것입니다이 사건의 내용을 청와대파견 나온 특별감찰관은 뭐니?',
#  '김태우 수사관이 비위사실이 있어서 소속 중으로 다시 돌려 보내 주고 거기에 핑계를 요청한 산입니다이 김태우 감찰 봐.',
#  '너는 이미 나왔던 기사들을 재탕하면서 촛불 하고 올리고 2017년 7월에 올렸던 내용 때문에 자신이 정치적으로 내초 졌다는 얼토당토않은 주장을 하고 있습니다이 김태우 수사관은 광교 자고 자기 뒤를 밀어주는업자인지는 모르겠으나 관계 청와대 근무 시간에 골프를 쳤습니다.',
#  '업자가 경찰 호환되는 날 경찰청을 직접 방문해서 수사 내용들을 확인했습니다.',
#  '그리고 이강철 대상들과 주고 받은 문자 등이 있었고 이런 내용들을 밝혀진 내용입니다.',
#  '또다시 김태우의 내가 의혹들이 나오고 있습니다.',
#  '유착의 시민은 건설업자에게 명절 때마다 대통령님을 선물을 했다는 겁니다.',
#  '김태우 특별감찰반원이 KT가 남긴 채 보러 사입을 추구했다는 의욕으로 수사를 받고 있기도 합니다.',
#  '일부 언론은 민간인 사찰을 청와대가 불쌍한 것 아니냐?',
#  '이런 이야기하는데 민간인 사찰이라고 하는 것은 어떤 것인지 여러분께 오늘이 표를 제공해 드리도록 하겠습니다.',
#  '다 봄인가 사찰들이 어떤 것이었는지 위의 내용에 정확히 나와 있습니다.',
#  '다시 한번 말씀 드리면 4대강 반대 세력을 방해하고 비어퐁 차단하고 환경단체 핵심인물 24명을 감찰하고 세무조사를 압박하고 우리가 기억합니다.',
#  'KB 한마음 김종익 대표는 수시로 사찰을 받아서 자살시도를 여러 번 했던 기억도 있습니다.',
#  '그리고 기무사가 세월호 유가족 실종자 가족 단원구 학생들을 불법 사찰 했던 내용들 이런 내용이 바로 과거 박근혜 정부에서 최순실 비선 실세 다 국기문란을 하면서 미뤄졌던 민간인 사찰입니다.',
#  '민간인 사찰이 어떤 것인지 다시 한번 정확히 여러분이 파악하고 그리고 또 기차에 올려 주실 것을 당부드립니다.',
#  '은서 언론은 자신들이 수 없기 때문에 우리 독식 할지 모른다라고 하는 착각은 그만둘 것을 촉구합니다.',
#  '이상입니다.',
#  '지 돈으로 사서 대통령령이 선물을 업체에게 전달 할 때는 마치 자기 돈으로 사서 마치게 통영 깼어.',
#  '선물하신 것처럼 이렇게 위장하는 술수도 보였다라고 하는 것을 말씀드리겠습니다.',
#  '대로 정말 9분 정도에 연장에 따른겠습니다.',
#  '어제 오후 늦게 택시 차 단체장들 깼어.',
#  '매우 어려운 결정을 내렸습니다.',
#  '택시 택시 타면 커플의 갈등을 해결하기 위해서 사회적 대타협기구에 참여하고 또 대화와 타협으로 서희 문제를 해결 하겠다.',
#  '재활을 세우셨습니다.',
#  '그리고 오늘 예정 10만 명 규모의 여의도 집회도 평화적으로 진행하기로 하였습니다.',
#  '택시업계에 오늘 집회 되지만 그 동안 많은 우려가 있어고 채우기 기사님의 분신이 있었고 택시업계는 생존권 투쟁으로 이번 집회를 교정시험만큼 극단적인 상황이 벌어질 우려가 있습니다.',
#  '정치권에서는 집회를 취소하거나 적어도 최소한 평화적 집회가 되어야 한다라는 고민이 깊어집니다.',
#  '극한 상황에서도 대화에 끈을 놓지 않을 택시 이쪽에 인내심에 깊은 감사를 드립니다.',
#  '그리고 이러한 결단을 내려 주신 택시업계에 카풀 TF 위원장으로서 진심으로 결단을 높이 평가 합니다.',
#  '오늘고 채우기 택시기사님의 영결식이 역시 예정되어 있습니다.',
#  '다시 한번 고인의 명복을 빌고 유가족들에게 깊은 위로를 드립니다.',
#  '다시는 이런 희생자가 발생하지 않도록 더불어민주당도 택시 산업 발전을 위해서 최선을 다하겠습니다.',
#  '감사합니다.',
#  '가는 길이 통과 중.',
#  '설정 좀는 안 된다고 생각합니다.',
#  '전 국민의 관심을 가지고 지켜봐 주고 계시는 산업안전보건법 개정 않는 그런 내용을 담고 있습니다.',
#  '우리가 제도를 통해서 모든 산업체를 모든 산업재해를 통한 사망사고를 없앨수는 없겠습니다만 제도를 통해서 해도 할 수는 있습니다.',
#  '그 최소화하기 위한 정보 나도 네이버 보이 노력에 대해서 경제계는 이제 제발 응답해 주시기를 바랍니다이 법이 통과되면 않기를 바라면서 입법 젖이 노력하는 그 열정만큼 실제로 현장에서 산업체를 줄이기 위해서 산업재해로 인한 사망사고를 줄이기 위해서 사용자들이 무엇을 해야 하는지에 대해서 한 번 더 고민해 주시는 그런 시간을 가져 주기를 바랍니다.',
#  '21일 공청회 그리고 법안소위 내가 최대한 노력을 해서 24일까지는 전체의 1일까지 마치고 하노이를 통과시킨 다음에 27일 보내면 상정이 될 수 있도록 최대한 노력을 할 것입니다.',
#  '이렇게 이뻐.',
#  '부가 노력하는 것에 대해서 경영계는 다시 한번 말씀드립니다.',
#  '응답해 주시기를 바라겠습니다네.',
#  '이상으로 제 115차 정책조정회의 붕괴 일을 모두 마치도록 하겠습니다.',
#  '여러분들의']

# %%
# 스크립트 만 Text 파일로 저장 (with newline)
text_file = "text/" + FILE_NAME + ".txt"
with open(text_file, 'w', encoding='utf-8') as f:
    for sent in sentence:
        f.write(sent + "\n")

# %%
# print(words_with_tags)
words_array = [wt for wts in words_with_tags for wt in wts]
words_array
# Out:
# [['네', 0.4, 1.7, 1],
#  ['반갑습니다', 1.7, 7.1, 1],
#  ['제', 7.1, 7.7, 1],
#  ['125차', 7.7, 8.4, 1],
#  ['정책조정회의', 8.4, 9.4, 1],
#  ['일을', 9.4, 9.8, 1],
#  ['상영표', 9.8, 10.2, 1],
#  ['원내대표에', 10.2, 10.9, 1],
#  ['모두', 10.9, 11.1, 1],
#  ['바로', 11.1, 11.4, 1],
#  ['가겠습니다', 11.4, 12.0, 1],
#  ['11', 12.0, 15.3, 1],
#  ['12', 15.3, 16.2, 1],
#  ['월', 16.2, 16.5, 1],
#  ['이렇게', 16.5, 17.4, 1],
#  ['분위기가', 17.4, 17.7, 1],
#  ['이제', 17.7, 19.2, 1],
#  ['일주일', 19.2, 19.6, 1],
#  ['앞으로', 19.6, 19.9, 1],
#  ['다가왔습니다', 19.9, 20.5, 1],
#  ['여야가', 20.5, 22.5, 1],
#  ['민생법안', 22.5, 23.5, 1],
#  ['처리를', 23.5, 24.0, 1],
#  ['위해서', 24.0, 24.4, 1],
#  ['노니의', 24.4, 25.3, 1],
#  ['속도를', 25.3, 26.0, 1],
#  ['더', 26.0, 26.2, 1],
#  ['내야겠습니다', 26.2, 26.8, 1],
#  ['꼭', 26.8, 28.5, 1],
#  ['처리해야', 28.5, 29.2, 1],
#  ['할', 29.2, 29.5, 1],
#  ['일이', 29.5, 29.7, 1],
#  ['또', 29.7, 30.0, 1],
#  ['과제는', 30.0, 30.5, 1],
#  ['6300번', 30.5, 32.0, 1],
#  ['산업안전보건법', 32.0, 33.5, 1],
#  ['입니다', 33.5, 34.0, 1],
#  ['하나유치원', 34.0, 35.3, 1],
#  ['선법은', 35.3, 35.9, 1],
#  ['오늘', 35.9, 36.2, 1],
#  ['의', 36.2, 36.5, 1],
#  ['연애', 36.5, 36.8, 1],
#  ['법안소위에서', 36.8, 38.0, 1],
#  ['어머니들', 38.0, 38.9, 1],
#  ['예정입니다', 38.9, 39.7, 1],
#  ['오늘', 39.7, 40.6, 1],
#  ['합의가', 40.6, 41.2, 1],
#  ['이루어지지', 41.2, 41.8, 1],
#  ['않을', 41.8, 42.1, 1],
#  ['경우', 42.1, 42.5, 1],
#  ['이십칠분', 43.8, 44.0, 1],
#  ['에', 44.0, 44.1, 1],
#  ['철인가', 44.1, 44.8, 1],
#  ['사실상', 44.8, 45.4, 1],
#  ['어렵습니다', 45.4, 46.1, 1],
#  ['자유한국당', 46.1, 47.9, 1],
#  ['너', 47.9, 48.1, 1],
#  ['우리', 48.1, 48.4, 1],
#  ['아이들이', 48.4, 48.9, 1],
#  ['하는', 48.9, 49.1, 1],
#  ['마음이', 49.1, 49.7, 1],
#  ['조금이라도', 49.7, 50.3, 1],
#  ['있다면', 50.3, 50.6, 1],
#  ['6003번', 50.6, 52.0, 1],
#  ['노니의', 52.0, 52.5, 1],
#  ['접수', 52.5, 53.3, 1],
#  ['임해야', 53.3, 53.9, 1],
#  ['합니다', 53.9, 54.1, 1],
#  ['지난번', 54.1, 56.5, 1],
#  ['정기국회', 56.5, 57.1, 1],
#  ['때처럼', 57.1, 57.6, 1],
#  ['법안처리를', 57.6, 59.9, 1],
#  ['네', 0.4, 1.7, 1],
#  ['반갑습니다', 1.7, 7.1, 1],
#  ['제', 7.1, 7.7, 1],
#  ['125차', 7.7, 8.4, 1],
#  ['정책조정회의', 8.4, 9.4, 1],
#  ['일을', 9.4, 9.8, 1],
#  ['상영표', 9.8, 10.2, 1],
#  ['원내대표에', 10.2, 10.9, 1],
#  ['모두', 10.9, 11.1, 1],
#  ['바로', 11.1, 11.4, 1],
#  ['가겠습니다', 11.4, 12.0, 1],
#  ['11', 12.0, 15.3, 1],
#  ['12', 15.3, 16.2, 1],
#  ['월', 16.2, 16.5, 1],
#  ['이렇게', 16.5, 17.4, 1],
#  ['분위기가', 17.4, 17.7, 1],
#  ['이제', 17.7, 19.2, 1],
#  ['일주일', 19.2, 19.6, 1],
#  ['앞으로', 19.6, 19.9, 1],
#  ['다가왔습니다', 19.9, 20.5, 1],
#  ['여야가', 20.5, 22.5, 1],
#  ['민생법안', 22.5, 23.5, 1],
#  ['처리를', 23.5, 24.0, 1],
#  ['위해서', 24.0, 24.4, 1],
#  ['노니의', 24.4, 25.3, 1],
#  ['속도를', 25.3, 26.0, 1],
#  ['더', 26.0, 26.2, 1],
#  ['내야겠습니다', 26.2, 26.8, 1],
#  ['꼭', 26.8, 28.5, 1],
#  ['처리해야', 28.5, 29.2, 1],
#  ['할', 29.2, 29.5, 1],
#  ['일이', 29.5, 29.7, 1],
#  ['또', 29.7, 30.0, 1],
#  ['과제는', 30.0, 30.5, 1],
#  ['6300번', 30.5, 32.0, 1],
#  ['산업안전보건법', 32.0, 33.5, 1],
#  ['입니다', 33.5, 34.0, 1],
#  ['하나유치원', 34.0, 35.3, 1],
#  ['선법은', 35.3, 35.9, 1],
#  ['오늘', 35.9, 36.2, 1],
#  ['의', 36.2, 36.5, 1],
#  ['연애', 36.5, 36.8, 1],
#  ['법안소위에서', 36.8, 38.0, 1],
#  ['어머니들', 38.0, 38.9, 1],
#  ['예정입니다', 38.9, 39.7, 1],
#  ['오늘', 39.7, 40.6, 1],
#  ['합의가', 40.6, 41.2, 1],
#  ['이루어지지', 41.2, 41.8, 1],
#  ['않을', 41.8, 42.1, 1],
#  ['경우', 42.1, 42.5, 1],
#  ['이십칠분', 43.8, 44.0, 1],
#  ['에', 44.0, 44.1, 1],
#  ['철인가', 44.1, 44.8, 1],
#  ['사실상', 44.8, 45.4, 1],
#  ['어렵습니다', 45.4, 46.1, 1],
#  ['자유한국당', 46.1, 47.9, 1],
#  ['너', 47.9, 48.1, 1],
#  ['우리', 48.1, 48.4, 1],
#  ['아이들이', 48.4, 48.9, 1],
#  ['하는', 48.9, 49.1, 1],
#  ['마음이', 49.1, 49.7, 1],
#  ['조금이라도', 49.7, 50.3, 1],
#  ['있다면', 50.3, 50.6, 1],
#  ['6003번', 50.6, 52.0, 1],
#  ['노니의', 52.0, 52.5, 1],
#  ['접수', 52.5, 53.3, 1],
#  ['임해야', 53.3, 53.9, 1],
#  ['합니다', 53.9, 54.1, 1],
#  ['지난번', 54.1, 56.5, 1],
#  ['정기국회', 56.5, 57.1, 1],
#  ['때처럼', 57.1, 57.6, 1],
#  ['법안처리를', 57.6, 59.9, 1],
#  ['연', 60.4, 60.8, 1],
#  ['시키려는', 60.8, 61.7, 1],
#  ['무슨', 61.7, 62.4, 1],
#  ['국민이', 62.4, 63.6, 1],
#  ['용납하지', 63.6, 64.5, 1],
#  ['않을', 64.5, 64.8, 1],
#  ['것입니다', 64.8, 65.1, 1],
#  ['우리당은', 65.1, 67.2, 1],
#  ['오늘', 67.2, 67.9, 1],
#  ['처리될', 67.9, 69.2, 1],
#  ['수', 69.2, 69.3, 1],
#  ['있도록', 69.3, 69.4, 1],
#  ['최선을', 69.4, 70.5, 1],
#  ['다해서', 70.5, 70.9, 1],
#  ['열린', 70.9, 71.5, 1],
#  ['자세로', 71.5, 71.9, 1],
#  ['소방서에', 71.9, 73.3, 1],
#  ['임하겠습니다', 73.3, 73.9, 1],
#  ['그러나', 73.9, 76.4, 1],
#  ['끝내', 76.4, 77.3, 1],
#  ['자유한국당이', 77.3, 78.5, 1],
#  ['반대한다면', 78.5, 79.6, 1],
#  ['패스트트랙을', 79.6, 82.4, 1],
#  ['통해', 82.4, 83.6, 1],
#  ['번', 83.6, 84.5, 1],
#  ['처리하는', 84.5, 85.5, 1],
#  ['방안을', 85.5, 86.1, 1],
#  ['추진', 86.1, 87.5, 1],
#  ['하겠습니다', 87.5, 88.0, 1],
#  ['위험의', 88.0, 89.9, 1],
#  ['외주화', 89.9, 89.9, 1],
#  ['를', 89.9, 90.5, 1],
#  ['막을', 90.5, 90.9, 1],
#  ['산업안전보건법', 90.9, 92.9, 1],
#  ['또', 92.9, 93.0, 1],
#  ['반드시', 93.0, 93.6, 1],
#  ['처리하겠습니다', 93.6, 94.2, 1],
#  ['하청노동자들의', 94.2, 96.6, 1],
#  ['더', 96.6, 97.0, 1],
#  ['이상', 97.0, 97.3, 1],
#  ['내몰리지', 97.3, 98.8, 1],
#  ['않기', 98.8, 99.2, 1],
#  ['위해서', 99.2, 99.6, 1],
#  ['필요한', 99.6, 99.9, 1],
#  ['법안입니다', 99.9, 100.4, 1],
#  ['다행히', 100.4, 101.9, 1],
#  ['어제', 101.9, 102.4, 1],
#  ['환노위', 102.4, 102.9, 1],
#  ['고용노동소위', 102.9, 103.9, 1],
#  ['해서', 103.9, 104.2, 1],
#  ['27일', 104.2, 105.0, 1],
#  ['본회의에서', 105.0, 105.4, 1],
#  ['산업안전보건법을', 105.4, 107.6, 1],
#  ['처리하기로', 107.6, 108.4, 1],
#  ['여야간', 108.4, 109.1, 1],
#  ['의견이', 109.1, 110.0, 1],
#  ['모아졌습니다', 110.0, 110.5, 1],
#  ['앞으로', 110.5, 111.7, 1],
#  ['논의과정에서', 111.7, 112.5, 1],
#  ['차질없이', 112.5, 113.6, 1],
#  ['처리될', 113.6, 115.2, 1],
#  ['수', 115.2, 115.3, 1],
#  ['있도록', 115.3, 115.5, 1],
#  ['기대합니다', 115.5, 117.5, 1],
#  ['대부분', 117.5, 120.1, 1],
#  ['네', 0.4, 1.7, 1],
#  ['반갑습니다', 1.7, 7.1, 1],
#  ['제', 7.1, 7.7, 1],
#  ['125차', 7.7, 8.4, 1],
#  ['정책조정회의', 8.4, 9.4, 1],
#  ['일을', 9.4, 9.8, 1],
#  ['상영표', 9.8, 10.2, 1],
#  ['원내대표에', 10.2, 10.9, 1],
#  ['모두', 10.9, 11.1, 1],
#  ['바로', 11.1, 11.4, 1],
#  ['가겠습니다', 11.4, 12.0, 1],
#  ['11', 12.0, 15.3, 1],
#  ['12', 15.3, 16.2, 1],
#  ['월', 16.2, 16.5, 1],
#  ['이렇게', 16.5, 17.4, 1],
#  ['분위기가', 17.4, 17.7, 1],
#  ['이제', 17.7, 19.2, 1],
#  ['일주일', 19.2, 19.6, 1],
#  ['앞으로', 19.6, 19.9, 1],
#  ['다가왔습니다', 19.9, 20.5, 1],
#  ['여야가', 20.5, 22.5, 1],
#  ['민생법안', 22.5, 23.5, 1],
#  ['처리를', 23.5, 24.0, 1],
#  ['위해서', 24.0, 24.4, 1],
#  ['노니의', 24.4, 25.3, 1],
#  ['속도를', 25.3, 26.0, 1],
#  ['더', 26.0, 26.2, 1],
#  ['내야겠습니다', 26.2, 26.8, 1],
#  ['꼭', 26.8, 28.5, 1],
#  ['처리해야', 28.5, 29.2, 1],
#  ['할', 29.2, 29.5, 1],
#  ['일이', 29.5, 29.7, 1],
#  ['또', 29.7, 30.0, 1],
#  ['과제는', 30.0, 30.5, 1],
#  ['6300번', 30.5, 32.0, 1],
#  ['산업안전보건법', 32.0, 33.5, 1],
#  ['입니다', 33.5, 34.0, 1],
#  ['하나유치원', 34.0, 35.3, 1],
#  ['선법은', 35.3, 35.9, 1],
#  ['오늘', 35.9, 36.2, 1],
#  ['의', 36.2, 36.5, 1],
#  ['연애', 36.5, 36.8, 1],
#  ['법안소위에서', 36.8, 38.0, 1],
#  ['어머니들', 38.0, 38.9, 1],
#  ['예정입니다', 38.9, 39.7, 1],
#  ['오늘', 39.7, 40.6, 1],
#  ['합의가', 40.6, 41.2, 1],
#  ['이루어지지', 41.2, 41.8, 1],
#  ['않을', 41.8, 42.1, 1],
#  ['경우', 42.1, 42.5, 1],
#  ['이십칠분', 43.8, 44.0, 1],
#  ['에', 44.0, 44.1, 1],
#  ['철인가', 44.1, 44.8, 1],
#  ['사실상', 44.8, 45.4, 1],
#  ['어렵습니다', 45.4, 46.1, 1],
#  ['자유한국당', 46.1, 47.9, 1],
#  ['너', 47.9, 48.1, 1],
#  ['우리', 48.1, 48.4, 1],
#  ['아이들이', 48.4, 48.9, 1],
#  ['하는', 48.9, 49.1, 1],
#  ['마음이', 49.1, 49.7, 1],
#  ['조금이라도', 49.7, 50.3, 1],
#  ['있다면', 50.3, 50.6, 1],
#  ['6003번', 50.6, 52.0, 1],
#  ['노니의', 52.0, 52.5, 1],
#  ['접수', 52.5, 53.3, 1],
#  ['임해야', 53.3, 53.9, 1],
#  ['합니다', 53.9, 54.1, 1],
#  ['지난번', 54.1, 56.5, 1],
#  ['정기국회', 56.5, 57.1, 1],
#  ['때처럼', 57.1, 57.6, 1],
#  ['법안처리를', 57.6, 59.9, 1],
#  ['연', 60.4, 60.8, 1],
#  ['시키려는', 60.8, 61.7, 1],
#  ['무슨', 61.7, 62.4, 1],
#  ['국민이', 62.4, 63.6, 1],
#  ['용납하지', 63.6, 64.5, 1],
#  ['않을', 64.5, 64.8, 1],
#  ['것입니다', 64.8, 65.1, 1],
#  ['우리당은', 65.1, 67.2, 1],
#  ['오늘', 67.2, 67.9, 1],
#  ['처리될', 67.9, 69.2, 1],
#  ['수', 69.2, 69.3, 1],
#  ['있도록', 69.3, 69.4, 1],
#  ['최선을', 69.4, 70.5, 1],
#  ['다해서', 70.5, 70.9, 1],
#  ['열린', 70.9, 71.5, 1],
#  ['자세로', 71.5, 71.9, 1],
#  ['소방서에', 71.9, 73.3, 1],
#  ['임하겠습니다', 73.3, 73.9, 1],
#  ['그러나', 73.9, 76.4, 1],
#  ['끝내', 76.4, 77.3, 1],
#  ['자유한국당이', 77.3, 78.5, 1],
#  ['반대한다면', 78.5, 79.6, 1],
#  ['패스트트랙을', 79.6, 82.4, 1],
#  ['통해', 82.4, 83.6, 1],
#  ['번', 83.6, 84.5, 1],
#  ['처리하는', 84.5, 85.5, 1],
#  ['방안을', 85.5, 86.1, 1],
#  ['추진', 86.1, 87.5, 1],
#  ['하겠습니다', 87.5, 88.0, 1],
#  ['위험의', 88.0, 89.9, 1],
#  ['외주화', 89.9, 89.9, 1],
#  ['를', 89.9, 90.5, 1],
#  ['막을', 90.5, 90.9, 1],
#  ['산업안전보건법', 90.9, 92.9, 1],
#  ['또', 92.9, 93.0, 1],
#  ['반드시', 93.0, 93.6, 1],
#  ['처리하겠습니다', 93.6, 94.2, 1],
#  ['하청노동자들의', 94.2, 96.6, 1],
#  ['더', 96.6, 97.0, 1],
#  ['이상', 97.0, 97.3, 1],
#  ['내몰리지', 97.3, 98.8, 1],
#  ['않기', 98.8, 99.2, 1],
#  ['위해서', 99.2, 99.6, 1],
#  ['필요한', 99.6, 99.9, 1],
#  ['법안입니다', 99.9, 100.4, 1],
#  ['다행히', 100.4, 101.9, 1],
#  ['어제', 101.9, 102.4, 1],
#  ['환노위', 102.4, 102.9, 1],
#  ['고용노동소위', 102.9, 103.9, 1],
#  ['해서', 103.9, 104.2, 1],
#  ['27일', 104.2, 105.0, 1],
#  ['본회의에서', 105.0, 105.4, 1],
#  ['산업안전보건법을', 105.4, 107.6, 1],
#  ['처리하기로', 107.6, 108.4, 1],
#  ['여야간', 108.4, 109.1, 1],
#  ['의견이', 109.1, 110.0, 1],
#  ['모아졌습니다', 110.0, 110.5, 1],
#  ['앞으로', 110.5, 111.7, 1],
#  ['논의과정에서', 111.7, 112.5, 1],
#  ['차질없이', 112.5, 113.6, 1],
#  ['처리될', 113.6, 115.2, 1],
#  ['수', 115.2, 115.3, 1],
#  ['있도록', 115.3, 115.5, 1],
#  ['기대합니다', 115.5, 117.5, 1],
#  ['대부분', 117.5, 120.1, 1],
#  ['협상을', 120.4, 121.1, 1],
#  ['총괄하는', 121.1, 121.6, 1],
#  ['비건', 121.6, 122.4, 1],
#  ['미국', 122.4, 122.8, 1],
#  ['특별대표가', 122.8, 123.6, 1],
#  ['어제', 123.6, 123.9, 1],
#  ['방황하면서', 123.9, 124.6, 1],
#  ['주목할만한', 124.6, 125.9, 1],
#  ['메시지', 125.9, 126.5, 1],
#  ['를', 126.5, 126.6, 1],
#  ['발표했습니다', 126.6, 127.3, 1],
#  ['인도적', 127.3, 128.5, 1],
#  ['차원의', 128.5, 128.9, 1],
#  ['대북지원을', 128.9, 129.7, 1],
#  ['확실히', 129.7, 130.1, 1],
#  ['보장하고', 130.1, 130.7, 1],
#  ['미국인의', 130.7, 131.8, 1],
#  ['북한', 131.8, 132.5, 1],
#  ['여행', 132.5, 132.8, 1],
#  ['금지', 132.8, 133.1, 1],
#  ['조치를', 133.1, 133.6, 1],
#  ['재검토하겠다고', 133.6, 134.8, 1],
#  ['밝혔다', 134.8, 135.0, 1],
#  ['입니다', 135.0, 135.6, 1],
#  ['남궁민', 135.6, 137.4, 1],
#  ['사이를', 137.4, 137.8, 1],
#  ['갈라놓았던', 137.8, 138.4, 1],
#  ['친한', 138.4, 138.9, 1],
#  ['70년에', 138.9, 139.5, 1],
#  ['적대감을', 139.5, 140.2, 1],
#  ['뛰어넘을', 140.2, 141.1, 1],
#  ['수', 141.1, 141.2, 1],
#  ['있도록', 141.2, 141.7, 1],
#  ['북한과', 141.7, 142.9, 1],
#  ['확장하겠다는', 142.9, 143.7, 1],
#  ['결혼', 143.7, 144.3, 1],
#  ['그동안은', 144.3, 146.4, 1],
#  ['엄격한', 146.4, 147.0, 1],
#  ['대북제재', 147.0, 147.6, 1],
#  ['방침을', 147.6, 148.1, 1],
#  ['고수했던', 148.1, 148.8, 1],
#  ['미국이', 148.8, 149.3, 1],
#  ['유화책을', 149.3, 150.8, 1],
#  ['제시한', 150.8, 151.3, 1],
#  ['것입니다', 151.3, 151.8, 1],
#  ['미국', 151.8, 153.0, 1],
#  ['정부가', 153.0, 153.4, 1],
#  ['인도적', 153.4, 154.5, 1],
#  ['차원의', 154.5, 154.9, 1],
#  ['대북지원을', 154.9, 156.0, 1],
#  ['내게', 156.0, 156.3, 1],
#  ['북미대화를', 156.3, 157.8, 1],
#  ['다시', 157.8, 158.4, 1],
#  ['진전', 158.4, 159.0, 1],
#  ['시키겠다는', 159.0, 159.6, 1],
#  ['강한', 159.6, 160.3, 1],
#  ['의지를', 160.3, 160.6, 1],
#  ['밝힌', 160.6, 161.4, 1],
#  ['것으로', 161.4, 161.9, 1],
#  ['해석됩니다', 161.9, 162.7, 1],
#  ['북한이', 162.7, 164.1, 1],
#  ['어떤', 164.1, 164.4, 1],
#  ['반응을', 164.4, 164.7, 1],
#  ['보이는지', 164.7, 165.0, 1],
#  ['나의', 165.0, 165.3, 1],
#  ['따라', 165.3, 165.7, 1],
#  ['한동안', 165.7, 166.4, 1],
#  ['곁에', 166.4, 166.7, 1],
#  ['교착상태를', 166.7, 167.7, 1],
#  ['보이던', 167.7, 168.2, 1],
#  ['북미', 168.2, 168.5, 1],
#  ['대화가', 168.5, 169.3, 1],
#  ['재개', 169.3, 170.0, 1],
#  ['될', 170.0, 170.2, 1],
#  ['가능성도', 170.2, 170.9, 1],
#  ['충분히', 170.9, 171.5, 1],
#  ['있어', 171.5, 171.7, 1],
#  ['보입니다', 171.7, 172.3, 1],
#  ['오늘과', 172.3, 173.6, 1],
#  ['내일', 173.6, 174.0, 1],
#  ['추석', 174.0, 174.8, 1],
#  ['대표회의', 174.8, 175.6, 1],
#  ['한미워킹그룹', 175.6, 176.8, 1],
#  ['2차', 176.8, 177.4, 1],
#  ['회의를', 177.4, 177.8, 1],
#  ['통해', 177.8, 178.1, 1],
#  ['한미양국이', 178.1, 179.0, 1],
#  ['국민', 179.0, 179.8, 1],
#  ['네', 0.4, 1.7, 1],
#  ['반갑습니다', 1.7, 7.1, 1],
#  ['제', 7.1, 7.7, 1],
#  ['125차', 7.7, 8.4, 1],
#  ['정책조정회의', 8.4, 9.4, 1],
#  ['일을', 9.4, 9.8, 1],
#  ['상영표', 9.8, 10.2, 1],
#  ['원내대표에', 10.2, 10.9, 1],
#  ['모두', 10.9, 11.1, 1],
#  ['바로', 11.1, 11.4, 1],
#  ['가겠습니다', 11.4, 12.0, 1],
#  ['11', 12.0, 15.3, 1],
#  ['12', 15.3, 16.2, 1],
#  ['월', 16.2, 16.5, 1],
#  ['이렇게', 16.5, 17.4, 1],
#  ['분위기가', 17.4, 17.7, 1],
#  ['이제', 17.7, 19.2, 1],
#  ['일주일', 19.2, 19.6, 1],
#  ['앞으로', 19.6, 19.9, 1],
#  ['다가왔습니다', 19.9, 20.5, 1],
#  ['여야가', 20.5, 22.5, 1],
#  ['민생법안', 22.5, 23.5, 1],
#  ['처리를', 23.5, 24.0, 1],
#  ['위해서', 24.0, 24.4, 1],
#  ['노니의', 24.4, 25.3, 1],
#  ['속도를', 25.3, 26.0, 1],
#  ['더', 26.0, 26.2, 1],
#  ['내야겠습니다', 26.2, 26.8, 1],
#  ['꼭', 26.8, 28.5, 1],
#  ['처리해야', 28.5, 29.2, 1],
#  ['할', 29.2, 29.5, 1],
#  ['일이', 29.5, 29.7, 1],
#  ['또', 29.7, 30.0, 1],
#  ['과제는', 30.0, 30.5, 1],
#  ['6300번', 30.5, 32.0, 1],
#  ['산업안전보건법', 32.0, 33.5, 1],
#  ['입니다', 33.5, 34.0, 1],
#  ['하나유치원', 34.0, 35.3, 1],
#  ['선법은', 35.3, 35.9, 1],
#  ['오늘', 35.9, 36.2, 1],
#  ['의', 36.2, 36.5, 1],
#  ['연애', 36.5, 36.8, 1],
#  ['법안소위에서', 36.8, 38.0, 1],
#  ['어머니들', 38.0, 38.9, 1],
#  ['예정입니다', 38.9, 39.7, 1],
#  ['오늘', 39.7, 40.6, 1],
#  ['합의가', 40.6, 41.2, 1],
#  ['이루어지지', 41.2, 41.8, 1],
#  ['않을', 41.8, 42.1, 1],
#  ['경우', 42.1, 42.5, 1],
#  ['이십칠분', 43.8, 44.0, 1],
#  ['에', 44.0, 44.1, 1],
#  ['철인가', 44.1, 44.8, 1],
#  ['사실상', 44.8, 45.4, 1],
#  ['어렵습니다', 45.4, 46.1, 1],
#  ['자유한국당', 46.1, 47.9, 1],
#  ['너', 47.9, 48.1, 1],
#  ['우리', 48.1, 48.4, 1],
#  ['아이들이', 48.4, 48.9, 1],
#  ['하는', 48.9, 49.1, 1],
#  ['마음이', 49.1, 49.7, 1],
#  ['조금이라도', 49.7, 50.3, 1],
#  ['있다면', 50.3, 50.6, 1],
#  ['6003번', 50.6, 52.0, 1],
#  ['노니의', 52.0, 52.5, 1],
#  ['접수', 52.5, 53.3, 1],
#  ['임해야', 53.3, 53.9, 1],
#  ['합니다', 53.9, 54.1, 1],
#  ['지난번', 54.1, 56.5, 1],
#  ['정기국회', 56.5, 57.1, 1],
#  ['때처럼', 57.1, 57.6, 1],
#  ['법안처리를', 57.6, 59.9, 1],
#  ['연', 60.4, 60.8, 1],
#  ['시키려는', 60.8, 61.7, 1],
#  ['무슨', 61.7, 62.4, 1],
#  ['국민이', 62.4, 63.6, 1],
#  ['용납하지', 63.6, 64.5, 1],
#  ['않을', 64.5, 64.8, 1],
#  ['것입니다', 64.8, 65.1, 1],
#  ['우리당은', 65.1, 67.2, 1],
#  ['오늘', 67.2, 67.9, 1],
#  ['처리될', 67.9, 69.2, 1],
#  ['수', 69.2, 69.3, 1],
#  ['있도록', 69.3, 69.4, 1],
#  ['최선을', 69.4, 70.5, 1],
#  ['다해서', 70.5, 70.9, 1],
#  ['열린', 70.9, 71.5, 1],
#  ['자세로', 71.5, 71.9, 1],
#  ['소방서에', 71.9, 73.3, 1],
#  ['임하겠습니다', 73.3, 73.9, 1],
#  ['그러나', 73.9, 76.4, 1],
#  ['끝내', 76.4, 77.3, 1],
#  ['자유한국당이', 77.3, 78.5, 1],
#  ['반대한다면', 78.5, 79.6, 1],
#  ['패스트트랙을', 79.6, 82.4, 1],
#  ['통해', 82.4, 83.6, 1],
#  ['번', 83.6, 84.5, 1],
#  ['처리하는', 84.5, 85.5, 1],
#  ['방안을', 85.5, 86.1, 1],
#  ['추진', 86.1, 87.5, 1],
#  ['하겠습니다', 87.5, 88.0, 1],
#  ['위험의', 88.0, 89.9, 1],
#  ['외주화', 89.9, 89.9, 1],
#  ['를', 89.9, 90.5, 1],
#  ['막을', 90.5, 90.9, 1],
#  ['산업안전보건법', 90.9, 92.9, 1],
#  ['또', 92.9, 93.0, 1],
#  ['반드시', 93.0, 93.6, 1],
#  ['처리하겠습니다', 93.6, 94.2, 1],
#  ['하청노동자들의', 94.2, 96.6, 1],
#  ['더', 96.6, 97.0, 1],
#  ['이상', 97.0, 97.3, 1],
#  ['내몰리지', 97.3, 98.8, 1],
#  ['않기', 98.8, 99.2, 1],
#  ['위해서', 99.2, 99.6, 1],
#  ['필요한', 99.6, 99.9, 1],
#  ['법안입니다', 99.9, 100.4, 1],
#  ['다행히', 100.4, 101.9, 1],
#  ['어제', 101.9, 102.4, 1],
#  ['환노위', 102.4, 102.9, 1],
#  ['고용노동소위', 102.9, 103.9, 1],
#  ['해서', 103.9, 104.2, 1],
#  ['27일', 104.2, 105.0, 1],
#  ['본회의에서', 105.0, 105.4, 1],
#  ['산업안전보건법을', 105.4, 107.6, 1],
#  ['처리하기로', 107.6, 108.4, 1],
#  ['여야간', 108.4, 109.1, 1],
#  ['의견이', 109.1, 110.0, 1],
#  ['모아졌습니다', 110.0, 110.5, 1],
#  ['앞으로', 110.5, 111.7, 1],
#  ['논의과정에서', 111.7, 112.5, 1],
#  ['차질없이', 112.5, 113.6, 1],
#  ['처리될', 113.6, 115.2, 1],
#  ['수', 115.2, 115.3, 1],
#  ['있도록', 115.3, 115.5, 1],
#  ['기대합니다', 115.5, 117.5, 1],
#  ['대부분', 117.5, 120.1, 1],
#  ['협상을', 120.4, 121.1, 1],
#  ['총괄하는', 121.1, 121.6, 1],
#  ['비건', 121.6, 122.4, 1],
#  ['미국', 122.4, 122.8, 1],
#  ['특별대표가', 122.8, 123.6, 1],
#  ['어제', 123.6, 123.9, 1],
#  ['방황하면서', 123.9, 124.6, 1],
#  ['주목할만한', 124.6, 125.9, 1],
#  ['메시지', 125.9, 126.5, 1],
#  ['를', 126.5, 126.6, 1],
#  ['발표했습니다', 126.6, 127.3, 1],
#  ['인도적', 127.3, 128.5, 1],
#  ['차원의', 128.5, 128.9, 1],
#  ['대북지원을', 128.9, 129.7, 1],
#  ['확실히', 129.7, 130.1, 1],
#  ['보장하고', 130.1, 130.7, 1],
#  ['미국인의', 130.7, 131.8, 1],
#  ['북한', 131.8, 132.5, 1],
#  ['여행', 132.5, 132.8, 1],
#  ['금지', 132.8, 133.1, 1],
#  ['조치를', 133.1, 133.6, 1],
#  ['재검토하겠다고', 133.6, 134.8, 1],
#  ['밝혔다', 134.8, 135.0, 1],
#  ['입니다', 135.0, 135.6, 1],
#  ['남궁민', 135.6, 137.4, 1],
#  ['사이를', 137.4, 137.8, 1],
#  ['갈라놓았던', 137.8, 138.4, 1],
#  ['친한', 138.4, 138.9, 1],
#  ['70년에', 138.9, 139.5, 1],
#  ['적대감을', 139.5, 140.2, 1],
#  ['뛰어넘을', 140.2, 141.1, 1],
#  ['수', 141.1, 141.2, 1],
#  ['있도록', 141.2, 141.7, 1],
#  ['북한과', 141.7, 142.9, 1],
#  ['확장하겠다는', 142.9, 143.7, 1],
#  ['결혼', 143.7, 144.3, 1],
#  ['그동안은', 144.3, 146.4, 1],
#  ['엄격한', 146.4, 147.0, 1],
#  ['대북제재', 147.0, 147.6, 1],
#  ['방침을', 147.6, 148.1, 1],
#  ['고수했던', 148.1, 148.8, 1],
#  ['미국이', 148.8, 149.3, 1],
#  ['유화책을', 149.3, 150.8, 1],
#  ['제시한', 150.8, 151.3, 1],
#  ['것입니다', 151.3, 151.8, 1],
#  ['미국', 151.8, 153.0, 1],
#  ['정부가', 153.0, 153.4, 1],
#  ['인도적', 153.4, 154.5, 1],
#  ['차원의', 154.5, 154.9, 1],
#  ['대북지원을', 154.9, 156.0, 1],
#  ['내게', 156.0, 156.3, 1],
#  ['북미대화를', 156.3, 157.8, 1],
#  ['다시', 157.8, 158.4, 1],
#  ['진전', 158.4, 159.0, 1],
#  ['시키겠다는', 159.0, 159.6, 1],
#  ['강한', 159.6, 160.3, 1],
#  ['의지를', 160.3, 160.6, 1],
#  ['밝힌', 160.6, 161.4, 1],
#  ['것으로', 161.4, 161.9, 1],
#  ['해석됩니다', 161.9, 162.7, 1],
#  ['북한이', 162.7, 164.1, 1],
#  ['어떤', 164.1, 164.4, 1],
#  ['반응을', 164.4, 164.7, 1],
#  ['보이는지', 164.7, 165.0, 1],
#  ['나의', 165.0, 165.3, 1],
#  ['따라', 165.3, 165.7, 1],
#  ['한동안', 165.7, 166.4, 1],
#  ['곁에', 166.4, 166.7, 1],
#  ['교착상태를', 166.7, 167.7, 1],
#  ['보이던', 167.7, 168.2, 1],
#  ['북미', 168.2, 168.5, 1],
#  ['대화가', 168.5, 169.3, 1],
#  ['재개', 169.3, 170.0, 1],
#  ['될', 170.0, 170.2, 1],
#  ['가능성도', 170.2, 170.9, 1],
#  ['충분히', 170.9, 171.5, 1],
#  ['있어', 171.5, 171.7, 1],
#  ['보입니다', 171.7, 172.3, 1],
#  ['오늘과', 172.3, 173.6, 1],
#  ['내일', 173.6, 174.0, 1],
#  ['추석', 174.0, 174.8, 1],
#  ['대표회의', 174.8, 175.6, 1],
#  ['한미워킹그룹', 175.6, 176.8, 1],
#  ['2차', 176.8, 177.4, 1],
#  ['회의를', 177.4, 177.8, 1],
#  ['통해', 177.8, 178.1, 1],
#  ['한미양국이', 178.1, 179.0, 1],
#  ['국민', 179.0, 179.8, 1],
#  ['새로운', 180.3, 181.3, 1],
#  ['돌파구를', 181.3, 182.2, 1],
#  ['마련하게', 182.2, 182.8, 1],
#  ['바랍니다', 182.8, 183.4, 1],
#  ['미국측이', 183.4, 185.5, 1],
#  ['인도적', 185.5, 186.2, 1],
#  ['차원의', 186.2, 186.5, 1],
#  ['제', 186.5, 186.7, 1],
#  ['해제를', 186.7, 187.4, 1],
#  ['식사하면서', 187.4, 188.0, 1],
#  ['남북', 188.0, 188.6, 1],
#  ['교류', 188.6, 188.9, 1],
#  ['해도', 188.9, 189.1, 1],
#  ['탄력이', 189.1, 190.1, 1],
#  ['붙을', 190.1, 190.5, 1],
#  ['것으로', 190.5, 190.9, 1],
#  ['예상됩니다', 190.9, 191.7, 1],
#  ['26일', 191.7, 194.0, 1],
#  ['열리는', 194.0, 195.0, 1],
#  ['남북', 195.0, 195.8, 1],
#  ['철도', 195.8, 197.3, 1],
#  ['착공시기', 197.3, 198.4, 1],
#  ['남북교류를', 198.4, 199.5, 1],
#  ['확대하고', 199.5, 200.2, 1],
#  ['북미', 200.2, 201.1, 1],
#  ['대화', 201.1, 201.4, 1],
#  ['친절을', 201.4, 202.0, 1],
#  ['가져오는', 202.0, 202.5, 1],
#  ['계기가', 202.5, 203.0, 1],
#  ['되기를', 203.0, 203.2, 1],
#  ['바랍니다', 203.2, 203.9, 1],
#  ['미국', 203.9, 206.4, 1],
#  ['중앙은행이', 206.4, 207.1, 1],
#  ['오늘', 207.1, 207.5, 1],
#  ['새벽', 207.5, 208.1, 1],
#  ['기준', 208.1, 208.8, 1],
#  ['금리를', 208.8, 209.4, 1],
#  ['또', 209.4, 209.6, 1],
#  ['인상했습니다', 209.6, 210.4, 1],
#  ['월드', 210.4, 211.5, 1],
#  ['더', 211.5, 211.6, 1],
#  ['많은', 211.6, 212.6, 1],
#  ['벌써', 212.6, 212.9, 1],
#  ['네', 212.9, 213.2, 1],
#  ['번째', 213.2, 213.3, 1],
#  ['기준', 213.3, 214.2, 1],
#  ['금리', 214.2, 214.6, 1],
#  ['인상', 214.6, 215.0, 1],
#  ['입니다', 215.0, 215.4, 1],
#  ['사람일까', 215.4, 217.0, 1],
#  ['우리나라의', 217.0, 218.1, 1],
#  ['기준', 218.1, 218.7, 1],
#  ['금리', 218.7, 219.1, 1],
#  ['격차', 219.1, 219.3, 1],
#  ['넣어서', 219.3, 220.0, 1],
#  ['벌어졌습니다', 220.0, 220.8, 1],
#  ['미국', 220.8, 222.2, 1],
#  ['금리', 222.2, 222.5, 1],
#  ['인상은', 222.5, 223.1, 1],
#  ['우리', 223.1, 223.4, 1],
#  ['경제의', 223.4, 223.9, 1],
#  ['여러', 223.9, 224.5, 1],
#  ['측면에서', 224.5, 225.1, 1],
#  ['영향을', 225.1, 226.4, 1],
#  ['미치게', 226.4, 226.9, 1],
#  ['됩니다', 226.9, 227.1, 1],
#  ['물론', 227.1, 228.4, 1],
#  ['당장은', 228.4, 229.2, 1],
#  ['우리', 229.2, 229.5, 1],
#  ['경제에', 229.5, 230.0, 1],
#  ['큰', 230.0, 230.2, 1],
#  ['영향은', 230.2, 230.9, 1],
#  ['없을', 230.9, 231.2, 1],
#  ['것이란', 231.2, 231.7, 1],
#  ['전망이', 231.7, 232.3, 1],
#  ['오세암', 232.3, 232.6, 1],
#  ['니다', 232.6, 232.9, 1],
#  ['그러나', 232.9, 233.8, 1],
#  ['외국인', 233.8, 234.5, 1],
#  ['자금', 234.5, 234.8, 1],
#  ['유출과', 234.8, 235.4, 1],
#  ['이로', 235.4, 235.7, 1],
#  ['인해', 235.7, 235.9, 1],
#  ['금융시장이', 235.9, 237.7, 1],
#  ['불안해질', 237.7, 238.5, 1],
#  ['가능성을', 238.5, 239.3, 1],
#  ['배제할', 239.3, 239.8, 1],
#  ['수', 239.8, 240.0, 1],
#  ['없음', 240.0, 240.3, 1],
#  ['네', 0.4, 1.7, 1],
#  ['반갑습니다', 1.7, 7.1, 1],
#  ['제', 7.1, 7.7, 1],
#  ['125차', 7.7, 8.4, 1],
#  ['정책조정회의', 8.4, 9.4, 1],
#  ['일을', 9.4, 9.8, 1],
#  ['상영표', 9.8, 10.2, 1],
#  ['원내대표에', 10.2, 10.9, 1],
#  ['모두', 10.9, 11.1, 1],
#  ['바로', 11.1, 11.4, 1],
#  ['가겠습니다', 11.4, 12.0, 1],
#  ['11', 12.0, 15.3, 1],
#  ['12', 15.3, 16.2, 1],
#  ['월', 16.2, 16.5, 1],
#  ['이렇게', 16.5, 17.4, 1],
#  ['분위기가', 17.4, 17.7, 1],
#  ['이제', 17.7, 19.2, 1],
#  ['일주일', 19.2, 19.6, 1],
#  ['앞으로', 19.6, 19.9, 1],
#  ['다가왔습니다', 19.9, 20.5, 1],
#  ['여야가', 20.5, 22.5, 1],
#  ['민생법안', 22.5, 23.5, 1],
#  ['처리를', 23.5, 24.0, 1],
#  ['위해서', 24.0, 24.4, 1],
#  ['노니의', 24.4, 25.3, 1],
#  ['속도를', 25.3, 26.0, 1],
#  ['더', 26.0, 26.2, 1],
#  ['내야겠습니다', 26.2, 26.8, 1],
#  ['꼭', 26.8, 28.5, 1],
#  ['처리해야', 28.5, 29.2, 1],
#  ['할', 29.2, 29.5, 1],
#  ['일이', 29.5, 29.7, 1],
#  ['또', 29.7, 30.0, 1],
#  ['과제는', 30.0, 30.5, 1],
#  ['6300번', 30.5, 32.0, 1],
#  ['산업안전보건법', 32.0, 33.5, 1],
#  ['입니다', 33.5, 34.0, 1],
#  ['하나유치원', 34.0, 35.3, 1],
#  ['선법은', 35.3, 35.9, 1],
#  ['오늘', 35.9, 36.2, 1],
#  ['의', 36.2, 36.5, 1],
#  ['연애', 36.5, 36.8, 1],
#  ['법안소위에서', 36.8, 38.0, 1],
#  ['어머니들', 38.0, 38.9, 1],
#  ['예정입니다', 38.9, 39.7, 1],
#  ['오늘', 39.7, 40.6, 1],
#  ['합의가', 40.6, 41.2, 1],
#  ['이루어지지', 41.2, 41.8, 1],
#  ['않을', 41.8, 42.1, 1],
#  ['경우', 42.1, 42.5, 1],
#  ['이십칠분', 43.8, 44.0, 1],
#  ['에', 44.0, 44.1, 1],
#  ['철인가', 44.1, 44.8, 1],
#  ['사실상', 44.8, 45.4, 1],
#  ['어렵습니다', 45.4, 46.1, 1],
#  ['자유한국당', 46.1, 47.9, 1],
#  ['너', 47.9, 48.1, 1],
#  ['우리', 48.1, 48.4, 1],
#  ['아이들이', 48.4, 48.9, 1],
#  ['하는', 48.9, 49.1, 1],
#  ['마음이', 49.1, 49.7, 1],
#  ['조금이라도', 49.7, 50.3, 1],
#  ['있다면', 50.3, 50.6, 1],
#  ['6003번', 50.6, 52.0, 1],
#  ['노니의', 52.0, 52.5, 1],
#  ['접수', 52.5, 53.3, 1],
#  ['임해야', 53.3, 53.9, 1],
#  ['합니다', 53.9, 54.1, 1],
#  ['지난번', 54.1, 56.5, 1],
#  ['정기국회', 56.5, 57.1, 1],
#  ['때처럼', 57.1, 57.6, 1],
#  ['법안처리를', 57.6, 59.9, 1],
#  ['연', 60.4, 60.8, 1],
#  ['시키려는', 60.8, 61.7, 1],
#  ['무슨', 61.7, 62.4, 1],
#  ['국민이', 62.4, 63.6, 1],
#  ['용납하지', 63.6, 64.5, 1],
#  ['않을', 64.5, 64.8, 1],
#  ['것입니다', 64.8, 65.1, 1],
#  ['우리당은', 65.1, 67.2, 1],
#  ['오늘', 67.2, 67.9, 1],
#  ['처리될', 67.9, 69.2, 1],
#  ['수', 69.2, 69.3, 1],
#  ['있도록', 69.3, 69.4, 1],
#  ['최선을', 69.4, 70.5, 1],
#  ['다해서', 70.5, 70.9, 1],
#  ['열린', 70.9, 71.5, 1],
#  ['자세로', 71.5, 71.9, 1],
#  ['소방서에', 71.9, 73.3, 1],
#  ['임하겠습니다', 73.3, 73.9, 1],
#  ['그러나', 73.9, 76.4, 1],
#  ['끝내', 76.4, 77.3, 1],
#  ['자유한국당이', 77.3, 78.5, 1],
#  ['반대한다면', 78.5, 79.6, 1],
#  ['패스트트랙을', 79.6, 82.4, 1],
#  ['통해', 82.4, 83.6, 1],
#  ['번', 83.6, 84.5, 1],
#  ['처리하는', 84.5, 85.5, 1],
#  ['방안을', 85.5, 86.1, 1],
#  ['추진', 86.1, 87.5, 1],
#  ['하겠습니다', 87.5, 88.0, 1],
#  ['위험의', 88.0, 89.9, 1],
#  ['외주화', 89.9, 89.9, 1],
#  ['를', 89.9, 90.5, 1],
#  ['막을', 90.5, 90.9, 1],
#  ['산업안전보건법', 90.9, 92.9, 1],
#  ['또', 92.9, 93.0, 1],
#  ['반드시', 93.0, 93.6, 1],
#  ['처리하겠습니다', 93.6, 94.2, 1],
#  ['하청노동자들의', 94.2, 96.6, 1],
#  ['더', 96.6, 97.0, 1],
#  ['이상', 97.0, 97.3, 1],
#  ['내몰리지', 97.3, 98.8, 1],
#  ['않기', 98.8, 99.2, 1],
#  ['위해서', 99.2, 99.6, 1],
#  ['필요한', 99.6, 99.9, 1],
#  ['법안입니다', 99.9, 100.4, 1],
#  ['다행히', 100.4, 101.9, 1],
#  ['어제', 101.9, 102.4, 1],
#  ['환노위', 102.4, 102.9, 1],
#  ['고용노동소위', 102.9, 103.9, 1],
#  ['해서', 103.9, 104.2, 1],
#  ['27일', 104.2, 105.0, 1],
#  ['본회의에서', 105.0, 105.4, 1],
#  ['산업안전보건법을', 105.4, 107.6, 1],
#  ['처리하기로', 107.6, 108.4, 1],
#  ['여야간', 108.4, 109.1, 1],
#  ['의견이', 109.1, 110.0, 1],
#  ['모아졌습니다', 110.0, 110.5, 1],
#  ['앞으로', 110.5, 111.7, 1],
#  ['논의과정에서', 111.7, 112.5, 1],
#  ['차질없이', 112.5, 113.6, 1],
#  ['처리될', 113.6, 115.2, 1],
#  ['수', 115.2, 115.3, 1],
#  ['있도록', 115.3, 115.5, 1],
#  ['기대합니다', 115.5, 117.5, 1],
#  ['대부분', 117.5, 120.1, 1],
#  ['협상을', 120.4, 121.1, 1],
#  ['총괄하는', 121.1, 121.6, 1],
#  ['비건', 121.6, 122.4, 1],
#  ['미국', 122.4, 122.8, 1],
#  ['특별대표가', 122.8, 123.6, 1],
#  ['어제', 123.6, 123.9, 1],
#  ['방황하면서', 123.9, 124.6, 1],
#  ['주목할만한', 124.6, 125.9, 1],
#  ['메시지', 125.9, 126.5, 1],
#  ['를', 126.5, 126.6, 1],
#  ['발표했습니다', 126.6, 127.3, 1],
#  ['인도적', 127.3, 128.5, 1],
#  ['차원의', 128.5, 128.9, 1],
#  ['대북지원을', 128.9, 129.7, 1],
#  ['확실히', 129.7, 130.1, 1],
#  ['보장하고', 130.1, 130.7, 1],
#  ['미국인의', 130.7, 131.8, 1],
#  ['북한', 131.8, 132.5, 1],
#  ['여행', 132.5, 132.8, 1],
#  ['금지', 132.8, 133.1, 1],
#  ['조치를', 133.1, 133.6, 1],
#  ['재검토하겠다고', 133.6, 134.8, 1],
#  ['밝혔다', 134.8, 135.0, 1],
#  ['입니다', 135.0, 135.6, 1],
#  ['남궁민', 135.6, 137.4, 1],
#  ['사이를', 137.4, 137.8, 1],
#  ['갈라놓았던', 137.8, 138.4, 1],
#  ['친한', 138.4, 138.9, 1],
#  ['70년에', 138.9, 139.5, 1],
#  ['적대감을', 139.5, 140.2, 1],
#  ['뛰어넘을', 140.2, 141.1, 1],
#  ['수', 141.1, 141.2, 1],
#  ['있도록', 141.2, 141.7, 1],
#  ['북한과', 141.7, 142.9, 1],
#  ['확장하겠다는', 142.9, 143.7, 1],
#  ['결혼', 143.7, 144.3, 1],
#  ['그동안은', 144.3, 146.4, 1],
#  ['엄격한', 146.4, 147.0, 1],
#  ['대북제재', 147.0, 147.6, 1],
#  ['방침을', 147.6, 148.1, 1],
#  ['고수했던', 148.1, 148.8, 1],
#  ['미국이', 148.8, 149.3, 1],
#  ['유화책을', 149.3, 150.8, 1],
#  ['제시한', 150.8, 151.3, 1],
#  ['것입니다', 151.3, 151.8, 1],
#  ['미국', 151.8, 153.0, 1],
#  ['정부가', 153.0, 153.4, 1],
#  ['인도적', 153.4, 154.5, 1],
#  ['차원의', 154.5, 154.9, 1],
#  ['대북지원을', 154.9, 156.0, 1],
#  ['내게', 156.0, 156.3, 1],
#  ['북미대화를', 156.3, 157.8, 1],
#  ['다시', 157.8, 158.4, 1],
#  ['진전', 158.4, 159.0, 1],
#  ['시키겠다는', 159.0, 159.6, 1],
#  ['강한', 159.6, 160.3, 1],
#  ['의지를', 160.3, 160.6, 1],
#  ['밝힌', 160.6, 161.4, 1],
#  ['것으로', 161.4, 161.9, 1],
#  ['해석됩니다', 161.9, 162.7, 1],
#  ['북한이', 162.7, 164.1, 1],
#  ['어떤', 164.1, 164.4, 1],
#  ['반응을', 164.4, 164.7, 1],
#  ['보이는지', 164.7, 165.0, 1],
#  ['나의', 165.0, 165.3, 1],
#  ['따라', 165.3, 165.7, 1],
#  ['한동안', 165.7, 166.4, 1],
#  ['곁에', 166.4, 166.7, 1],
#  ['교착상태를', 166.7, 167.7, 1],
#  ['보이던', 167.7, 168.2, 1],
#  ['북미', 168.2, 168.5, 1],
#  ['대화가', 168.5, 169.3, 1],
#  ['재개', 169.3, 170.0, 1],
#  ['될', 170.0, 170.2, 1],
#  ['가능성도', 170.2, 170.9, 1],
#  ['충분히', 170.9, 171.5, 1],
#  ['있어', 171.5, 171.7, 1],
#  ['보입니다', 171.7, 172.3, 1],
#  ['오늘과', 172.3, 173.6, 1],
#  ['내일', 173.6, 174.0, 1],
#  ['추석', 174.0, 174.8, 1],
#  ['대표회의', 174.8, 175.6, 1],
#  ['한미워킹그룹', 175.6, 176.8, 1],
#  ['2차', 176.8, 177.4, 1],
#  ['회의를', 177.4, 177.8, 1],
#  ['통해', 177.8, 178.1, 1],
#  ['한미양국이', 178.1, 179.0, 1],
#  ['국민', 179.0, 179.8, 1],
#  ['새로운', 180.3, 181.3, 1],
#  ['돌파구를', 181.3, 182.2, 1],
#  ['마련하게', 182.2, 182.8, 1],
#  ['바랍니다', 182.8, 183.4, 1],
#  ['미국측이', 183.4, 185.5, 1],
#  ['인도적', 185.5, 186.2, 1],
#  ['차원의', 186.2, 186.5, 1],
#  ['제', 186.5, 186.7, 1],
#  ['해제를', 186.7, 187.4, 1],
#  ['식사하면서', 187.4, 188.0, 1],
#  ['남북', 188.0, 188.6, 1],
#  ['교류', 188.6, 188.9, 1],
#  ['해도', 188.9, 189.1, 1],
#  ['탄력이', 189.1, 190.1, 1],
#  ['붙을', 190.1, 190.5, 1],
#  ['것으로', 190.5, 190.9, 1],
#  ['예상됩니다', 190.9, 191.7, 1],
#  ['26일', 191.7, 194.0, 1],
#  ['열리는', 194.0, 195.0, 1],
#  ['남북', 195.0, 195.8, 1],
#  ['철도', 195.8, 197.3, 1],
#  ['착공시기', 197.3, 198.4, 1],
#  ['남북교류를', 198.4, 199.5, 1],
#  ['확대하고', 199.5, 200.2, 1],
#  ['북미', 200.2, 201.1, 1],
#  ['대화', 201.1, 201.4, 1],
#  ['친절을', 201.4, 202.0, 1],
#  ...]

# %%
# CSV 파일로 저장
csv_file = "text/" + FILE_NAME + ".csv"
with open(csv_file, 'w', encoding='utf-8', newline='') as f:
    wr = csv.writer(f)
    wr.writerow(["word", "start_time", "end_time", "speaker_tag"])
    for words in words_array:
        wr.writerow(words)
